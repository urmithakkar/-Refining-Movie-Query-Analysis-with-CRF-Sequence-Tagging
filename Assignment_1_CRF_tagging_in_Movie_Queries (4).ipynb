# %% [markdown]
# # CRF sequence tagging for Movie Queries
#
# This project involves optimizing the performance of a **Conditional Random Field (CRF) sequence tagger** for movie trivia questions and answers data, which consist of instances of data of word sequences with the target classes/labels for each word in a **BIO (Beginning, Inside, Outside)** tagging format.
#
# It involves reading in, pre-processing, training and developing our tagger on the training data from *trivia10k13train.bio.txt*, and finally testing our tagger on the data *trivia10k13test.bio.txt*, attempting to get the best performing tagger across the different labels in our development process. We are going to optimize the performance of the tagger by improving its feature extraction function on the word sequences, incorporating POS tagging first, then the final task is to optimize the performance by all legal means neccessary (except looking at the test data).

# %%
# You may need to run this first- uncomment if so
# !pip install python-crfsuite
# Out:
# Requirement already satisfied: python-crfsuite in /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages (0.9.7)

# %%
import os
import sys

from copy import deepcopy
from collections import Counter
from nltk.tag import CRFTagger

from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import classification_report

from matplotlib import pyplot as plt
import numpy as np

import re
import unicodedata

# %%
def get_raw_data_from_bio_file(fpath):
    """A simple function to read in from a one-word-per-line BIO
    (Beginning, Inside, Outside) tagged corpus, tab separated
    and each example sentence/text separated with a blank line.
    The data is already tokenized in a simple way.
    e.g.:
    
    B-Actor	steve
    I-Actor	mcqueen
    O	provided
    O	a
    B-Plot	thrilling
    I-Plot	motorcycle
    I-Plot	chase
    I-Plot	in
    I-Plot	this
    B-Opinion	greatest
    I-Opinion	of
    I-Opinion	all
    B-Plot	ww
    I-Plot	2
    I-Plot	prison
    I-Plot	escape
    I-Plot	movies
    
    returns a list of lists of tuples of (word, tag) tuples
    """
    f = open(fpath)
    data = []  # the data, a list of lists of (word, tag) tuples
    current_sent = []  # data for current sentence/example
    for line in f:
        if line == "\n":  # each instance has a blank line separating it from next one
            # solution
            data.append(current_sent)
            current_sent = []
            continue
        line_data = line.strip("\n").split("\t")
        current_sent.append((line_data[1], line_data[0]))
    f.close()
    return data

# %%
raw_training_data = get_raw_data_from_bio_file("trivia10k13train.bio.txt")

# %%
# have a look at the first example
print(raw_training_data[0])
# Out:
# [('steve', 'B-Actor'), ('mcqueen', 'I-Actor'), ('provided', 'O'), ('a', 'O'), ('thrilling', 'B-Plot'), ('motorcycle', 'I-Plot'), ('chase', 'I-Plot'), ('in', 'I-Plot'), ('this', 'I-Plot'), ('greatest', 'B-Opinion'), ('of', 'I-Opinion'), ('all', 'I-Opinion'), ('ww', 'B-Plot'), ('2', 'I-Plot'), ('prison', 'I-Plot'), ('escape', 'I-Plot'), ('movies', 'I-Plot')]

# %% [markdown]
# print(len(raw_training_data), "instances")
# print(sum([len(sent) for sent in raw_training_data]), "words")

# %%
def preProcess(example):
    """Function takes in list of (word, bio-tag) pairs, e.g.:
        [('steve', 'B-Actor'), ('mcqueen', 'I-Actor'), ('provided', 'O'),
        ('a', 'O'), ('thrilling', 'B-Plot'), ('motorcycle', 'I-Plot'),
        ('chase', 'I-Plot'), ('in', 'I-Plot'), ('this', 'I-Plot'),
        ('greatest', 'B-Opinion'), ('of', 'I-Opinion'), ('all', 'I-Opinion'),
        ('ww', 'B-Plot'), ('2', 'I-Plot'), ('prison', 'I-Plot'),
        ('escape', 'I-Plot'), ('movies', 'I-Plot')]
        
    returns new (token, bio-tag) pairs with preprocessing applied to the words"""

    preprocessed_example = example  # trivial- no preprocessing
    return preprocessed_example

# %%
training_data = [preProcess(example) for example in raw_training_data]

# %%
# check the effect of pre-processing
print(training_data[0])
# Out:
# [('steve', 'B-Actor'), ('mcqueen', 'I-Actor'), ('provided', 'O'), ('a', 'O'), ('thrilling', 'B-Plot'), ('motorcycle', 'I-Plot'), ('chase', 'I-Plot'), ('in', 'I-Plot'), ('this', 'I-Plot'), ('greatest', 'B-Opinion'), ('of', 'I-Opinion'), ('all', 'I-Opinion'), ('ww', 'B-Plot'), ('2', 'I-Plot'), ('prison', 'I-Plot'), ('escape', 'I-Plot'), ('movies', 'I-Plot')]

# %%
_pattern = re.compile(r"\d")  # to recognize numbers/digits


# This is the 'out-of-the-box' get_features function from the nltk CRF tagger
def get_features(tokens, idx):
    """
    Extract basic features about this word including
         - Current Word
         - Is Capitalized ?
         - Has Punctuation ?
         - Has Number ?
         - Suffixes up to length 3
    Note that : we might include feature over previous word, next word ect.

    :return : a list which contains the features
    :rtype : list(str)

    """
    token = tokens[idx]
    feature_list = []

    if not token:
        return feature_list
    
    # Capitalization
    if token[0].isupper():
        feature_list.append("CAPITALIZATION")

    # Number
    if re.search(_pattern, token) is not None:
        feature_list.append("HAS_NUM")

    # Punctuation
    punc_cat = set(["Pc", "Pd", "Ps", "Pe", "Pi", "Pf", "Po"])
    if all(unicodedata.category(x) in punc_cat for x in token):
        feature_list.append("PUNCTUATION")

    # Suffix up to length 3
    if len(token) > 1:
        feature_list.append("SUF_" + token[-1:])
    if len(token) > 2:
        feature_list.append("SUF_" + token[-2:])
    if len(token) > 3:
        feature_list.append("SUF_" + token[-3:])
        
    feature_list.append("WORD_" + token)
    #print(feature_list)
    return feature_list

# %%
# Train the CRF BIO-tag tagger
TAGGER_PATH = "crf_nlu.tagger"  # path to the tagger- it will save/access the model from here
ct = CRFTagger(feature_func=get_features)  # initialize tagger with get_features function

print("training tagger...")
ct.train(training_data, TAGGER_PATH)
print("done")
# Out:
# training tagger...
# done

# %%
# let's see how it does in testing on sentences
def print_tags(sentence):
    # a method to print out the sequence with its tags
    tokens = sentence.split()
    tags = [p[1] for p in ct.tag(tokens)]
    for token, tag in zip(tokens, tags):
        print(f'{token:12s}{tag}')

# %%
# an example from the corpus
example = "steve mcqueen provided a thrilling motorcycle chase in this greatest of all ww 2 prison escape movies"
print_tags(example)
# Out:
# steve       B-Actor
# mcqueen     I-Actor
# provided    O
# a           B-Plot
# thrilling   I-Plot
# motorcycle  I-Plot
# chase       I-Plot
# in          I-Plot
# this        I-Plot
# greatest    I-Plot
# of          I-Plot
# all         I-Plot
# ww          I-Plot
# 2           I-Plot
# prison      I-Plot
# escape      I-Plot
# movies      I-Plot

# %%
# a novel, unseen example we've just made up
print_tags("batman is the main character in batman begins")
# Out:
# batman      O
# is          O
# the         O
# main        O
# character   O
# in          O
# batman      B-Character_Name
# begins      I-Character_Name

# %%
# another example
print_tags("the sound of music")
# Out:
# the         O
# sound       O
# of          O
# music       O

# %%
# load tagger from saved file
ct = CRFTagger(feature_func=get_features)  # initialize tagger
ct.set_model_file(TAGGER_PATH)  # load model from file

# prepare the test data:
raw_test_data = get_raw_data_from_bio_file("trivia10k13test.bio.txt") 
test_data = [preProcess(example) for example in raw_test_data]
print(len(test_data), "instances")
print(sum([len(sent) for sent in test_data]), "words")
# Out:
# 1953 instances
# 39035 words

# %%
print("testing tagger...")
preds = []
y_test = []
for sent in test_data:
    sent_preds = [x[1] for x in ct.tag([s[0] for s in sent])]
    sent_true = [s[1] for s in sent]
    preds.extend(sent_preds)
    y_test.extend(sent_true)
print("done")
# Out:
# testing tagger...
# done

# %%
# Output the classification report (which you should save each time for comparing your models)
print(classification_report(y_test, preds))
print(precision_recall_fscore_support(y_test, preds, average='macro'))  # print out accurate macro score
# Out:
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                   precision    recall  f1-score   support
#
#          B-Actor       0.85      0.88      0.87      1274
#          B-Award       0.72      0.62      0.67        66
# B-Character_Name       0.78      0.24      0.37       283
#       B-Director       0.84      0.72      0.78       425
#          B-Genre       0.83      0.76      0.80       789
#        B-Opinion       0.49      0.30      0.37       195
#         B-Origin       0.52      0.38      0.44       190
#           B-Plot       0.49      0.47      0.48      1577
#          B-Quote       0.75      0.26      0.38        47
#   B-Relationship       0.80      0.53      0.64       171
#     B-Soundtrack       0.00      0.00      0.00         8
#           B-Year       0.94      0.97      0.96       661
#          I-Actor       0.86      0.89      0.87      1553
#          I-Award       0.74      0.69      0.72       147
# I-Character_Name       0.82      0.30      0.43       227
#       I-Director       0.89      0.74      0.81       411
#          I-Genre       0.77      0.75      0.76       544
#        I-Opinion       0.13      0.08      0.10       143
#         I-Origin       0.66      0.68      0.67       808
#           I-Plot       0.82      0.94      0.88     14661
#          I-Quote       0.75      0.55      0.63       349
#   I-Relationship       0.54      0.50      0.52       289
#     I-Soundtrack       0.00      0.00      0.00        30
#           I-Year       0.58      0.68      0.62        44
#                O       0.88      0.81      0.84     14143
#
#         accuracy                           0.82     39035
#        macro avg       0.66      0.55      0.58     39035
#     weighted avg       0.82      0.82      0.82     39035
#
# (0.6581485250363811, 0.5495470870201031, 0.5838971371849242, None)
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
def confusion_matrix_heatmap(y_test, preds):
    """Function to plot a confusion matrix"""
    labels = list(set(y_test))   # get the labels in the y_test
    # print(labels)
    cm = confusion_matrix(y_test, preds, labels)
    fig = plt.figure(figsize=(20,20))
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title('Confusion matrix of the classifier')
    fig.colorbar(cax)
    ax.set_xticks(np.arange(len(labels)))
    ax.set_yticks(np.arange(len(labels)))
    ax.set_xticklabels( labels, rotation=45)
    ax.set_yticklabels( labels)

    for i in range(len(cm)):
        for j in range(len(cm)):
            text = ax.text(j, i, cm[i, j],
                           ha="center", va="center", color="w")

    plt.xlabel('Predicted')
    plt.ylabel('True')
    #fig.tight_layout()
    # fix for mpl bug that cuts off top/bottom of seaborn viz:
    b, t = plt.ylim() # discover the values for bottom and top
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t) # update the ylim(bottom, top) values
    plt.show() # ta-da!

# %%
confusion_matrix_heatmap(y_test, preds)
# Out:
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=['I-Quote', 'B-Origin', 'I-Plot', 'I-Relationship', 'B-Soundtrack', 'B-Quote', 'B-Director', 'I-Actor', 'B-Year', 'B-Genre', 'B-Opinion', 'B-Actor', 'I-Genre', 'I-Year', 'I-Origin', 'I-Soundtrack', 'I-Director', 'B-Relationship', 'I-Character_Name', 'O', 'B-Award', 'B-Character_Name', 'B-Plot', 'I-Award', 'I-Opinion'] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %%
# Let's see what the CRF learned by looking at the internal transition/feature weights....

# %%
def print_transition_weights(transitions):
    """Sort the transitions between states/labels from highest to
    lowest strengths and print out."""
    ranked_transitions = [x for x in sorted(transitions,
                                               key=lambda x:x[1], reverse=True)]
    for (label_from, label_to), weight in ranked_transitions:
        print("%0.6f %-8s -> %s" % (weight, label_from, label_to))

# %%
print_transition_weights(ct._tagger.info().transitions.items())
# Out:
# 8.730936 B-Actor  -> I-Actor
# 8.345982 B-Plot   -> I-Plot
# 8.062881 B-Director -> I-Director
# 7.851024 B-Origin -> I-Origin
# 7.728286 I-Plot   -> I-Plot
# 7.557302 I-Quote  -> I-Quote
# 7.400516 B-Character_Name -> I-Character_Name
# 7.347592 I-Origin -> I-Origin
# 7.270472 B-Relationship -> I-Relationship
# 7.168646 B-Quote  -> I-Quote
# 7.019230 I-Relationship -> I-Relationship
# 6.874782 I-Soundtrack -> I-Soundtrack
# 6.792831 I-Opinion -> I-Opinion
# 6.739054 B-Genre  -> I-Genre
# 6.682199 B-Soundtrack -> I-Soundtrack
# 6.580473 B-Award  -> I-Award
# 6.441732 B-Opinion -> I-Opinion
# 6.428294 I-Award  -> I-Award
# 6.362482 I-Genre  -> I-Genre
# 6.348037 I-Actor  -> I-Actor
# 6.225893 I-Character_Name -> I-Character_Name
# 5.430455 I-Director -> I-Director
# 4.809019 I-Year   -> I-Year
# 4.082752 B-Year   -> I-Year
# 3.773733 B-Character_Name -> B-Plot
# 3.563915 O        -> O
# 3.562699 I-Character_Name -> B-Plot
# 3.277145 O        -> B-Plot
# 3.199695 B-Plot   -> B-Character_Name
# 3.091597 B-Opinion -> B-Genre
# 3.030532 O        -> B-Character_Name
# 2.934198 I-Actor  -> B-Plot
# 2.801482 O        -> B-Actor
# 2.792755 B-Year   -> B-Genre
# 2.706181 O        -> B-Genre
# 2.687525 O        -> B-Director
# 2.672818 I-Actor  -> O
# 2.663746 I-Director -> B-Genre
# 2.655017 B-Genre  -> O
# 2.567043 B-Year   -> B-Director
# 2.534235 I-Genre  -> O
# 2.490029 O        -> B-Origin
# 2.400990 O        -> B-Year
# 2.397687 O        -> B-Quote
# 2.373786 I-Director -> O
# 2.266841 I-Plot   -> B-Character_Name
# 2.265270 B-Genre  -> B-Opinion
# 2.264145 O        -> B-Soundtrack
# 2.258935 O        -> B-Relationship
# 2.251816 O        -> B-Opinion
# 2.131672 B-Opinion -> O
# 2.126611 O        -> B-Award
# 2.117207 B-Opinion -> B-Origin
# 1.999124 B-Genre  -> B-Relationship
# 1.937795 B-Relationship -> O
# 1.933784 B-Genre  -> B-Plot
# 1.930446 I-Genre  -> B-Plot
# 1.910566 B-Genre  -> B-Director
# 1.891287 B-Opinion -> B-Director
# 1.891230 B-Director -> O
# 1.881804 B-Opinion -> B-Plot
# 1.874311 B-Director -> B-Genre
# 1.839720 I-Opinion -> B-Genre
# 1.751070 I-Character_Name -> O
# 1.734777 I-Genre  -> B-Relationship
# 1.656710 B-Character_Name -> O
# 1.648629 B-Genre  -> B-Origin
# 1.623114 I-Director -> B-Plot
# 1.569655 B-Year   -> B-Opinion
# 1.557249 B-Year   -> O
# 1.514210 I-Year   -> B-Plot
# 1.509890 B-Actor  -> B-Plot
# 1.508110 I-Genre  -> B-Opinion
# 1.396631 B-Origin -> B-Genre
# 1.396501 B-Director -> B-Opinion
# 1.387063 I-Year   -> B-Genre
# 1.385215 I-Year   -> O
# 1.353781 I-Director -> B-Relationship
# 1.345764 I-Origin -> B-Plot
# 1.322186 B-Opinion -> B-Year
# 1.295095 B-Genre  -> B-Year
# 1.289299 I-Origin -> O
# 1.224855 I-Award  -> O
# 1.182365 B-Plot   -> B-Actor
# 1.137015 B-Relationship -> B-Plot
# 1.121243 I-Relationship -> B-Character_Name
# 1.105617 B-Origin -> O
# 1.098265 B-Year   -> B-Plot
# 1.087003 I-Relationship -> O
# 1.084388 I-Opinion -> O
# 1.056202 I-Opinion -> B-Plot
# 1.051100 I-Director -> B-Opinion
# 0.971313 B-Award  -> O
# 0.899805 B-Relationship -> B-Genre
# 0.898257 I-Genre  -> B-Origin
# 0.897439 B-Origin -> B-Plot
# 0.888943 B-Actor  -> O
# 0.887177 I-Relationship -> B-Origin
# 0.856608 I-Opinion -> B-Relationship
# 0.855742 B-Origin -> B-Opinion
# 0.811647 B-Plot   -> O
# 0.810218 I-Actor  -> B-Genre
# 0.799969 B-Director -> B-Relationship
# 0.781695 B-Opinion -> B-Relationship
# 0.767418 I-Actor  -> B-Opinion
# 0.709574 B-Year   -> B-Award
# 0.691967 I-Relationship -> B-Director
# 0.680452 B-Year   -> B-Relationship
# 0.633217 I-Opinion -> B-Origin
# 0.626002 B-Opinion -> B-Actor
# 0.619246 B-Genre  -> B-Actor
# 0.596038 B-Year   -> B-Origin
# 0.580971 I-Relationship -> B-Plot
# 0.577076 B-Relationship -> B-Character_Name
# 0.550891 B-Opinion -> B-Award
# 0.510417 I-Actor  -> B-Award
# 0.503995 I-Relationship -> B-Genre
# 0.457410 B-Genre  -> B-Award
# 0.453808 B-Director -> B-Origin
# 0.444503 I-Award  -> B-Relationship
# 0.440991 I-Year   -> B-Opinion
# 0.440784 I-Origin -> B-Relationship
# 0.423086 I-Genre  -> B-Director
# 0.414510 I-Director -> B-Origin
# 0.409743 I-Award  -> B-Origin
# 0.401053 I-Origin -> B-Genre
# 0.367355 I-Relationship -> B-Award
# 0.362341 B-Relationship -> B-Origin
# 0.345324 I-Director -> B-Year
# 0.320024 I-Genre  -> B-Character_Name
# 0.290050 I-Character_Name -> B-Quote
# 0.288398 I-Award  -> B-Soundtrack
# 0.274935 I-Quote  -> B-Quote
# 0.268692 I-Quote  -> O
# 0.267630 I-Genre  -> B-Year
# 0.259472 I-Origin -> B-Award
# 0.256442 B-Year   -> B-Actor
# 0.244771 I-Soundtrack -> B-Origin
# 0.239951 I-Actor  -> B-Soundtrack
# 0.237958 I-Director -> B-Award
# 0.236196 I-Award  -> B-Genre
# 0.215980 I-Actor  -> B-Origin
# 0.212225 I-Genre  -> B-Award
# 0.195597 B-Award  -> B-Year
# 0.176706 I-Plot   -> B-Actor
# 0.148647 I-Quote  -> B-Character_Name
# 0.148364 B-Director -> B-Character_Name
# 0.129132 I-Soundtrack -> O
# 0.126449 B-Relationship -> B-Actor
# 0.121501 B-Plot   -> B-Opinion
# 0.116394 B-Director -> B-Year
# 0.115634 I-Plot   -> O
# 0.109100 I-Year   -> B-Director
# 0.108970 B-Relationship -> B-Opinion
# 0.091674 B-Quote  -> B-Plot
# 0.082562 I-Award  -> B-Director
# 0.070225 I-Character_Name -> B-Relationship
# 0.065076 B-Actor  -> B-Opinion
# 0.058698 I-Plot   -> B-Origin
# 0.052249 B-Opinion -> B-Character_Name
# 0.042711 I-Opinion -> B-Director
# 0.040102 B-Relationship -> B-Director
# 0.016185 I-Award  -> B-Year
# 0.002568 B-Director -> B-Plot
# -0.001852 I-Award  -> B-Opinion
# -0.032859 I-Opinion -> B-Year
# -0.034626 I-Character_Name -> B-Opinion
# -0.078362 B-Plot   -> B-Genre
# -0.126698 I-Actor  -> B-Quote
# -0.128150 I-Relationship -> B-Actor
# -0.136801 B-Plot   -> B-Origin
# -0.167971 B-Actor  -> B-Genre
# -0.173348 I-Origin -> B-Character_Name
# -0.177007 I-Award  -> B-Actor
# -0.199002 I-Origin -> B-Year
# -0.209389 B-Plot   -> B-Relationship
# -0.246653 I-Award  -> B-Plot
# -0.269033 I-Genre  -> B-Actor
# -0.290423 I-Plot   -> B-Quote
# -0.302729 I-Opinion -> B-Actor
# -0.316463 I-Origin -> B-Opinion
# -0.319441 I-Origin -> B-Director
# -0.320591 I-Actor  -> B-Relationship
# -0.393885 B-Character_Name -> B-Actor
# -0.413538 B-Year   -> B-Character_Name
# -0.416705 B-Soundtrack -> O
# -0.452781 I-Relationship -> B-Opinion
# -0.507671 I-Actor  -> B-Character_Name
# -0.542928 I-Director -> B-Actor
# -0.553140 I-Character_Name -> B-Actor
# -0.652014 B-Plot   -> B-Year
# -0.714168 I-Origin -> B-Actor
# -0.751903 I-Plot   -> B-Soundtrack
# -0.769372 B-Quote  -> O
# -0.773347 I-Plot   -> B-Award
# -0.996567 I-Plot   -> B-Genre
# -1.045340 I-Plot   -> B-Relationship
# -1.310679 I-Plot   -> B-Opinion
# -1.547280 I-Plot   -> B-Director
# -1.931441 I-Plot   -> B-Year

# %%
def print_most_predictive_state_features(state_features,
                                         excluded_classes=["O"],
                                         top_k=None):
    """Takes in the dict of state_features from a python crf-suite tagger,
    orders them in terms of how predictive they are of different classes.
    We assume we are not interested in O labels."""
    if not top_k:
        top_k = len(state_features)  # assume we want to print all of them
    ranked_state_features = [x for x in sorted(state_features, key=lambda x:x[1], reverse=True) \
         if x[0][1] not in excluded_classes][:top_k]
    for (attr, label), weight in ranked_state_features:
        print("%0.6f %-8s %s" % (weight, label, attr))

# %%
print_most_predictive_state_features(ct._tagger.info().state_features.items())
# Out:
# 5.191234 B-Year   HAS_NUM
# 4.378852 B-Genre  WORD_animated
# 4.376891 I-Year   WORD_s
# 3.280298 B-Genre  WORD_thriller
# 2.998992 B-Quote  WORD_i
# 2.986864 I-Genre  WORD_animated
# 2.968166 B-Genre  WORD_action
# 2.913375 B-Plot   WORD_a
# 2.910979 B-Opinion WORD_blockbuster
# 2.682290 B-Award  WORD_oscar
# 2.667863 B-Genre  WORD_animation
# 2.596255 B-Relationship SUF_uel
# 2.572959 B-Director WORD_disney
# 2.563763 B-Opinion WORD_masterpiece
# 2.552841 I-Genre  WORD_fiction
# 2.542230 B-Award  SUF_car
# 2.527780 B-Relationship WORD_remake
# 2.471652 B-Actor  WORD_cher
# 2.439679 B-Genre  WORD_horror
# 2.427487 I-Genre  WORD_white
# 2.413953 B-Relationship WORD_sequel
# 2.410295 I-Genre  WORD_thriller
# 2.378248 B-Genre  WORD_slasher
# 2.370675 B-Genre  WORD_comedy
# 2.337885 B-Origin WORD_adapted
# 2.304871 I-Actor  WORD_cage
# 2.276711 B-Genre  WORD_documentary
# 2.231418 B-Director SUF_xar
# 2.231418 B-Director WORD_pixar
# 2.227497 B-Genre  WORD_romance
# 2.184817 B-Genre  WORD_war
# 2.180846 B-Award  WORD_won
# 2.177721 B-Plot   WORD_an
# 2.176634 B-Genre  WORD_musical
# 2.166588 B-Genre  WORD_crime
# 2.162839 B-Character_Name WORD_dave
# 2.152172 B-Origin WORD_based
# 2.150851 I-Origin WORD_by
# 2.150546 B-Character_Name WORD_king
# 2.148149 I-Genre  WORD_war
# 2.145001 I-Award  WORD_oscars
# 2.136533 I-Genre  WORD_fi
# 2.131678 B-Character_Name SUF_eus
# 2.124746 B-Character_Name WORD_dorothy
# 2.109841 B-Actor  WORD_fred
# 2.107800 B-Award  WORD_oscars
# 2.103489 B-Award  WORD_best
# 2.102564 B-Character_Name WORD_hal
# 2.095050 B-Director WORD_dreamworks
# 2.085946 B-Genre  WORD_3
# 2.080712 B-Genre  SUF_ror
# 2.079870 B-Opinion WORD_classic
# 2.071401 B-Opinion SUF_ece
# 2.061600 I-Plot   WORD_war
# 2.042688 I-Genre  WORD_comedy
# 2.019451 B-Actor  WORD_channing
# 2.015746 B-Actor  WORD_kate
# 2.011854 B-Actor  WORD_ryan
# 2.007517 I-Director WORD_romero
# 2.005298 B-Genre  SUF_edy
# 1.989086 I-Plot   WORD_his
# 1.988584 B-Director WORD_peter
# 1.984605 B-Director WORD_hitchcock
# 1.972555 B-Genre  WORD_sports
# 1.969913 I-Award  WORD_oscar
# 1.968346 B-Award  WORD_award
# 1.950585 B-Actor  WORD_jack
# 1.947703 I-Director WORD_brothers
# 1.947473 I-Actor  WORD_jr
# 1.938340 B-Actor  SUF_tte
# 1.934493 B-Opinion SUF_ous
# 1.926447 I-Year   HAS_NUM
# 1.922685 B-Actor  SUF_eth
# 1.916267 B-Origin SUF_vel
# 1.906205 I-Actor  WORD_gosling
# 1.903663 B-Genre  WORD_american
# 1.901480 I-Relationship WORD_series
# 1.895676 I-Award  WORD_award
# 1.894274 B-Genre  WORD_cartoon
# 1.888594 B-Genre  WORD_drama
# 1.881488 B-Genre  WORD_superhero
# 1.871934 B-Director WORD_scorsese
# 1.869844 B-Soundtrack WORD_i
# 1.869450 B-Award  WORD_nominated
# 1.861323 B-Actor  WORD_arnold
# 1.854329 B-Genre  SUF_ama
# 1.850844 B-Relationship WORD_remade
# 1.844344 B-Character_Name WORD_captain
# 1.837997 B-Relationship WORD_second
# 1.828164 I-Actor  WORD_fat
# 1.825822 B-Character_Name WORD_jack
# 1.822999 I-Award  SUF_car
# 1.821699 B-Genre  WORD_gangster
# 1.820887 B-Plot   WORD_set
# 1.814783 B-Genre  WORD_family
# 1.814608 B-Actor  WORD_tom
# 1.814136 B-Relationship WORD_third
# 1.813341 B-Director WORD_wes
# 1.810041 I-Soundtrack WORD_by
# 1.803877 B-Plot   WORD_he
# 1.802096 B-Origin WORD_shakespeare
# 1.801766 I-Plot   WORD_to
# 1.799407 B-Genre  WORD_western
# 1.789402 I-Year   SUF_0
# 1.778092 I-Plot   WORD_man
# 1.772472 B-Origin WORD_shakespearean
# 1.766465 B-Relationship WORD_franchise
# 1.766203 B-Genre  WORD_fantasy
# 1.764967 B-Character_Name WORD_bane
# 1.760704 I-Plot   WORD_prison
# 1.755262 B-Genre  WORD_holiday
# 1.754661 B-Director WORD_stanley
# 1.738439 I-Actor  SUF_son
# 1.736671 B-Opinion WORD_popular
# 1.734079 B-Genre  WORD_inspirational
# 1.731222 I-Actor  WORD_pacino
# 1.729775 B-Year   WORD_mid
# 1.729466 B-Genre  WORD_adventure
# 1.729074 B-Year   SUF_2
# 1.723610 B-Opinion WORD_hit
# 1.722116 I-Actor  WORD_stallone
# 1.721844 B-Genre  SUF_ern
# 1.712215 I-Genre  WORD_d
# 1.711122 I-Genre  WORD_animation
# 1.708089 I-Genre  WORD_apocalyptic
# 1.704470 B-Director WORD_ridley
# 1.703584 I-Quote  WORD_be
# 1.700886 B-Genre  WORD_romantic
# 1.698756 B-Director WORD_oliver
# 1.697176 B-Genre  WORD_children
# 1.689372 I-Actor  SUF_itt
# 1.684548 B-Actor  SUF_a
# 1.684185 I-Genre  WORD_action
# 1.683525 B-Genre  WORD_disney
# 1.679230 I-Quote  WORD_no
# 1.676472 B-Actor  SUF_fer
# 1.660950 I-Director WORD_burton
# 1.660784 B-Genre  SUF_ime
# 1.651372 B-Genre  WORD_chick
# 1.650390 B-Genre  WORD_silent
# 1.649673 B-Director WORD_brian
# 1.647498 I-Director WORD_lee
# 1.642618 B-Genre  WORD_christmas
# 1.642090 B-Director WORD_ang
# 1.636948 B-Opinion WORD_epic
# 1.636947 I-Actor  SUF_tt
# 1.635811 I-Actor  WORD_hanks
# 1.635380 I-Actor  SUF_nes
# 1.632763 B-Actor  WORD_russell
# 1.629215 I-Plot   SUF_ain
# 1.627282 B-Director WORD_rza
# 1.626197 I-Relationship WORD_sequels
# 1.622992 B-Character_Name SUF_us
# 1.615855 I-Genre  WORD_horror
# 1.611138 I-Opinion WORD_classic
# 1.610468 I-Character_Name WORD_skywalker
# 1.609683 B-Genre  SUF_ian
# 1.607343 B-Genre  WORD_suspense
# 1.597136 I-Actor  WORD_weaver
# 1.596204 I-Relationship WORD_a
# 1.590877 B-Genre  SUF_cal
# 1.590457 B-Character_Name WORD_batman
# 1.589811 B-Year   WORD_early
# 1.587796 B-Award  SUF_ars
# 1.581834 B-Actor  WORD_christian
# 1.577758 I-Character_Name WORD_skellington
# 1.576782 I-Character_Name WORD_capone
# 1.575141 B-Actor  WORD_ed
# 1.571315 I-Character_Name WORD_bond
# 1.570956 I-Genre  WORD_adventure
# 1.569634 I-Director WORD_spielberg
# 1.569417 I-Origin WORD_novel
# 1.569323 I-Director WORD_snyder
# 1.567302 B-Director WORD_woody
# 1.567230 B-Opinion WORD_amazing
# 1.565246 B-Character_Name WORD_princess
# 1.562974 B-Director WORD_soderbergh
# 1.562123 B-Genre  SUF_oon
# 1.560960 I-Actor  SUF_and
# 1.560726 I-Director WORD_cameron
# 1.558216 B-Origin WORD_novel
# 1.557782 B-Actor  WORD_harrison
# 1.555607 B-Genre  SUF_can
# 1.555524 B-Relationship WORD_trilogy
# 1.553707 B-Director WORD_robert
# 1.551635 B-Character_Name WORD_belle
# 1.551335 I-Origin WORD_book
# 1.546482 B-Actor  SUF_ey
# 1.546442 B-Genre  SUF_day
# 1.545141 I-Actor  WORD_rock
# 1.541737 B-Actor  SUF_rt
# 1.540898 B-Origin WORD_loosely
# 1.540251 B-Opinion WORD_greatest
# 1.535659 I-Actor  WORD_stewart
# 1.533321 I-Director WORD_kubrick
# 1.533226 B-Genre  SUF_ily
# 1.532745 I-Quote  WORD_my
# 1.531796 I-Genre  SUF_ror
# 1.530511 B-Relationship WORD_series
# 1.529355 I-Award  WORD_awards
# 1.525302 I-Director WORD_moore
# 1.525036 I-Genre  SUF_edy
# 1.523495 I-Director WORD_hitchcock
# 1.523494 I-Actor  WORD_bale
# 1.523287 B-Character_Name SUF_tt
# 1.522955 B-Character_Name WORD_woody
# 1.514366 I-Plot   WORD_travel
# 1.512724 B-Year   SUF_8
# 1.512569 B-Genre  SUF_mas
# 1.511640 B-Genre  SUF_asy
# 1.510493 B-Origin SUF_sed
# 1.510389 B-Genre  WORD_baseball
# 1.508501 I-Relationship WORD_franchise
# 1.508215 B-Origin WORD_j
# 1.505779 I-Actor  SUF_ton
# 1.505075 B-Relationship WORD_last
# 1.504732 B-Character_Name WORD_norman
# 1.503773 B-Opinion WORD_timeless
# 1.498813 B-Actor  WORD_ben
# 1.497950 B-Relationship WORD_first
# 1.496629 B-Year   SUF_rly
# 1.492357 B-Relationship SUF_ond
# 1.491568 B-Genre  SUF_ion
# 1.491421 I-Relationship SUF_ies
# 1.487307 I-Character_Name WORD_brown
# 1.486590 B-Director SUF_rks
# 1.483435 I-Relationship WORD_in
# 1.483433 B-Relationship SUF_ogy
# 1.481099 I-Director WORD_anderson
# 1.480072 B-Plot   WORD_in
# 1.478367 B-Genre  WORD_scary
# 1.476761 I-Director WORD_wilder
# 1.475845 I-Actor  WORD_sandler
# 1.472199 I-Actor  WORD_cooper
# 1.471320 B-Genre  SUF_lt
# 1.469054 I-Actor  WORD_gere
# 1.469000 I-Plot   WORD_in
# 1.467912 I-Character_Name WORD_collins
# 1.467512 I-Opinion WORD_all
# 1.467367 I-Actor  WORD_tatum
# 1.465136 B-Genre  SUF_rts
# 1.464292 B-Director WORD_tarantino
# 1.464093 B-Origin WORD_book
# 1.462389 I-Genre  WORD_drama
# 1.461555 B-Origin WORD_adaptation
# 1.460878 B-Character_Name WORD_clark
# 1.457207 I-Director SUF_lan
# 1.457203 I-Director WORD_scorsese
# 1.454543 I-Genre  WORD_romance
# 1.454204 B-Award  SUF_my
# 1.454096 B-Opinion SUF_ic
# 1.451586 I-Award  WORD_picture
# 1.449789 B-Opinion SUF_us
# 1.447961 I-Genre  SUF_ama
# 1.446295 I-Director SUF_one
# 1.445031 B-Director SUF_rry
# 1.442832 B-Genre  WORD_sci
# 1.442110 I-Plot   WORD_he
# 1.441979 B-Genre  WORD_science
# 1.441979 I-Actor  WORD_cruise
# 1.441668 B-Director SUF_rgh
# 1.437753 B-Actor  SUF_eg
# 1.437073 B-Year   SUF_id
# 1.436797 B-Director SUF_red
# 1.435364 I-Actor  WORD_pitt
# 1.434535 B-Character_Name SUF_ron
# 1.432951 B-Plot   WORD_parodies
# 1.432805 I-Plot   WORD_family
# 1.432687 B-Origin WORD_retelling
# 1.431619 I-Award  SUF_ars
# 1.430634 I-Actor  SUF_tum
# 1.430090 I-Director SUF_ron
# 1.429846 I-Relationship SUF_uel
# 1.428715 B-Relationship SUF_gy
# 1.427749 I-Actor  WORD_myers
# 1.426157 I-Actor  SUF_mon
# 1.421924 I-Plot   WORD_woman
# 1.419617 B-Character_Name SUF_a
# 1.418670 B-Year   SUF_1
# 1.418358 B-Actor  WORD_peter
# 1.418243 B-Actor  WORD_julia
# 1.417631 I-Actor  SUF_is
# 1.415287 I-Actor  WORD_hepburn
# 1.411923 I-Quote  WORD_is
# 1.410598 I-Actor  WORD_kilmer
# 1.406895 B-Actor  SUF_yan
# 1.406692 B-Genre  WORD_boxing
# 1.405121 I-Plot   WORD_killer
# 1.404150 I-Award  SUF_rds
# 1.403862 B-Genre  SUF_ary
# 1.403660 I-Relationship WORD_installment
# 1.403136 I-Director WORD_bay
# 1.401178 B-Director WORD_billy
# 1.400213 B-Director WORD_george
# 1.399872 B-Character_Name WORD_rapunzel
# 1.399658 I-Director WORD_jackson
# 1.399284 B-Relationship SUF_ird
# 1.397031 I-Actor  WORD_sellers
# 1.394066 B-Year   SUF_6
# 1.392469 B-Director SUF_ese
# 1.392339 I-Director WORD_night
# 1.391679 B-Opinion SUF_lar
# 1.388968 I-Actor  WORD_beatty
# 1.387539 B-Opinion WORD_funny
# 1.387118 I-Relationship WORD_movie
# 1.386991 B-Character_Name SUF_in
# 1.386940 B-Relationship SUF_rst
# 1.384155 B-Award  WORD_academy
# 1.383884 B-Actor  WORD_nick
# 1.383524 B-Award  SUF_ar
# 1.383119 B-Genre  WORD_french
# 1.381358 B-Director WORD_alfred
# 1.380248 B-Soundtrack WORD_music
# 1.380204 B-Character_Name WORD_mad
# 1.378557 I-Relationship SUF_vie
# 1.378034 B-Actor  WORD_ray
# 1.375421 I-Character_Name WORD_wallace
# 1.375377 B-Actor  WORD_val
# 1.375196 I-Plot   WORD_by
# 1.373800 B-Director SUF_tin
# 1.372344 I-Actor  SUF_sen
# 1.372265 B-Actor  WORD_sean
# 1.370735 B-Relationship WORD_spawned
# 1.370173 I-Actor  WORD_damon
# 1.366162 B-Character_Name WORD_scarecrow
# 1.364184 I-Character_Name WORD_krueger
# 1.363228 I-Character_Name WORD_ness
# 1.363221 B-Award  SUF_est
# 1.360702 B-Genre  SUF_rn
# 1.360561 B-Origin WORD_charles
# 1.359264 B-Genre  WORD_mystery
# 1.356954 I-Plot   WORD_a
# 1.356119 B-Year   SUF_9
# 1.355068 B-Genre  WORD_japanese
# 1.354124 I-Actor  WORD_kelly
# 1.353936 B-Relationship SUF_ise
# 1.353868 I-Director WORD_carpenter
# 1.352892 B-Year   SUF_7
# 1.352595 I-Character_Name WORD_connor
# 1.351561 B-Genre  SUF_ren
# 1.349753 B-Plot   WORD_killer
# 1.349728 B-Character_Name WORD_darth
# 1.347345 I-Relationship WORD_sequel
# 1.347038 I-Director WORD_smith
# 1.346953 B-Director WORD_spielberg
# 1.346672 B-Genre  WORD_indie
# 1.345001 B-Genre  SUF_ted
# 1.344803 B-Genre  SUF_nce
# 1.343538 B-Character_Name SUF_to
# 1.343030 B-Opinion WORD_intense
# 1.342355 B-Director SUF_ike
# 1.338834 I-Genre  SUF_ion
# 1.337116 I-Actor  SUF_nks
# 1.335849 I-Character_Name WORD_zuckerberg
# 1.335839 I-Genre  WORD_musical
# 1.335081 B-Genre  SUF_ult
# 1.333363 I-Origin SUF_ame
# 1.332925 B-Character_Name SUF_odo
# 1.332925 B-Character_Name WORD_frodo
# 1.332450 B-Character_Name WORD_al
# 1.328514 I-Origin WORD_play
# 1.327997 B-Relationship WORD_reboot
# 1.326683 B-Genre  SUF_ma
# 1.325291 B-Genre  SUF_ci
# 1.324006 B-Actor  SUF_las
# 1.323304 I-Plot   WORD_men
# 1.322394 B-Origin SUF_ion
# 1.320602 B-Actor  WORD_reese
# 1.320370 B-Genre  SUF_ic
# 1.320264 B-Genre  WORD_fairytale
# 1.318341 B-Character_Name WORD_aldous
# 1.315964 B-Character_Name SUF_ie
# 1.312770 B-Plot   SUF_wo
# 1.312770 B-Plot   WORD_two
# 1.311715 B-Character_Name WORD_george
# 1.309441 B-Character_Name SUF_uzz
# 1.309441 B-Character_Name WORD_buzz
# 1.307396 B-Opinion SUF_t
# 1.306800 B-Director WORD_steven
# 1.306503 B-Actor  WORD_kristen
# 1.306093 I-Actor  SUF_pp
# 1.304963 B-Actor  WORD_jason
# 1.303970 B-Genre  WORD_childrens
# 1.303857 I-Director WORD_nolan
# 1.303613 B-Character_Name SUF_cky
# 1.301767 I-Character_Name WORD_golightly
# 1.298337 B-Genre  SUF_dy
# 1.298331 I-Plot   WORD_creature
# 1.297130 I-Actor  WORD_mcdormand
# 1.297105 I-Genre  WORD_noir
# 1.296752 B-Actor  SUF_nu
# 1.296752 B-Actor  SUF_anu
# 1.296752 B-Actor  WORD_keanu
# 1.296371 B-Actor  WORD_richard
# 1.296249 I-Actor  SUF_lis
# 1.293482 B-Actor  SUF_ph
# 1.293017 I-Actor  WORD_toole
# 1.292630 B-Relationship SUF_nal
# 1.292167 B-Actor  WORD_bogart
# 1.290386 B-Origin SUF_are
# 1.289347 B-Director SUF_ley
# 1.288675 B-Genre  WORD_computer
# 1.288323 B-Origin WORD_adaption
# 1.288018 B-Award  SUF_emy
# 1.287838 I-Actor  WORD_c
# 1.287830 I-Origin SUF_vel
# 1.287042 B-Opinion WORD_iconic
# 1.286137 I-Director WORD_scott
# 1.284213 I-Actor  WORD_astaire
# 1.283448 B-Character_Name SUF_mba
# 1.282709 B-Director WORD_rob
# 1.282625 I-Actor  WORD_hoffman
# 1.282401 I-Plot   SUF_hat
# 1.281848 B-Character_Name SUF_rry
# 1.281696 B-Actor  WORD_holly
# 1.281326 I-Actor  WORD_bridges
# 1.281173 B-Director SUF_ino
# 1.281058 B-Origin WORD_dr
# 1.280706 B-Genre  WORD_biopic
# 1.280451 I-Origin WORD_story
# 1.279714 B-Actor  SUF_yn
# 1.279683 B-Actor  WORD_james
# 1.277893 B-Relationship SUF_oot
# 1.277534 I-Quote  WORD_it
# 1.276080 I-Actor  SUF_ire
# 1.275927 I-Plot   WORD_an
# 1.275358 B-Director WORD_ron
# 1.275241 B-Character_Name WORD_mr
# 1.273677 B-Director WORD_mel
# 1.273499 B-Actor  SUF_lle
# 1.272980 B-Actor  WORD_al
# 1.271521 I-Opinion WORD_of
# 1.270590 B-Genre  WORD_supernatural
# 1.270309 B-Director WORD_frank
# 1.268514 I-Genre  WORD_documentary
# 1.265944 I-Actor  WORD_whitaker
# 1.265594 B-Opinion WORD_charming
# 1.265555 I-Plot   SUF_tel
# 1.264798 B-Director SUF_im
# 1.262551 I-Character_Name WORD_myers
# 1.258905 B-Actor  WORD_clint
# 1.257387 I-Character_Name WORD_mouse
# 1.256516 B-Director WORD_tyler
# 1.255989 B-Opinion WORD_awesome
# 1.255651 I-Opinion SUF_ver
# 1.255240 I-Character_Name WORD_cogburn
# 1.255157 B-Actor  WORD_samuel
# 1.255136 I-Director WORD_altman
# 1.255103 I-Actor  WORD_broderick
# 1.254161 B-Actor  WORD_jennifer
# 1.254159 B-Relationship WORD_finale
# 1.253834 B-Relationship SUF_st
# 1.253204 B-Actor  WORD_leonardo
# 1.252123 B-Opinion WORD_controversial
# 1.252019 B-Relationship WORD_retelling
# 1.248953 B-Actor  WORD_cary
# 1.247975 B-Plot   WORD_cars
# 1.247393 B-Director WORD_quentin
# 1.246369 I-Plot   WORD_facebook
# 1.243496 B-Genre  WORD_funny
# 1.242066 I-Actor  SUF_aal
# 1.239982 B-Plot   SUF_zes
# 1.239899 B-Relationship SUF_ely
# 1.239200 B-Genre  WORD_thrilling
# 1.236965 B-Plot   WORD_woman
# 1.235615 B-Character_Name WORD_sam
# 1.235215 B-Director SUF_ney
# 1.233459 I-Origin WORD_shakespeare
# 1.233271 B-Opinion SUF_sic
# 1.232351 B-Character_Name WORD_hades
# 1.228860 B-Character_Name WORD_roger
# 1.228288 B-Director WORD_j
# 1.227097 I-Actor  WORD_hunter
# 1.226997 I-Actor  WORD_willis
# 1.225006 B-Character_Name WORD_toto
# 1.224422 B-Opinion WORD_favorite
# 1.222488 I-Opinion WORD_ever
# 1.220561 B-Character_Name WORD_freddy
# 1.219437 B-Character_Name WORD_hannibal
# 1.219301 B-Year   SUF_ate
# 1.217301 I-Genre  SUF_ler
# 1.216494 B-Director SUF_oen
# 1.216494 B-Director WORD_coen
# 1.216377 I-Character_Name SUF_ond
# 1.215757 I-Actor  WORD_grant
# 1.215378 B-Opinion SUF_ful
# 1.214170 B-Actor  SUF_lie
# 1.212491 I-Actor  SUF_ham
# 1.211745 I-Actor  WORD_streep
# 1.211191 I-Plot   WORD_paris
# 1.209767 B-Actor  WORD_johnny
# 1.209173 B-Director WORD_roman
# 1.206010 B-Year   SUF_10
# 1.206010 B-Year   SUF_010
# 1.206010 B-Year   WORD_2010
# 1.205035 B-Genre  SUF_nch
# 1.204672 I-Character_Name WORD_jones
# 1.203730 I-Award  SUF_tor
# 1.202712 B-Actor  WORD_tim
# 1.202659 I-Plot   WORD_shark
# 1.201260 B-Genre  SUF_ish
# 1.199872 I-Director SUF_ore
# 1.199293 B-Opinion SUF_it
# 1.198538 B-Opinion WORD_considered
# 1.198290 I-Actor  SUF_eld
# 1.197923 B-Actor  WORD_walter
# 1.196945 I-Plot   WORD_son
# 1.196461 B-Character_Name WORD_sauron
# 1.194974 B-Actor  WORD_steve
# 1.194626 B-Character_Name SUF_u
# 1.194483 I-Origin WORD_s
# 1.194356 I-Actor  WORD_freeman
# 1.193986 B-Relationship WORD_adaptation
# 1.193200 B-Actor  SUF_gan
# 1.192567 B-Director WORD_tim
# 1.191801 I-Plot   WORD_crossed
# 1.191406 I-Director WORD_abrams
# 1.189378 B-Actor  WORD_amanda
# 1.189346 B-Opinion WORD_great
# 1.188223 I-Actor  WORD_black
# 1.187741 B-Actor  WORD_emily
# 1.187496 B-Plot   WORD_intertwined
# 1.186344 I-Actor  SUF_epp
# 1.186344 I-Actor  WORD_depp
# 1.185979 B-Director WORD_david
# 1.185714 I-Actor  WORD_reeves
# 1.185175 B-Soundtrack SUF_una
# 1.185079 B-Genre  WORD_mockumentary
# 1.184373 B-Genre  SUF_al
# 1.182906 I-Actor  WORD_redford
# 1.181758 B-Award  HAS_NUM
# 1.180751 B-Quote  SUF_ere
# 1.180573 I-Plot   SUF_ion
# 1.179710 B-Director SUF_rge
# 1.179685 I-Origin WORD_novels
# 1.179192 B-Year   SUF_5
# 1.177905 I-Relationship WORD_trilogy
# 1.177498 B-Actor  SUF_eve
# 1.177368 B-Actor  SUF_rey
# 1.177066 B-Award  SUF_rs
# 1.176791 I-Actor  WORD_crystal
# 1.175400 B-Actor  WORD_chris
# 1.172299 I-Director WORD_eastwood
# 1.171407 B-Year   WORD_2000
# 1.170596 B-Actor  SUF_rew
# 1.170503 I-Plot   WORD_apprentice
# 1.170471 I-Actor  SUF_man
# 1.170031 I-Plot   WORD_happens
# 1.169924 B-Genre  WORD_parody
# 1.169229 I-Genre  SUF_ma
# 1.168219 I-Actor  WORD_newman
# 1.167827 I-Character_Name SUF_ley
# 1.167106 B-Genre  WORD_classic
# 1.166543 I-Award  SUF_ure
# 1.166507 I-Year   WORD_ago
# 1.165367 B-Actor  WORD_meg
# 1.164894 B-Genre  WORD_tearjerker
# 1.164219 B-Director SUF_ey
# 1.163679 B-Opinion SUF_y
# 1.163129 I-Quote  WORD_me
# 1.162843 I-Plot   WORD_wrong
# 1.162378 I-Origin WORD_dickens
# 1.161804 B-Genre  SUF_sy
# 1.159926 B-Genre  SUF_c
# 1.159849 I-Genre  SUF_ero
# 1.159486 I-Genre  WORD_crime
# 1.158725 B-Actor  SUF_her
# 1.156289 I-Actor  WORD_hopkins
# 1.155599 B-Character_Name SUF_lle
# 1.155520 I-Actor  WORD_lively
# 1.155409 I-Actor  SUF_ell
# 1.154398 B-Actor  SUF_eff
# 1.154398 B-Actor  WORD_jeff
# 1.153132 B-Character_Name SUF_bas
# 1.153132 B-Character_Name WORD_barnabas
# 1.151862 I-Actor  WORD_gable
# 1.151089 B-Character_Name WORD_jason
# 1.150281 B-Character_Name WORD_rumpelstiltskin
# 1.150192 I-Plot   WORD_invasion
# 1.150183 B-Relationship SUF_el
# 1.149227 I-Origin SUF_lay
# 1.149022 I-Genre  SUF_ern
# 1.146632 B-Actor  SUF_ie
# 1.146193 B-Actor  SUF_ard
# 1.145989 I-Actor  WORD_schwarzenegger
# 1.145445 B-Plot   WORD_british
# 1.144439 I-Actor  WORD_witherspoon
# 1.143459 B-Actor  WORD_gene
# 1.142011 B-Actor  WORD_christopher
# 1.141348 B-Relationship SUF_ake
# 1.140796 I-Character_Name SUF_tly
# 1.139417 B-Genre  WORD_spoof
# 1.138660 B-Genre  SUF_ure
# 1.138192 B-Year   SUF_3
# 1.138072 B-Plot   WORD_centered
# 1.138016 B-Director SUF_za
# 1.136894 B-Year   WORD_late
# 1.136707 I-Plot   WORD_mob
# 1.136367 B-Origin SUF_ade
# 1.135840 I-Actor  WORD_niro
# 1.135031 I-Relationship WORD_adaptation
# 1.134368 I-Actor  SUF_ers
# 1.134191 I-Genre  WORD_western
# 1.133953 B-Genre  SUF_oof
# 1.133428 I-Plot   WORD_holocaust
# 1.132896 B-Director SUF_int
# 1.132343 B-Opinion WORD_modern
# 1.132155 B-Opinion WORD_brilliant
# 1.131684 B-Genre  SUF_of
# 1.131535 I-Plot   WORD_spell
# 1.130762 B-Actor  WORD_macaulay
# 1.130578 B-Plot   WORD_man
# 1.129993 I-Plot   WORD_of
# 1.128519 B-Plot   WORD_monster
# 1.128182 I-Year   SUF_go
# 1.128104 I-Actor  WORD_winslet
# 1.127517 I-Genre  SUF_rts
# 1.127319 I-Actor  SUF_ray
# 1.126116 B-Character_Name SUF_ave
# 1.126068 I-Plot   SUF_ity
# 1.125246 B-Character_Name WORD_gandalf
# 1.125186 B-Actor  SUF_ric
# 1.124940 I-Actor  WORD_foster
# 1.124080 I-Actor  WORD_culkin
# 1.122753 B-Relationship SUF_de
# 1.121768 B-Genre  SUF_ent
# 1.120321 B-Actor  SUF_mon
# 1.119822 B-Character_Name SUF_row
# 1.119212 B-Genre  SUF_pic
# 1.118747 B-Director WORD_m
# 1.118214 I-Actor  WORD_connery
# 1.117676 I-Character_Name SUF_nor
# 1.117636 B-Plot   SUF_he
# 1.117302 B-Year   SUF_4
# 1.116846 B-Director SUF_vid
# 1.116749 I-Director WORD_reiner
# 1.116705 B-Opinion SUF_c
# 1.116263 I-Director WORD_j
# 1.116063 I-Plot   WORD_plane
# 1.115021 B-Genre  SUF_die
# 1.114322 B-Character_Name SUF_bal
# 1.114209 I-Actor  SUF_nn
# 1.113843 I-Character_Name SUF_olo
# 1.113776 B-Actor  WORD_gregory
# 1.113394 I-Director WORD_lucas
# 1.113367 I-Opinion WORD_an
# 1.112210 I-Character_Name SUF_bs
# 1.112210 I-Director SUF_cas
# 1.112098 B-Actor  WORD_sigourney
# 1.111510 B-Character_Name WORD_professor
# 1.111091 B-Quote  SUF_re
# 1.111091 I-Actor  WORD_helms
# 1.109503 B-Genre  SUF_ero
# 1.109038 B-Character_Name SUF_am
# 1.108841 I-Director WORD_renoir
# 1.108127 B-Director SUF_no
# 1.107802 I-Genre  WORD_superhero
# 1.107554 I-Origin WORD_character
# 1.105431 B-Plot   WORD_unemployed
# 1.104923 B-Actor  SUF_tin
# 1.104835 B-Character_Name WORD_snoopy
# 1.104484 B-Genre  WORD_italian
# 1.103305 I-Actor  WORD_roberts
# 1.103247 I-Origin WORD_king
# 1.103200 B-Origin WORD_inspired
# 1.102870 B-Character_Name SUF_zz
# 1.102716 B-Opinion WORD_humorous
# 1.102334 I-Character_Name WORD_daddy
# 1.101815 B-Origin SUF_ean
# 1.100834 B-Relationship SUF_ade
# 1.099724 I-Actor  WORD_curtis
# 1.099035 B-Director WORD_walt
# 1.097078 B-Director SUF_alt
# 1.096625 B-Genre  WORD_dramatic
# 1.096390 B-Actor  SUF_iel
# 1.096186 B-Director WORD_orson
# 1.095947 I-Actor  SUF_ms
# 1.095934 B-Character_Name WORD_jay
# 1.095521 I-Genre  SUF_oir
# 1.094234 I-Actor  WORD_osment
# 1.093950 I-Actor  SUF_las
# 1.093234 B-Genre  WORD_post
# 1.092656 I-Actor  WORD_blunt
# 1.090279 B-Award  SUF_ted
# 1.090219 B-Actor  WORD_liam
# 1.089641 B-Character_Name SUF_sor
# 1.089226 B-Director WORD_michael
# 1.088385 I-Actor  WORD_leigh
# 1.087662 B-Actor  WORD_chevy
# 1.087456 I-Actor  SUF_iro
# 1.087435 I-Plot   WORD_struggles
# 1.086245 I-Genre  WORD_children
# 1.086073 B-Actor  SUF_evy
# 1.085742 I-Actor  WORD_brody
# 1.084903 B-Character_Name WORD_dr
# 1.083846 B-Actor  SUF_old
# 1.083767 B-Actor  WORD_taylor
# 1.083663 B-Director SUF_ock
# 1.083042 I-Director WORD_marshall
# 1.082972 B-Plot   WORD_his
# 1.082046 B-Opinion SUF_eat
# 1.081908 I-Genre  SUF_ts
# 1.081806 B-Actor  WORD_damon
# 1.081108 B-Plot   WORD_troubled
# 1.081076 I-Genre  WORD_kong
# 1.080653 I-Director WORD_howard
# 1.080096 I-Actor  SUF_vin
# 1.079342 I-Opinion WORD_known
# 1.078804 I-Director WORD_welles
# 1.078747 B-Relationship WORD_final
# 1.078229 I-Actor  WORD_gibson
# 1.077661 B-Character_Name SUF_oto
# 1.076959 B-Opinion WORD_master
# 1.075361 B-Character_Name SUF_el
# 1.074599 I-Year   WORD_90
# 1.074446 B-Director SUF_ki
# 1.073825 B-Director SUF_g
# 1.073299 I-Relationship WORD_first
# 1.072669 B-Actor  SUF_ne
# 1.072432 I-Origin WORD_musical
# 1.071855 B-Origin SUF_ely
# 1.071132 B-Actor  WORD_mike
# 1.071083 I-Relationship SUF_ion
# 1.070829 B-Opinion SUF_sly
# 1.070358 B-Relationship WORD_latest
# 1.070139 B-Actor  SUF_aul
# 1.070139 B-Actor  WORD_paul
# 1.069767 B-Plot   WORD_four
# 1.069217 I-Director SUF_ino
# 1.068534 B-Character_Name WORD_joan
# 1.067780 I-Actor  WORD_decker
# 1.067034 B-Actor  SUF_lyn
# 1.066999 B-Character_Name SUF_ba
# 1.066162 I-Genre  SUF_dy
# 1.066087 I-Actor  SUF_rry
# 1.065708 I-Origin WORD_sparks
# 1.065295 I-Opinion WORD_hit
# 1.065132 I-Actor  WORD_sheen
# 1.064393 I-Genre  WORD_movie
# 1.064179 B-Plot   WORD_2
# 1.064134 B-Genre  WORD_satire
# 1.063865 B-Character_Name WORD_lord
# 1.062775 I-Plot   WORD_day
# 1.062666 B-Actor  SUF_ris
# 1.062364 B-Character_Name SUF_lo
# 1.062303 I-Genre  SUF_vie
# 1.061693 I-Actor  SUF_tis
# 1.061663 B-Actor  WORD_kevin
# 1.061051 I-Genre  WORD_age
# 1.060966 B-Director WORD_seth
# 1.060632 B-Plot   WORD_aliens
# 1.060505 I-Character_Name SUF_ker
# 1.059829 I-Genre  WORD_story
# 1.059707 B-Actor  SUF_wan
# 1.059570 I-Actor  WORD_timberlake
# 1.059103 B-Actor  WORD_kathleen
# 1.057282 I-Actor  WORD_carell
# 1.056364 B-Character_Name WORD_jigsaw
# 1.055324 B-Relationship WORD_loosely
# 1.053602 I-Actor  WORD_murray
# 1.053582 I-Opinion WORD_famous
# 1.053058 B-Director SUF_ks
# 1.052398 B-Year   SUF_012
# 1.052398 B-Year   WORD_2012
# 1.052290 I-Genre  SUF_can
# 1.052273 B-Genre  SUF_all
# 1.051942 B-Director WORD_christopher
# 1.051415 B-Character_Name SUF_do
# 1.050391 B-Character_Name WORD_luke
# 1.049861 B-Origin WORD_nicholas
# 1.049068 I-Character_Name SUF_lo
# 1.048856 I-Actor  SUF_rt
# 1.048133 B-Actor  WORD_drew
# 1.047265 B-Opinion SUF_pic
# 1.046619 I-Genre  WORD_travel
# 1.045700 I-Plot   WORD_agent
# 1.045443 B-Character_Name SUF_ley
# 1.044722 I-Origin WORD_k
# 1.044187 I-Actor  WORD_hathaway
# 1.043732 I-Actor  WORD_voight
# 1.043551 B-Character_Name SUF_oan
# 1.043357 I-Director SUF_ki
# 1.043356 B-Actor  SUF_vin
# 1.043219 B-Character_Name SUF_opy
# 1.042829 I-Plot   SUF_ful
# 1.042784 I-Actor  WORD_cohen
# 1.042492 B-Genre  WORD_space
# 1.041903 I-Genre  SUF_ren
# 1.041501 I-Relationship WORD_by
# 1.040980 B-Director SUF_ke
# 1.040763 I-Opinion WORD_popular
# 1.040343 B-Actor  SUF_do
# 1.040197 B-Plot   WORD_three
# 1.040117 I-Actor  SUF_lta
# 1.040117 I-Actor  WORD_travolta
# 1.039899 B-Actor  WORD_jake
# 1.039897 I-Actor  WORD_wahlberg
# 1.039726 B-Director WORD_universal
# 1.039605 B-Actor  WORD_kathy
# 1.039284 B-Character_Name WORD_ripley
# 1.039162 B-Director SUF_sal
# 1.038911 I-Plot   WORD_crime
# 1.038528 B-Actor  WORD_bing
# 1.038523 B-Director SUF_tt
# 1.038346 B-Plot   WORD_they
# 1.038022 B-Character_Name SUF_iot
# 1.037041 B-Director SUF_los
# 1.036993 I-Director WORD_craven
# 1.036881 I-Actor  SUF_let
# 1.036526 I-Plot   SUF_nto
# 1.036163 I-Origin WORD_a
# 1.035933 I-Opinion SUF_ed
# 1.035589 I-Award  WORD_best
# 1.035412 I-Character_Name SUF_ane
# 1.035103 I-Plot   WORD_into
# 1.034951 B-Actor  WORD_jonah
# 1.034642 I-Director SUF_is
# 1.034490 I-Plot   WORD_game
# 1.034412 B-Character_Name WORD_blanche
# 1.034134 I-Opinion WORD_acclaimed
# 1.033958 I-Relationship SUF_ogy
# 1.033508 B-Genre  WORD_futuristic
# 1.032062 B-Genre  WORD_fairy
# 1.031986 I-Origin SUF_ies
# 1.031060 B-Genre  SUF_iry
# 1.030795 B-Opinion WORD_heart
# 1.030414 B-Director SUF_ody
# 1.030146 I-Actor  WORD_ledger
# 1.030058 I-Actor  WORD_eve
# 1.029967 B-Opinion WORD_hilarious
# 1.028894 I-Plot   WORD_singer
# 1.027027 I-Origin WORD_television
# 1.027013 I-Plot   WORD_baseball
# 1.026894 I-Genre  SUF_ro
# 1.026242 B-Character_Name SUF_che
# 1.026106 B-Genre  SUF_ire
# 1.025424 B-Actor  SUF_in
# 1.023646 B-Character_Name SUF_nic
# 1.023392 B-Relationship SUF_ion
# 1.023012 B-Genre  WORD_live
# 1.022237 B-Soundtrack WORD_song
# 1.020491 B-Origin SUF_ook
# 1.020263 I-Genre  WORD_mystery
# 1.019169 B-Actor  SUF_on
# 1.018702 I-Actor  SUF_um
# 1.018611 B-Character_Name SUF_uke
# 1.018259 I-Plot   WORD_with
# 1.017694 I-Plot   WORD_her
# 1.017565 I-Director SUF_ee
# 1.017464 B-Character_Name WORD_chuckie
# 1.016733 I-Character_Name SUF_eus
# 1.016699 I-Actor  SUF_ns
# 1.016663 I-Director SUF_ven
# 1.016614 I-Plot   WORD_tycoon
# 1.016362 I-Plot   WORD_boy
# 1.016217 B-Character_Name WORD_perseus
# 1.016118 I-Plot   WORD_they
# 1.015770 I-Actor  WORD_cusack
# 1.015744 I-Actor  WORD_allen
# 1.014593 I-Actor  WORD_sarandon
# 1.014337 B-Relationship WORD_spin
# 1.013127 I-Character_Name WORD_kent
# 1.013064 B-Plot   WORD_about
# 1.012852 B-Origin WORD_e
# 1.012531 I-Plot   WORD_sword
# 1.011883 I-Actor  WORD_nicholson
# 1.011813 B-Actor  SUF_ile
# 1.011477 B-Award  SUF_ard
# 1.011240 B-Actor  WORD_daniel
# 1.009959 B-Character_Name SUF_r
# 1.009952 B-Opinion SUF_nse
# 1.009908 B-Relationship SUF_pin
# 1.009510 I-Character_Name WORD_lion
# 1.009408 I-Actor  WORD_peck
# 1.008066 I-Actor  SUF_rio
# 1.007754 I-Actor  WORD_jones
# 1.007351 I-Character_Name SUF_an
# 1.005827 I-Character_Name SUF_ddy
# 1.005668 B-Character_Name SUF_lip
# 1.005459 B-Character_Name WORD_edward
# 1.003163 I-Actor  SUF_sby
# 1.003163 I-Actor  WORD_crosby
# 1.002993 B-Genre  WORD_black
# 1.002133 I-Origin SUF_ale
# 1.001873 I-Director SUF_ann
# 1.001811 B-Genre  SUF_ro
# 1.001780 I-Director SUF_oen
# 1.001780 I-Director WORD_coen
# 1.001618 B-Year   SUF_te
# 1.001566 B-Director SUF_od
# 1.000948 I-Plot   WORD_police
# 1.000850 I-Character_Name WORD_mcclane
# 1.000650 I-Character_Name WORD_parker
# 1.000034 B-Opinion WORD_famous
# 0.999683 I-Relationship SUF_ilm
# 0.999683 I-Relationship WORD_film
# 0.999243 B-Award  SUF_st
# 0.998800 I-Plot   WORD_sister
# 0.998701 I-Opinion WORD_to
# 0.998482 B-Genre  WORD_hong
# 0.997663 I-Actor  WORD_taylor
# 0.997610 B-Plot   WORD_she
# 0.997561 B-Character_Name SUF_bby
# 0.997273 B-Character_Name WORD_mickey
# 0.996857 I-Character_Name WORD_sparrow
# 0.996758 I-Relationship SUF_ise
# 0.996613 I-Director WORD_coppola
# 0.996118 B-Director SUF_rmo
# 0.996118 B-Director WORD_guillermo
# 0.995230 B-Genre  WORD_dystopian
# 0.995100 I-Plot   WORD_character
# 0.994969 B-Director SUF_ael
# 0.994618 B-Plot   SUF_ho
# 0.994321 I-Director WORD_gilliam
# 0.993980 I-Plot   WORD_friends
# 0.993931 I-Origin WORD_seuss
# 0.993797 I-Character_Name WORD_bates
# 0.993786 I-Opinion WORD_and
# 0.993754 B-Director SUF_erg
# 0.993562 I-Director SUF_ola
# 0.993325 B-Opinion WORD_cult
# 0.993089 I-Plot   SUF_rom
# 0.992341 I-Opinion SUF_zed
# 0.992327 I-Soundtrack SUF_ata
# 0.991778 B-Origin WORD_stephen
# 0.991566 I-Character_Name SUF_ken
# 0.991223 B-Actor  SUF_urt
# 0.991157 I-Actor  WORD_gyllenhaal
# 0.990482 I-Plot   WORD_era
# 0.990330 I-Plot   WORD_con
# 0.990325 B-Relationship SUF_ned
# 0.989987 B-Character_Name WORD_rose
# 0.989676 I-Opinion WORD_favorite
# 0.989084 I-Plot   SUF_hip
# 0.987973 B-Actor  WORD_alan
# 0.987350 I-Genre  SUF_vel
# 0.987335 I-Quote  WORD_as
# 0.986887 B-Character_Name WORD_tyler
# 0.986141 I-Character_Name WORD_hatter
# 0.984605 I-Origin WORD_books
# 0.984433 I-Actor  SUF_io
# 0.984247 B-Actor  WORD_judy
# 0.984232 B-Origin SUF_ok
# 0.984108 I-Director WORD_hammerstein
# 0.984020 I-Quote  WORD_talking
# 0.983796 I-Relationship WORD_was
# 0.983594 I-Plot   SUF_vil
# 0.983337 I-Actor  WORD_danes
# 0.982996 B-Character_Name WORD_rachel
# 0.982603 B-Relationship SUF_ies
# 0.982461 I-Director SUF_ott
# 0.982060 B-Opinion WORD_most
# 0.981391 I-Character_Name WORD_snow
# 0.980966 I-Actor  WORD_fassbender
# 0.980965 I-Genre  SUF_ted
# 0.980901 B-Actor  WORD_brad
# 0.980860 I-Actor  WORD_efron
# 0.980422 I-Opinion WORD_great
# 0.980157 B-Actor  SUF_rad
# 0.980126 B-Director WORD_spike
# 0.979223 B-Director WORD_james
# 0.979107 I-Plot   WORD_park
# 0.978612 B-Director SUF_mo
# 0.978524 B-Genre  WORD_biographical
# 0.978186 I-Actor  WORD_lawrence
# 0.978168 I-Actor  SUF_gor
# 0.978119 B-Actor  WORD_denzel
# 0.977417 B-Director SUF_awa
# 0.977417 B-Director WORD_kurosawa
# 0.977138 I-Actor  WORD_eastwood
# 0.976908 I-Genre  WORD_slasher
# 0.976733 B-Genre  SUF_ale
# 0.976509 I-Actor  WORD_fonda
# 0.976351 B-Character_Name WORD_charles
# 0.975934 I-Actor  WORD_li
# 0.975605 B-Genre  SUF_ese
# 0.975234 I-Director SUF_ams
# 0.975139 I-Plot   WORD_criminal
# 0.974776 I-Director SUF_ck
# 0.974547 I-Plot   WORD_future
# 0.974447 B-Actor  SUF_mes
# 0.974173 B-Actor  SUF_ill
# 0.972897 B-Character_Name WORD_bella
# 0.972717 I-Plot   WORD_lizard
# 0.972448 I-Actor  WORD_douglas
# 0.971887 B-Director SUF_wa
# 0.971488 I-Plot   WORD_gone
# 0.971120 I-Relationship SUF_els
# 0.970915 I-Director WORD_zemeckis
# 0.970821 B-Actor  WORD_andre
# 0.970782 I-Plot   WORD_hero
# 0.969611 B-Character_Name WORD_simba
# 0.969322 B-Character_Name SUF_ad
# 0.969130 I-Genre  SUF_cal
# 0.968837 I-Relationship SUF_gy
# 0.968774 B-Actor  SUF_an
# 0.968125 B-Actor  WORD_eric
# 0.968118 I-Director SUF_son
# 0.967724 B-Opinion WORD_legendary
# 0.967639 B-Character_Name SUF_hie
# 0.967533 B-Director SUF_i
# 0.967520 I-Character_Name WORD_bailey
# 0.967498 I-Plot   WORD_kill
# 0.967295 B-Actor  WORD_hugh
# 0.966504 B-Actor  WORD_janet
# 0.965654 B-Actor  SUF_m
# 0.964639 I-Director SUF_au
# 0.963593 B-Actor  WORD_alice
# 0.963201 I-Actor  WORD_dreyfuss
# 0.962282 B-Genre  SUF_ney
# 0.961589 B-Origin SUF_wis
# 0.961589 B-Origin WORD_lewis
# 0.961251 B-Actor  SUF_my
# 0.961057 I-Actor  WORD_dicaprio
# 0.959963 I-Plot   WORD_wizard
# 0.958782 I-Plot   WORD_earth
# 0.958143 B-Genre  WORD_love
# 0.957146 I-Relationship SUF_se
# 0.956848 B-Opinion SUF_ul
# 0.956625 I-Quote  WORD_ki
# 0.956319 I-Character_Name WORD_lamotta
# 0.955132 I-Actor  SUF_kis
# 0.955113 I-Actor  WORD_barrymore
# 0.954713 I-Plot   WORD_fighting
# 0.954643 B-Character_Name SUF_thy
# 0.953702 I-Soundtrack WORD_music
# 0.953292 B-Character_Name WORD_holly
# 0.953107 B-Actor  WORD_heath
# 0.952671 B-Director SUF_cis
# 0.952671 B-Director WORD_francis
# 0.950955 B-Actor  WORD_chow
# 0.950945 B-Actor  SUF_lor
# 0.950764 B-Actor  SUF_ff
# 0.950548 B-Plot   WORD_travel
# 0.950462 B-Genre  SUF_ler
# 0.950382 B-Actor  WORD_meatloaf
# 0.949544 I-Origin WORD_cartoon
# 0.949075 B-Year   WORD_nineties
# 0.947643 B-Origin WORD_written
# 0.946879 B-Actor  SUF_oaf
# 0.946867 I-Character_Name SUF_ett
# 0.946417 B-Director SUF_el
# 0.945262 I-Relationship WORD_up
# 0.944958 I-Character_Name SUF_oge
# 0.944958 I-Character_Name WORD_scrooge
# 0.944834 B-Actor  SUF_io
# 0.944274 I-Actor  WORD_carrey
# 0.944271 B-Actor  SUF_son
# 0.944220 B-Opinion WORD_very
# 0.944135 B-Actor  SUF_udy
# 0.944040 B-Genre  WORD_violent
# 0.943557 I-Actor  SUF_fer
# 0.943011 B-Plot   SUF_ing
# 0.942822 I-Plot   WORD_who
# 0.942557 B-Plot   WORD_go
# 0.942404 I-Character_Name SUF_fly
# 0.940702 B-Actor  SUF_int
# 0.940694 B-Relationship WORD_continuation
# 0.940466 B-Director SUF_ven
# 0.939163 I-Plot   WORD_ballet
# 0.939052 B-Relationship WORD_prequel
# 0.938575 B-Origin SUF_las
# 0.938139 B-Actor  SUF_dre
# 0.937696 B-Opinion SUF_ing
# 0.937673 I-Plot   WORD_lives
# 0.937432 I-Relationship WORD_filming
# 0.937327 I-Plot   WORD_women
# 0.937019 I-Relationship WORD_version
# 0.937014 B-Director WORD_gary
# 0.936928 I-Character_Name SUF_eri
# 0.936167 I-Year   WORD_years
# 0.936027 B-Actor  WORD_mandy
# 0.935754 I-Actor  SUF_ey
# 0.935603 I-Actor  SUF_lds
# 0.935257 B-Plot   SUF_hat
# 0.934208 I-Plot   WORD_food
# 0.934176 I-Actor  WORD_dunaway
# 0.934123 B-Plot   WORD_battle
# 0.933508 B-Character_Name WORD_edmund
# 0.933214 B-Character_Name WORD_tony
# 0.933106 B-Plot   WORD_ex
# 0.932763 B-Opinion WORD_smash
# 0.932668 B-Opinion SUF_ble
# 0.932581 B-Director SUF_in
# 0.932092 B-Opinion WORD_often
# 0.931593 B-Relationship SUF_fth
# 0.931593 B-Relationship WORD_fifth
# 0.931476 B-Actor  SUF_af
# 0.930801 B-Soundtrack SUF_na
# 0.930425 I-Plot   WORD_land
# 0.930211 B-Year   SUF_ly
# 0.929897 B-Plot   SUF_s
# 0.929541 B-Plot   WORD_post
# 0.928894 B-Genre  SUF_ld
# 0.928863 B-Plot   WORD_buddy
# 0.928336 I-Award  SUF_my
# 0.928135 B-Genre  SUF_op
# 0.928109 B-Actor  WORD_catherine
# 0.927103 B-Plot   SUF_ere
# 0.927021 B-Character_Name SUF_ex
# 0.926259 I-Actor  SUF_rth
# 0.925919 I-Award  SUF_ard
# 0.925714 B-Actor  SUF_aye
# 0.925614 B-Director WORD_don
# 0.924741 B-Director WORD_akira
# 0.924508 I-Actor  WORD_yun
# 0.924466 I-Director WORD_perry
# 0.924360 B-Relationship HAS_NUM
# 0.923979 I-Plot   WORD_west
# 0.923690 B-Character_Name WORD_peter
# 0.923632 I-Plot   WORD_killing
# 0.923611 I-Opinion WORD_office
# 0.922464 I-Plot   WORD_from
# 0.921605 B-Actor  WORD_julianne
# 0.921392 B-Character_Name WORD_dante
# 0.920918 B-Director WORD_micheal
# 0.920388 B-Actor  SUF_go
# 0.920280 I-Director WORD_stone
# 0.919820 B-Opinion SUF_ial
# 0.919508 B-Opinion WORD_really
# 0.919483 B-Actor  WORD_ned
# 0.919393 I-Actor  SUF_dd
# 0.919274 I-Actor  SUF_art
# 0.918897 B-Actor  WORD_danny
# 0.918832 B-Soundtrack WORD_hakuna
# 0.918646 B-Character_Name SUF_o
# 0.918571 B-Plot   WORD_emotional
# 0.918481 I-Actor  WORD_seyfried
# 0.918454 B-Character_Name WORD_thumper
# 0.917987 I-Plot   WORD_take
# 0.917948 B-Character_Name WORD_james
# 0.917527 I-Origin WORD_name
# 0.916610 I-Origin WORD_series
# 0.916121 I-Actor  SUF_ro
# 0.916107 I-Genre  SUF_ite
# 0.915865 I-Character_Name SUF_eia
# 0.915865 I-Character_Name WORD_leia
# 0.915382 I-Director SUF_iam
# 0.915368 B-Director SUF_ksy
# 0.915368 B-Director WORD_banksy
# 0.915049 I-Plot   WORD_on
# 0.914405 B-Character_Name WORD_mufasa
# 0.914335 B-Character_Name WORD_aragorn
# 0.913923 B-Genre  SUF_i
# 0.913698 B-Actor  SUF_nis
# 0.913608 I-Actor  WORD_aniston
# 0.913475 I-Genre  WORD_arts
# 0.913448 B-Actor  WORD_omar
# 0.913356 B-Character_Name SUF_eth
# 0.912666 I-Origin SUF_are
# 0.912510 I-Actor  SUF_iaz
# 0.912510 I-Actor  WORD_diaz
# 0.912345 I-Genre  SUF_rn
# 0.912206 B-Director SUF_ohn
# 0.912206 B-Director WORD_john
# 0.911374 B-Actor  SUF_ene
# 0.911171 B-Origin WORD_stage
# 0.910770 I-Opinion WORD_time
# 0.910371 I-Actor  WORD_chase
# 0.910169 I-Opinion WORD_one
# 0.909509 I-Plot   SUF_ife
# 0.909282 I-Actor  WORD_norton
# 0.908915 I-Opinion SUF_lar
# 0.908689 I-Award  SUF_ds
# 0.908614 I-Character_Name SUF_ulk
# 0.908614 I-Character_Name WORD_hulk
# 0.908367 I-Director SUF_no
# 0.908102 I-Actor  WORD_gooding
# 0.907936 B-Opinion SUF_ome
# 0.907785 B-Genre  WORD_zombie
# 0.907738 B-Genre  SUF_ens
# 0.906762 I-Plot   WORD_is
# 0.906589 B-Character_Name WORD_rooster
# 0.906482 B-Origin SUF_k
# 0.906337 B-Actor  WORD_george
# 0.906165 B-Plot   WORD_back
# 0.906081 I-Opinion WORD_jerker
# 0.905806 I-Plot   WORD_sheriff
# 0.905652 I-Genre  WORD_fantasy
# 0.905385 B-Relationship SUF_th
# 0.904985 B-Actor  SUF_tt
# 0.903780 I-Actor  SUF_unt
# 0.902839 I-Relationship SUF_ame
# 0.902660 B-Actor  WORD_marlon
# 0.902362 B-Director WORD_neil
# 0.902287 I-Director SUF_der
# 0.901884 I-Actor  SUF_dem
# 0.901884 I-Actor  WORD_bardem
# 0.901780 B-Genre  SUF_iod
# 0.901780 B-Genre  WORD_period
# 0.901553 I-Actor  SUF_ams
# 0.901348 B-Actor  WORD_deniro
# 0.901268 B-Actor  SUF_ohn
# 0.901268 B-Actor  WORD_john
# 0.900187 B-Character_Name WORD_lightning
# 0.900166 I-Actor  WORD_o
# 0.900097 B-Character_Name WORD_lancelot
# 0.899807 I-Opinion SUF_ous
# 0.899713 I-Plot   SUF_20
# 0.899047 B-Character_Name SUF_ael
# 0.898901 B-Opinion SUF_sh
# 0.898537 I-Plot   WORD_everyone
# 0.898248 I-Actor  SUF_tty
# 0.898204 B-Plot   WORD_teenage
# 0.897825 I-Character_Name WORD_vader
# 0.897462 B-Plot   WORD_retired
# 0.896437 B-Origin SUF_les
# 0.896070 B-Plot   WORD_main
# 0.895952 I-Award  SUF_rs
# 0.895898 I-Actor  SUF_len
# 0.895187 I-Opinion WORD_awaited
# 0.894735 B-Genre  SUF_se
# 0.894671 B-Actor  SUF_nne
# 0.894523 I-Actor  WORD_washington
# 0.894495 B-Plot   WORD_hitman
# 0.894444 I-Actor  WORD_kutcher
# 0.893776 I-Actor  WORD_owen
# 0.893755 B-Character_Name WORD_mater
# 0.892616 I-Character_Name SUF_ast
# 0.892607 B-Actor  WORD_rachel
# 0.892489 B-Opinion WORD_groundbreaking
# 0.892370 B-Opinion WORD_well
# 0.892272 B-Plot   WORD_where
# 0.891188 I-Plot   WORD_quest
# 0.890578 I-Origin SUF_me
# 0.890266 I-Director SUF_ric
# 0.889238 B-Actor  WORD_jude
# 0.889077 B-Plot   SUF_ero
# 0.888802 I-Actor  SUF_rif
# 0.888262 B-Director SUF_hn
# 0.887952 B-Actor  WORD_frances
# 0.887407 B-Genre  WORD_teen
# 0.887052 I-Plot   WORD_deadly
# 0.886735 B-Actor  WORD_robin
# 0.886611 I-Director WORD_toro
# 0.886445 I-Actor  WORD_patrick
# 0.886340 B-Director WORD_clint
# 0.884937 B-Plot   WORD_what
# 0.884840 I-Director SUF_oro
# 0.884840 B-Actor  WORD_topher
# 0.884442 B-Origin SUF_nie
# 0.884390 B-Character_Name WORD_leatherface
# 0.884278 I-Director WORD_singer
# 0.884119 I-Plot   SUF_can
# 0.884113 B-Character_Name SUF_cob
# 0.884113 B-Character_Name WORD_jacob
# 0.883966 I-Director SUF_z
# 0.883069 I-Actor  WORD_stone
# 0.882985 B-Origin WORD_update
# 0.882631 I-Soundtrack WORD_song
# 0.882618 B-Genre  WORD_ensemble
# 0.882523 I-Plot   WORD_father
# 0.882457 B-Plot   WORD_teen
# 0.882425 I-Genre  WORD_and
# 0.882348 B-Genre  WORD_mob
# 0.882326 I-Relationship WORD_th
# 0.882247 B-Character_Name SUF_lbo
# 0.882247 B-Character_Name WORD_bilbo
# 0.882153 B-Plot   WORD_panda
# 0.881565 B-Character_Name SUF_ang
# 0.881328 B-Actor  SUF_ah
# 0.881275 I-Actor  SUF_hn
# 0.881257 I-Plot   WORD_aging
# 0.879925 I-Plot   WORD_back
# 0.879769 I-Director WORD_allen
# 0.879297 I-Character_Name WORD_bannion
# 0.879182 B-Genre  WORD_marvel
# 0.878948 B-Opinion SUF_ky
# 0.878832 B-Award  WORD_winning
# 0.878605 I-Plot   WORD_pilot
# 0.878390 I-Director WORD_rated
# 0.877813 I-Actor  WORD_evans
# 0.877658 I-Character_Name SUF_urn
# 0.877285 I-Genre  SUF_ary
# 0.876907 B-Character_Name WORD_heathcliff
# 0.876534 B-Character_Name WORD_red
# 0.876157 B-Actor  WORD_grace
# 0.875628 I-Origin SUF_ook
# 0.875440 B-Character_Name SUF_b
# 0.875167 I-Director SUF_don
# 0.875133 I-Actor  SUF_sci
# 0.875133 I-Actor  WORD_pesci
# 0.874739 B-Character_Name WORD_neo
# 0.874667 B-Actor  SUF_en
# 0.874275 B-Director SUF_lly
# 0.874127 B-Actor  WORD_ashton
# 0.873532 B-Character_Name SUF_alf
# 0.873171 I-Relationship SUF_med
# 0.872688 B-Director SUF_rg
# 0.872569 B-Award  SUF_on
# 0.872320 B-Director WORD_scorcese
# 0.872228 I-Genre  SUF_asy
# 0.871484 B-Plot   WORD_chronicles
# 0.870812 I-Plot   WORD_killed
# 0.870733 B-Character_Name WORD_joker
# 0.870600 B-Actor  SUF_lon
# 0.870461 I-Actor  SUF_rre
# 0.870382 I-Actor  WORD_lee
# 0.869853 B-Character_Name WORD_selene
# 0.869829 B-Genre  SUF_bie
# 0.869544 I-Plot   WORD_person
# 0.868060 I-Character_Name SUF_ock
# 0.867896 I-Actor  WORD_neeson
# 0.867668 B-Actor  WORD_justin
# 0.867659 B-Actor  WORD_ewan
# 0.867389 I-Genre  SUF_ime
# 0.866939 B-Actor  WORD_will
# 0.866592 B-Actor  SUF_l
# 0.866406 B-Actor  WORD_linda
# 0.866183 I-Genre  SUF_tic
# 0.865896 I-Actor  WORD_stiller
# 0.865783 B-Actor  WORD_alexander
# 0.865353 B-Opinion WORD_whimsical
# 0.865326 B-Relationship WORD_re
# 0.865234 I-Actor  WORD_swank
# 0.865133 I-Genre  WORD_tale
# 0.865088 I-Award  SUF_est
# 0.864818 I-Actor  WORD_bob
# 0.864745 B-Actor  SUF_is
# 0.863597 B-Character_Name WORD_thor
# 0.863525 I-Relationship SUF_lm
# 0.863333 B-Genre  WORD_suspenseful
# 0.863167 B-Actor  SUF_bin
# 0.862803 I-Award  WORD_winning
# 0.862503 I-Director SUF_lle
# 0.862440 B-Genre  WORD_satirical
# 0.862106 B-Actor  SUF_hn
# 0.861910 B-Opinion SUF_ly
# 0.861637 I-Plot   WORD_job
# 0.861288 I-Actor  WORD_murphy
# 0.860624 I-Plot   WORD_businessman
# 0.860547 I-Actor  WORD_maguire
# 0.859965 I-Director WORD_tarantino
# 0.859795 B-Character_Name WORD_micheal
# 0.859229 B-Character_Name SUF_dro
# 0.859229 B-Character_Name WORD_pedro
# 0.858986 B-Genre  SUF_ce
# 0.858673 B-Character_Name WORD_moe
# 0.857606 B-Plot   SUF_ain
# 0.857358 I-Character_Name WORD_montana
# 0.857357 B-Actor  WORD_sandra
# 0.857281 I-Plot   WORD_panda
# 0.857162 B-Soundtrack SUF_ong
# 0.856973 B-Character_Name WORD_aang
# 0.856781 I-Actor  SUF_wen
# 0.856120 B-Opinion WORD_sad
# 0.856020 B-Director SUF_ob
# 0.855945 B-Character_Name WORD_moses
# 0.855747 I-Award  SUF_re
# 0.855500 I-Soundtrack WORD_to
# 0.855272 B-Genre  SUF_tic
# 0.855121 I-Character_Name SUF_de
# 0.854889 B-Plot   WORD_android
# 0.854655 B-Plot   WORD_lions
# 0.854511 B-Character_Name SUF_bo
# 0.854416 I-Genre  WORD_s
# 0.853888 B-Genre  WORD_chinese
# 0.853032 B-Actor  SUF_ary
# 0.852703 I-Plot   WORD_teenager
# 0.851881 B-Character_Name SUF_an
# 0.851821 B-Character_Name SUF_eo
# 0.851203 B-Opinion SUF_ern
# 0.851090 B-Actor  WORD_pat
# 0.850424 I-Plot   WORD_feline
# 0.850294 B-Director SUF_ira
# 0.850086 B-Genre  WORD_found
# 0.850030 B-Director SUF_aul
# 0.850030 B-Director WORD_paul
# 0.849979 I-Relationship SUF_rst
# 0.848862 B-Director WORD_ingmar
# 0.848465 B-Actor  WORD_zach
# 0.848343 B-Plot   WORD_young
# 0.847776 B-Character_Name SUF_ses
# 0.847133 B-Actor  SUF_im
# 0.846832 B-Character_Name SUF_des
# 0.846802 I-Actor  SUF_voy
# 0.846802 I-Actor  WORD_mcavoy
# 0.846468 B-Character_Name SUF_mes
# 0.846120 I-Character_Name WORD_solo
# 0.846082 I-Plot   WORD_daughter
# 0.845963 B-Director WORD_jean
# 0.845620 B-Quote  SUF_u
# 0.845389 I-Relationship SUF_ie
# 0.845360 I-Origin WORD_classic
# 0.845095 I-Actor  WORD_giant
# 0.845002 B-Director SUF_ert
# 0.844722 I-Plot   WORD_president
# 0.844296 I-Plot   SUF_tar
# 0.844200 I-Director WORD_del
# 0.844126 I-Director SUF_kin
# 0.843771 I-Actor  SUF_ews
# 0.843738 I-Actor  SUF_lie
# 0.843619 I-Actor  SUF_nco
# 0.843619 I-Actor  WORD_franco
# 0.843275 I-Origin SUF_ok
# 0.843157 B-Actor  WORD_morgan
# 0.843068 I-Actor  SUF_ron
# 0.842789 B-Director WORD_mike
# 0.842507 B-Character_Name SUF_oki
# 0.842507 B-Character_Name WORD_loki
# 0.842406 I-Plot   WORD_between
# 0.842054 B-Plot   WORD_romance
# 0.841914 I-Director SUF_ang
# 0.841774 B-Character_Name SUF_zel
# 0.841526 B-Character_Name WORD_scarlett
# 0.841378 I-Actor  WORD_moore
# 0.841284 B-Character_Name SUF_ohn
# 0.841284 B-Character_Name WORD_john
# 0.841173 B-Origin WORD_dickens
# 0.841124 B-Character_Name WORD_lois
# 0.840586 I-Actor  WORD_galifianakis
# 0.839032 I-Award  WORD_of
# 0.838785 B-Character_Name WORD_ally
# 0.838464 B-Actor  WORD_jodie
# 0.837746 I-Actor  WORD_pattinson
# 0.837607 B-Actor  WORD_audrey
# 0.837511 I-Origin WORD_lee
# 0.837043 B-Actor  WORD_matt
# 0.836790 I-Plot   WORD_soldiers
# 0.836729 I-Character_Name WORD_daniels
# 0.836622 B-Origin WORD_remake
# 0.836405 B-Plot   WORD_aired
# 0.836278 I-Plot   WORD_detective
# 0.836149 B-Character_Name WORD_mrs
# 0.836039 I-Plot   SUF_920
# 0.836039 I-Plot   WORD_1920
# 0.835966 I-Soundtrack WORD_my
# 0.835886 B-Plot   SUF_ion
# 0.835492 B-Quote  SUF_ay
# 0.835480 I-Actor  SUF_if
# 0.835159 I-Plot   SUF_ol
# 0.834806 B-Character_Name SUF_kie
# 0.834376 I-Origin WORD_rowling
# 0.834260 B-Opinion WORD_mind
# 0.833288 I-Director WORD_w
# 0.833014 I-Actor  WORD_grace
# 0.832900 B-Actor  SUF_die
# 0.832899 B-Plot   SUF_ows
# 0.832576 B-Character_Name WORD_eliot
# 0.832354 B-Character_Name WORD_rick
# 0.831634 B-Actor  WORD_vince
# 0.831403 B-Director SUF_eth
# 0.831387 B-Actor  SUF_dr
# 0.831387 B-Actor  SUF_ndr
# 0.831387 B-Actor  WORD_andr
# 0.831248 I-Plot   SUF_ho
# 0.830763 I-Opinion WORD_loved
# 0.830443 I-Actor  SUF_hel
# 0.829965 B-Genre  WORD_foreign
# 0.829840 B-Relationship SUF_ke
# 0.829827 B-Director WORD_joe
# 0.829524 B-Genre  SUF_ts
# 0.829163 I-Opinion WORD_quality
# 0.828996 B-Director SUF_ank
# 0.828600 B-Actor  WORD_yul
# 0.828300 I-Director SUF_am
# 0.828200 I-Character_Name WORD_jung
# 0.828134 B-Actor  SUF_rge
# 0.828014 I-Actor  SUF_way
# 0.827940 I-Character_Name WORD_mcqueen
# 0.827466 I-Actor  WORD_baruchel
# 0.827435 B-Character_Name SUF_ff
# 0.827290 I-Director WORD_ritchie
# 0.827228 I-Director WORD_polanski
# 0.827024 B-Plot   SUF_tar
# 0.826184 B-Actor  WORD_shia
# 0.826117 B-Character_Name SUF_lly
# 0.825686 I-Opinion SUF_ut
# 0.825423 I-Plot   WORD_parkinson
# 0.824821 B-Relationship WORD_follow
# 0.824767 I-Actor  WORD_neal
# 0.824557 I-Actor  SUF_ft
# 0.824218 I-Plot   WORD_up
# 0.823605 B-Opinion WORD_low
# 0.823397 B-Relationship WORD_installment
# 0.823302 I-Character_Name SUF_hes
# 0.822715 B-Actor  WORD_lee
# 0.822177 I-Actor  WORD_garland
# 0.822122 B-Character_Name WORD_han
# 0.822047 B-Actor  WORD_julie
# 0.821523 B-Character_Name SUF_asa
# 0.821475 I-Relationship WORD_bruges
# 0.821324 I-Character_Name SUF_to
# 0.821314 B-Actor  WORD_zac
# 0.821208 I-Actor  SUF_uss
# 0.820305 B-Actor  WORD_marilyn
# 0.819985 I-Actor  WORD_malkovich
# 0.817701 I-Opinion SUF_ime
# 0.817667 I-Actor  SUF_en
# 0.817485 I-Actor  SUF_ble
# 0.817485 I-Actor  WORD_scheider
# 0.816826 B-Opinion WORD_much
# 0.816213 I-Relationship WORD_nominated
# 0.815991 I-Award  SUF_lm
# 0.815796 I-Actor  SUF_urn
# 0.815653 I-Soundtrack WORD_of
# 0.815272 B-Origin SUF_v
# 0.814995 I-Actor  WORD_cleese
# 0.814850 I-Character_Name SUF_nes
# 0.814626 B-Plot   WORD_super
# 0.814168 B-Character_Name WORD_tin
# 0.813856 B-Plot   WORD_must
# 0.813732 B-Director WORD_martin
# 0.813675 B-Director SUF_io
# 0.813647 B-Actor  WORD_katherine
# 0.813389 I-Plot   WORD_rich
# 0.812975 B-Origin SUF_de
# 0.812580 I-Actor  SUF_ndo
# 0.812290 B-Character_Name SUF_iff
# 0.812265 I-Actor  WORD_bacon
# 0.811798 I-Director WORD_truffaut
# 0.811768 B-Actor  WORD_dustin
# 0.811635 I-Relationship WORD_telling
# 0.811367 B-Genre  WORD_independent
# 0.810915 B-Character_Name SUF_k
# 0.810911 I-Actor  SUF_rne
# 0.810909 B-Plot   SUF_ung
# 0.810601 I-Actor  WORD_zellweger
# 0.810581 I-Character_Name SUF_sie
# 0.810471 I-Origin WORD_released
# 0.810106 I-Actor  WORD_clooney
# 0.810090 I-Actor  SUF_iig
# 0.810090 I-Actor  WORD_wiig
# 0.810044 I-Plot   SUF_hey
# 0.809352 B-Character_Name WORD_ren
# 0.808904 I-Actor  WORD_brand
# 0.808840 I-Director WORD_kubric
# 0.808641 I-Actor  SUF_tal
# 0.808459 I-Director SUF_aut
# 0.808395 I-Actor  WORD_de
# 0.808180 B-Character_Name SUF_i
# 0.807796 B-Plot   SUF_ut
# 0.807462 I-Origin WORD_comics
# 0.807229 I-Plot   WORD_die
# 0.806799 I-Director SUF_awa
# 0.806799 I-Director WORD_kurosawa
# 0.806397 B-Director WORD_milos
# 0.806268 I-Actor  SUF_don
# 0.805886 I-Origin WORD_franchise
# 0.805011 B-Character_Name SUF_hn
# 0.804452 B-Character_Name SUF_nte
# 0.803090 I-Plot   WORD_nuclear
# 0.803007 B-Director WORD_charlie
# 0.802967 I-Director SUF_wa
# 0.802832 I-Director SUF_hie
# 0.802763 I-Plot   SUF_ued
# 0.801962 I-Plot   WORD_cocaine
# 0.801830 B-Genre  SUF_gn
# 0.801830 B-Genre  SUF_ign
# 0.801794 I-Plot   SUF_any
# 0.801783 B-Actor  WORD_javier
# 0.801363 B-Director WORD_kevin
# 0.801087 B-Director SUF_eil
# 0.800409 I-Actor  SUF_ied
# 0.800006 I-Relationship WORD_part
# 0.799962 I-Director WORD_mendes
# 0.799892 B-Actor  WORD_claire
# 0.799860 I-Actor  WORD_ryan
# 0.799649 B-Plot   SUF_ist
# 0.799584 B-Origin WORD_re
# 0.799315 I-Origin SUF_cal
# 0.799305 B-Actor  WORD_vincent
# 0.798975 B-Relationship SUF_ale
# 0.798963 I-Actor  SUF_lor
# 0.798851 B-Genre  WORD_coming
# 0.798696 I-Actor  WORD_quaid
# 0.798034 B-Character_Name SUF_x
# 0.797793 B-Actor  WORD_gerard
# 0.797696 B-Character_Name WORD_cowardly
# 0.797651 I-Character_Name SUF_ins
# 0.797635 I-Plot   WORD_wedding
# 0.797508 B-Director SUF_rol
# 0.797392 I-Director WORD_henson
# 0.797259 B-Genre  WORD_cult
# 0.797117 I-Director SUF_lma
# 0.797012 B-Plot   SUF_hey
# 0.796845 B-Opinion SUF_d
# 0.796812 B-Character_Name SUF_oda
# 0.796812 B-Character_Name WORD_yoda
# 0.796429 B-Character_Name WORD_harry
# 0.796386 I-Genre  SUF_ge
# 0.796207 I-Origin WORD_of
# 0.796110 I-Relationship SUF_ory
# 0.795822 I-Origin SUF_uss
# 0.795521 B-Origin SUF_el
# 0.795367 I-Director SUF_in
# 0.795346 B-Actor  WORD_sally
# 0.795289 I-Plot   WORD_11
# 0.795265 B-Actor  WORD_sylvester
# 0.795128 I-Plot   WORD_way
# 0.795100 B-Character_Name SUF_rge
# 0.795054 I-Plot   WORD_computer
# 0.794896 B-Year   SUF_0
# 0.794430 B-Plot   SUF_ath
# 0.794140 B-Director WORD_sam
# 0.794071 B-Plot   SUF_tle
# 0.793775 B-Actor  SUF_hel
# 0.793633 B-Director SUF_is
# 0.793395 I-Plot   WORD_crew
# 0.793143 I-Director SUF_rd
# 0.793026 I-Director SUF_dan
# 0.792985 B-Character_Name WORD_sarah
# ...
# -0.431953 I-Plot   WORD_wounded
# -0.432424 I-Plot   SUF_ddy
# -0.434104 I-Actor  SUF_u
# -0.434368 I-Plot   WORD_voiced
# -0.435187 B-Genre  SUF_in
# -0.436333 B-Opinion SUF_o
# -0.436869 I-Plot   WORD_dorothy
# -0.436968 I-Plot   WORD_longs
# -0.437100 B-Plot   SUF_ton
# -0.437996 I-Plot   SUF_ept
# -0.438192 I-Opinion SUF_se
# -0.439170 I-Plot   WORD_scar
# -0.439603 I-Plot   WORD_adversity
# -0.440192 I-Plot   WORD_word
# -0.440206 I-Actor  SUF_il
# -0.440887 I-Plot   SUF_3
# -0.441307 I-Plot   SUF_lle
# -0.441343 B-Actor  SUF_ous
# -0.441490 I-Plot   WORD_speaking
# -0.442910 I-Plot   HAS_NUM
# -0.444435 I-Plot   WORD_your
# -0.444870 I-Plot   WORD_threats
# -0.444920 I-Plot   SUF_ke
# -0.445708 I-Plot   WORD_memorable
# -0.446064 I-Plot   SUF_han
# -0.446951 I-Actor  WORD_t
# -0.448377 B-Director SUF_ng
# -0.448878 I-Plot   WORD_musical
# -0.449105 I-Plot   SUF_ara
# -0.449339 I-Quote  SUF_d
# -0.449618 I-Plot   SUF_rge
# -0.450405 B-Actor  SUF_rs
# -0.450587 I-Plot   SUF_row
# -0.451364 I-Plot   SUF_itt
# -0.451435 I-Plot   WORD_5
# -0.452326 I-Plot   WORD_considered
# -0.453004 I-Plot   WORD_b
# -0.454211 I-Plot   WORD_lot
# -0.454491 I-Plot   WORD_focused
# -0.454968 B-Plot   SUF_a
# -0.455406 I-Director SUF_ke
# -0.455943 I-Genre  SUF_p
# -0.456151 B-Plot   SUF_ver
# -0.457489 I-Plot   WORD_awards
# -0.457492 I-Plot   SUF_m
# -0.457835 I-Plot   WORD_largest
# -0.457879 I-Plot   WORD_l
# -0.458807 I-Origin SUF_e
# -0.459053 I-Plot   WORD_most
# -0.459487 I-Plot   WORD_light
# -0.459818 I-Plot   SUF_lan
# -0.460236 I-Plot   SUF_ark
# -0.460682 I-Plot   SUF_tu
# -0.461076 I-Plot   WORD_rest
# -0.461294 B-Character_Name WORD_jackie
# -0.461395 B-Plot   SUF_ise
# -0.461927 I-Origin SUF_t
# -0.462963 I-Plot   SUF_tie
# -0.463505 I-Plot   WORD_kate
# -0.463787 I-Plot   WORD_five
# -0.464402 I-Plot   SUF_eus
# -0.464481 B-Genre  WORD_music
# -0.464619 B-Plot   SUF_ick
# -0.465259 I-Quote  SUF_r
# -0.465678 B-Plot   SUF_ong
# -0.466817 B-Quote  SUF_s
# -0.466968 I-Plot   WORD_live
# -0.467136 I-Actor  WORD_rodriguez
# -0.468132 I-Plot   WORD_showed
# -0.468504 I-Plot   WORD_itself
# -0.468593 I-Actor  SUF_cer
# -0.469246 I-Plot   WORD_just
# -0.469997 B-Year   SUF_y
# -0.470285 I-Plot   SUF_uss
# -0.470649 I-Plot   SUF_ph
# -0.470698 I-Plot   WORD_map
# -0.471193 I-Plot   SUF_oe
# -0.471267 I-Relationship SUF_r
# -0.471451 I-Plot   WORD_loosely
# -0.471704 I-Plot   WORD_hop
# -0.472484 B-Plot   SUF_id
# -0.472984 B-Opinion SUF_ay
# -0.473120 I-Plot   SUF_eck
# -0.473498 I-Actor  WORD_macfarlane
# -0.475141 B-Opinion SUF_ted
# -0.475383 I-Actor  SUF_ory
# -0.476720 I-Plot   SUF_gor
# -0.476970 I-Plot   WORD_move
# -0.478108 I-Plot   WORD_shower
# -0.478131 I-Actor  SUF_ive
# -0.479592 I-Plot   SUF_ven
# -0.479730 I-Plot   WORD_audience
# -0.481608 I-Plot   WORD_stage
# -0.481680 I-Plot   WORD_twist
# -0.482623 B-Actor  SUF_p
# -0.483732 B-Director SUF_uel
# -0.484357 I-Plot   WORD_half
# -0.484380 I-Relationship SUF_ld
# -0.485302 I-Relationship SUF_k
# -0.485377 I-Actor  SUF_ian
# -0.486066 I-Plot   SUF_cup
# -0.486129 I-Plot   SUF_tch
# -0.486769 I-Opinion SUF_i
# -0.488161 B-Character_Name SUF_her
# -0.489129 I-Quote  SUF_ar
# -0.490832 I-Plot   SUF_k
# -0.491590 I-Plot   SUF_lay
# -0.492417 I-Origin WORD_d
# -0.493006 I-Plot   WORD_greatest
# -0.494318 I-Plot   SUF_ops
# -0.494576 I-Director SUF_re
# -0.495141 I-Plot   SUF_eal
# -0.496103 I-Director SUF_y
# -0.496542 I-Origin SUF_r
# -0.497044 I-Plot   WORD_favorite
# -0.498275 I-Plot   SUF_tin
# -0.498633 I-Plot   SUF_eld
# -0.498857 I-Plot   WORD_camera
# -0.499609 I-Plot   SUF_los
# -0.500418 I-Origin SUF_d
# -0.500801 I-Plot   SUF_ino
# -0.501782 B-Plot   WORD_does
# -0.501837 B-Plot   WORD_series
# -0.501991 I-Plot   WORD_develops
# -0.502219 I-Origin SUF_a
# -0.502256 I-Plot   WORD_lord
# -0.502832 I-Plot   WORD_mickey
# -0.503809 B-Plot   WORD_real
# -0.503916 I-Plot   SUF_ne
# -0.504228 B-Plot   SUF_rst
# -0.504651 I-Plot   WORD_phrase
# -0.504774 I-Plot   SUF_vid
# -0.505808 I-Plot   SUF_ump
# -0.506780 I-Genre  SUF_red
# -0.508655 I-Plot   WORD_every
# -0.509009 B-Character_Name SUF_me
# -0.509110 I-Actor  SUF_uez
# -0.509309 B-Plot   SUF_x
# -0.509767 I-Director SUF_d
# -0.510083 I-Plot   WORD_spent
# -0.510277 I-Relationship WORD_set
# -0.510507 I-Genre  SUF_n
# -0.510578 I-Plot   SUF_emy
# -0.510691 I-Plot   SUF_len
# -0.511775 I-Plot   WORD_futuristic
# -0.511917 I-Plot   SUF_eo
# -0.512323 I-Plot   WORD_role
# -0.512341 I-Director SUF_p
# -0.512356 I-Director WORD_s
# -0.512750 I-Plot   WORD_brown
# -0.513019 I-Plot   SUF_ta
# -0.513790 I-Plot   WORD_screen
# -0.514904 B-Character_Name SUF_ney
# -0.515084 I-Plot   WORD_capture
# -0.515704 I-Plot   WORD_marvel
# -0.516028 B-Quote  SUF_l
# -0.516150 I-Plot   WORD_epic
# -0.517472 B-Opinion WORD_the
# -0.517999 I-Character_Name SUF_ry
# -0.518526 B-Plot   WORD_by
# -0.518613 I-Plot   WORD_harry
# -0.518623 I-Actor  SUF_rk
# -0.519246 B-Origin SUF_f
# -0.521428 B-Plot   SUF_us
# -0.521583 I-Plot   SUF_ise
# -0.521832 I-Actor  SUF_ky
# -0.521937 I-Plot   SUF_tum
# -0.522825 B-Plot   SUF_ger
# -0.523231 I-Plot   SUF_za
# -0.524986 I-Plot   SUF_nes
# -0.524990 I-Plot   WORD_hamlet
# -0.525005 I-Actor  SUF_or
# -0.525129 I-Plot   WORD_steve
# -0.525290 I-Director SUF_t
# -0.525861 B-Plot   SUF_med
# -0.526458 I-Relationship SUF_an
# -0.526715 B-Quote  SUF_d
# -0.526784 I-Genre  WORD_adaptation
# -0.527226 I-Plot   SUF_ob
# -0.527553 B-Opinion SUF_hat
# -0.528142 B-Quote  SUF_r
# -0.528153 I-Plot   SUF_ode
# -0.528366 I-Origin WORD_hunter
# -0.528430 I-Plot   SUF_iam
# -0.529114 I-Character_Name SUF_as
# -0.529362 I-Plot   SUF_ey
# -0.529364 I-Plot   SUF_red
# -0.529520 B-Plot   SUF_rd
# -0.530335 I-Plot   WORD_feature
# -0.530904 I-Plot   SUF_ris
# -0.532621 I-Plot   WORD_water
# -0.533012 I-Plot   WORD_thomas
# -0.534238 I-Plot   WORD_hal
# -0.534355 I-Actor  SUF_b
# -0.535259 I-Plot   WORD_put
# -0.536245 I-Plot   WORD_aldous
# -0.537720 B-Actor  SUF_s
# -0.538981 I-Relationship SUF_er
# -0.540222 I-Plot   WORD_private
# -0.540516 I-Plot   WORD_h
# -0.541046 I-Plot   WORD_roles
# -0.541291 B-Plot   SUF_mes
# -0.541667 I-Character_Name SUF_c
# -0.542023 I-Plot   SUF_hy
# -0.542314 B-Plot   SUF_ms
# -0.543171 I-Director SUF_ce
# -0.544771 B-Actor  SUF_sh
# -0.544966 I-Plot   WORD_telling
# -0.545596 I-Plot   SUF_ggs
# -0.547212 I-Origin SUF_b
# -0.548566 I-Origin SUF_her
# -0.549025 I-Plot   WORD_britons
# -0.549609 I-Plot   WORD_fairytale
# -0.552526 I-Plot   WORD_versions
# -0.553850 I-Plot   SUF_get
# -0.554888 I-Plot   SUF_ler
# -0.555481 I-Plot   SUF_e
# -0.556143 I-Plot   SUF_ott
# -0.556690 I-Origin SUF_se
# -0.557672 I-Relationship WORD_action
# -0.558464 I-Plot   WORD_jr
# -0.560519 I-Plot   SUF_rie
# -0.560702 I-Actor  SUF_edy
# -0.561302 I-Genre  SUF_ing
# -0.561383 I-Year   SUF_y
# -0.564142 B-Origin SUF_er
# -0.564753 I-Plot   SUF_ye
# -0.565108 I-Plot   WORD_voices
# -0.565476 I-Plot   WORD_fans
# -0.566171 I-Plot   SUF_ese
# -0.566722 I-Plot   WORD_brothers
# -0.566923 B-Actor  SUF_ery
# -0.567689 I-Plot   SUF_uts
# -0.568268 I-Plot   SUF_ael
# -0.568384 I-Character_Name SUF_al
# -0.568543 I-Plot   WORD_afraid
# -0.568755 B-Plot   WORD_do
# -0.569785 I-Plot   SUF_ams
# -0.570760 I-Relationship SUF_ar
# -0.571005 I-Plot   WORD_shakespeare
# -0.573022 I-Plot   SUF_hur
# -0.573070 I-Plot   SUF_llo
# -0.573348 I-Plot   WORD_befriend
# -0.573702 I-Plot   WORD_members
# -0.573764 B-Opinion SUF_he
# -0.574092 I-Origin SUF_nk
# -0.574135 I-Plot   WORD_rob
# -0.574880 I-Actor  SUF_ven
# -0.575020 I-Plot   WORD_comedy
# -0.575058 B-Director SUF_le
# -0.575236 I-Plot   SUF_kin
# -0.575506 I-Plot   WORD_fourth
# -0.575698 I-Relationship SUF_ge
# -0.575735 I-Plot   SUF_ul
# -0.576160 I-Plot   WORD_book
# -0.576765 I-Plot   WORD_few
# -0.576788 I-Plot   SUF_oks
# -0.578008 I-Plot   WORD_because
# -0.578666 I-Opinion SUF_en
# -0.579047 I-Plot   WORD_focusing
# -0.579684 B-Origin SUF_ck
# -0.580556 I-Plot   WORD_action
# -0.581360 I-Director SUF_e
# -0.581397 I-Plot   WORD_x
# -0.582309 B-Character_Name SUF_ry
# -0.582504 I-Origin WORD_frank
# -0.583103 I-Plot   WORD_distant
# -0.585398 B-Plot   WORD_were
# -0.587401 I-Plot   SUF_ald
# -0.589128 I-Actor  SUF_ter
# -0.589135 I-Plot   WORD_portrayal
# -0.590091 I-Plot   WORD_song
# -0.590552 I-Actor  WORD_movie
# -0.593642 I-Plot   SUF_ony
# -0.594070 I-Plot   SUF_bal
# -0.595323 I-Director SUF_ed
# -0.595458 I-Plot   SUF_d
# -0.596732 I-Plot   SUF_eed
# -0.596778 I-Plot   SUF_yle
# -0.597330 I-Director SUF_ly
# -0.598111 I-Quote  HAS_NUM
# -0.598544 I-Plot   WORD_picture
# -0.598711 I-Actor  SUF_ew
# -0.600905 I-Plot   WORD_grant
# -0.603297 I-Actor  SUF_ave
# -0.603499 I-Plot   WORD_released
# -0.604604 I-Plot   WORD_acting
# -0.604850 B-Director SUF_ion
# -0.604960 B-Actor  WORD_bryan
# -0.605834 I-Plot   SUF_ten
# -0.607675 I-Plot   WORD_voice
# -0.609294 I-Director SUF_ve
# -0.609403 I-Actor  SUF_o
# -0.609443 I-Plot   SUF_nne
# -0.611227 I-Plot   SUF_li
# -0.611354 B-Actor  SUF_hen
# -0.611502 I-Director SUF_ss
# -0.611964 B-Plot   WORD_around
# -0.612541 I-Plot   WORD_eliot
# -0.612624 I-Plot   WORD_hit
# -0.613635 B-Actor  SUF_ody
# -0.614213 I-Plot   SUF_est
# -0.614624 I-Actor  SUF_ake
# -0.617157 I-Plot   WORD_flight
# -0.617480 I-Genre  SUF_h
# -0.618823 I-Plot   SUF_us
# -0.619452 I-Plot   WORD_me
# -0.620458 I-Director SUF_ng
# -0.620997 B-Genre  SUF_ory
# -0.621070 I-Quote  SUF_as
# -0.621764 I-Actor  SUF_ho
# -0.621776 I-Character_Name WORD_a
# -0.623355 I-Plot   SUF_go
# -0.625846 B-Year   SUF_e
# -0.626249 I-Plot   SUF_ohn
# -0.626249 I-Plot   WORD_john
# -0.629193 I-Plot   SUF_by
# -0.629770 I-Plot   WORD_depicts
# -0.629847 I-Plot   SUF_nor
# -0.630508 I-Plot   WORD_prime
# -0.630628 I-Plot   SUF_h
# -0.630875 I-Plot   WORD_title
# -0.631092 I-Genre  SUF_g
# -0.632620 I-Plot   WORD_third
# -0.632950 I-Genre  SUF_all
# -0.636228 B-Year   SUF_s
# -0.638029 I-Plot   SUF_nn
# -0.638992 I-Plot   SUF_yn
# -0.639058 B-Year   SUF_00
# -0.639215 I-Plot   WORD_tells
# -0.639358 I-Plot   WORD_novel
# -0.640217 I-Plot   SUF_el
# -0.641486 I-Plot   SUF_nny
# -0.642976 I-Plot   SUF_r
# -0.643316 I-Plot   SUF_eve
# -0.643733 I-Plot   WORD_actual
# -0.644168 I-Award  SUF_er
# -0.644234 I-Plot   WORD_trilogy
# -0.644520 I-Plot   WORD_alongside
# -0.644786 I-Plot   WORD_eastwood
# -0.646738 I-Director SUF_ack
# -0.647376 B-Plot   SUF_u
# -0.647586 I-Plot   WORD_budget
# -0.649076 I-Actor  SUF_lm
# -0.650523 I-Character_Name WORD_and
# -0.651448 I-Plot   WORD_e
# -0.651530 I-Plot   SUF_hor
# -0.651720 I-Actor  SUF_ata
# -0.652577 I-Plot   SUF_les
# -0.653700 I-Actor  SUF_t
# -0.655784 I-Relationship SUF_ce
# -0.656780 I-Plot   WORD_brings
# -0.657848 I-Plot   WORD_scary
# -0.660084 I-Plot   WORD_part
# -0.660755 I-Plot   WORD_frank
# -0.661775 I-Actor  SUF_vie
# -0.663200 I-Plot   WORD_score
# -0.665702 I-Quote  WORD_and
# -0.666892 B-Director SUF_ll
# -0.670645 I-Actor  SUF_st
# -0.672155 B-Plot   SUF_son
# -0.673321 B-Plot   SUF_on
# -0.673550 I-Quote  SUF_ne
# -0.674293 I-Plot   WORD_dr
# -0.674376 I-Plot   WORD_centers
# -0.674494 I-Plot   WORD_dante
# -0.675327 I-Plot   WORD_best
# -0.677437 I-Award  SUF_t
# -0.681054 I-Plot   WORD_its
# -0.681337 I-Plot   SUF_os
# -0.682917 I-Plot   WORD_popular
# -0.685367 I-Actor  SUF_sh
# -0.687316 I-Director WORD_movie
# -0.687706 B-Actor  SUF_hey
# -0.688930 B-Actor  SUF_he
# -0.689763 I-Plot   SUF_tty
# -0.690142 I-Director SUF_vie
# -0.691758 I-Origin SUF_ly
# -0.692603 I-Plot   WORD_hours
# -0.695420 I-Origin WORD_peter
# -0.700463 I-Plot   WORD_roberts
# -0.702456 I-Plot   WORD_mike
# -0.703101 B-Plot   SUF_ie
# -0.703826 I-Plot   SUF_g
# -0.704305 I-Plot   SUF_dd
# -0.704878 I-Plot   WORD_m
# -0.707099 I-Plot   WORD_deals
# -0.708713 I-Plot   WORD_multiple
# -0.710501 I-Origin SUF_in
# -0.711744 I-Plot   SUF_uce
# -0.713707 I-Actor  WORD_huston
# -0.714090 I-Plot   SUF_to
# -0.716188 I-Plot   SUF_oto
# -0.717204 I-Plot   SUF_ah
# -0.718159 I-Quote  SUF_en
# -0.719191 B-Actor  SUF_ed
# -0.719281 I-Plot   WORD_stars
# -0.719629 I-Quote  SUF_te
# -0.719882 I-Plot   SUF_int
# -0.719958 B-Actor  SUF_ar
# -0.722405 B-Actor  SUF_ven
# -0.724958 I-Plot   WORD_rose
# -0.725231 I-Year   SUF_e
# -0.727861 I-Plot   WORD_disney
# -0.728202 I-Actor  SUF_c
# -0.728270 I-Origin SUF_o
# -0.728532 B-Actor  SUF_ng
# -0.729983 I-Plot   SUF_is
# -0.730372 I-Plot   SUF_rre
# -0.731677 I-Plot   WORD_actor
# -0.732442 B-Director WORD_the
# -0.732556 I-Quote  SUF_ed
# -0.732717 I-Actor  SUF_ero
# -0.733375 I-Soundtrack SUF_d
# -0.740027 B-Plot   SUF_nes
# -0.741219 B-Director SUF_us
# -0.744056 I-Actor  SUF_p
# -0.745043 B-Director SUF_st
# -0.748393 I-Relationship WORD_television
# -0.750081 I-Opinion SUF_k
# -0.750253 I-Plot   SUF_gan
# -0.753893 I-Award  WORD_for
# -0.755088 B-Plot   WORD_james
# -0.755376 I-Character_Name SUF_ing
# -0.759077 I-Plot   WORD_i
# -0.760741 I-Quote  SUF_ry
# -0.765229 B-Actor  SUF_nd
# -0.768130 I-Plot   WORD_animated
# -0.769277 I-Plot   SUF_sa
# -0.770744 I-Relationship SUF_en
# -0.772375 B-Director HAS_NUM
# -0.773079 I-Plot   SUF_lms
# -0.773366 I-Actor  SUF_ent
# -0.773516 I-Plot   WORD_bates
# -0.774299 I-Genre  HAS_NUM
# -0.776359 I-Character_Name SUF_ed
# -0.777112 B-Plot   SUF_les
# -0.778710 I-Actor  SUF_ad
# -0.781154 I-Plot   SUF_ois
# -0.783209 I-Actor  WORD_anderson
# -0.783229 I-Plot   WORD_cast
# -0.789084 I-Plot   WORD_famously
# -0.794140 I-Plot   WORD_playing
# -0.795327 I-Actor  WORD_cameron
# -0.797400 I-Actor  WORD_nelson
# -0.798328 I-Plot   WORD_portrays
# -0.799244 I-Plot   SUF_in
# -0.800173 I-Plot   SUF_rad
# -0.802459 I-Plot   WORD_plot
# -0.803206 I-Plot   SUF_ker
# -0.803752 I-Actor  SUF_me
# -0.804467 B-Director SUF_he
# -0.806640 I-Plot   SUF_y
# -0.807824 B-Plot   SUF_rt
# -0.819757 B-Plot   SUF_is
# -0.821981 B-Actor  SUF_st
# -0.828470 I-Opinion SUF_a
# -0.830110 I-Plot   WORD_starring
# -0.830269 I-Director SUF_c
# -0.833080 I-Director WORD_animation
# -0.840296 B-Genre  WORD_the
# -0.842479 I-Plot   SUF_x
# -0.842888 I-Actor  WORD_who
# -0.845339 I-Plot   SUF_mon
# -0.851363 I-Plot   SUF_c
# -0.851845 I-Plot   WORD_lee
# -0.853852 I-Plot   SUF_on
# -0.858345 I-Plot   WORD_filming
# -0.858476 I-Plot   SUF_o
# -0.859975 I-Plot   WORD_original
# -0.865995 I-Opinion SUF_an
# -0.867333 B-Plot   SUF_ved
# -0.867610 I-Genre  SUF_o
# -0.868722 I-Plot   WORD_sean
# -0.869828 B-Plot   SUF_i
# -0.871987 I-Origin WORD_j
# -0.874548 I-Plot   WORD_cartoon
# -0.877626 I-Plot   SUF_ki
# -0.884266 I-Actor  SUF_s
# -0.885731 I-Plot   SUF_alf
# -0.890651 I-Plot   WORD_k
# -0.892169 B-Genre  SUF_he
# -0.892278 I-Actor  WORD_a
# -0.895484 I-Plot   SUF_eg
# -0.909150 I-Plot   WORD_installment
# -0.909328 I-Plot   WORD_cage
# -0.914312 I-Director SUF_al
# -0.918004 I-Plot   WORD_actors
# -0.919121 I-Plot   WORD_rings
# -0.927526 I-Quote  SUF_se
# -0.929728 I-Origin SUF_g
# -0.936444 I-Relationship SUF_a
# -0.936558 I-Plot   WORD_r
# -0.938846 I-Plot   SUF_hn
# -0.941563 B-Actor  SUF_ion
# -0.944455 I-Plot   WORD_mark
# -0.946844 B-Character_Name SUF_ll
# -0.947065 I-Plot   SUF_els
# -0.951219 I-Actor  HAS_NUM
# -0.952705 I-Plot   SUF_ley
# -0.954155 I-Plot   WORD_plays
# -0.957319 I-Plot   WORD_documentary
# -0.958357 I-Genre  WORD_feature
# -0.961124 I-Plot   WORD_focuses
# -0.985009 I-Plot   SUF_z
# -0.988650 I-Plot   SUF_ell
# -0.992345 I-Plot   SUF_ie
# -1.000750 B-Character_Name WORD_the
# -1.001167 I-Director SUF_ic
# -1.010202 B-Character_Name SUF_st
# -1.011326 I-Actor  WORD_burton
# -1.013014 I-Plot   WORD_called
# -1.014938 I-Plot   SUF_v
# -1.022553 I-Plot   SUF_ray
# -1.025851 I-Director SUF_m
# -1.029060 I-Plot   WORD_played
# -1.029410 I-Plot   WORD_involving
# -1.033340 I-Plot   SUF_rry
# -1.040120 I-Plot   SUF_fer
# -1.041701 I-Plot   SUF_a
# -1.054101 B-Director SUF_ing
# -1.062827 I-Award  WORD_including
# -1.065892 I-Plot   SUF_l
# -1.067796 I-Plot   WORD_o
# -1.068120 I-Plot   WORD_george
# -1.071963 B-Character_Name SUF_ous
# -1.077195 I-Plot   WORD_lawrence
# -1.081496 I-Actor  SUF_ing
# -1.083176 I-Plot   WORD_classic
# -1.085208 I-Plot   WORD_t
# -1.100144 I-Plot   WORD_d
# -1.103202 B-Actor  WORD_the
# -1.106949 I-Plot   WORD_robert
# -1.113837 I-Plot   WORD_fat
# -1.119547 I-Actor  SUF_ic
# -1.125159 I-Actor  SUF_lay
# -1.128108 I-Plot   WORD_involves
# -1.128526 I-Plot   WORD_features
# -1.134062 I-Plot   SUF_tt
# -1.175458 B-Actor  SUF_al
# -1.182210 I-Plot   WORD_movies
# -1.184399 I-Plot   WORD_james
# -1.185310 I-Director SUF_ion
# -1.218156 I-Plot   WORD_jack
# -1.229129 I-Plot   SUF_las
# -1.237195 I-Plot   WORD_featuring
# -1.271226 I-Plot   SUF_eth
# -1.278425 I-Actor  WORD_and
# -1.278979 I-Plot   WORD_my
# -1.279797 I-Actor  WORD_s
# -1.291191 I-Plot   SUF_ron
# -1.291753 I-Genre  SUF_t
# -1.317945 B-Actor  WORD_a
# -1.345184 I-Plot   WORD_series
# -1.347472 I-Actor  WORD_of
# -1.368208 I-Genre  SUF_s
# -1.398732 I-Plot   SUF_lo
# -1.402683 I-Actor  SUF_ar
# -1.407709 I-Plot   WORD_based
# -1.458788 I-Plot   SUF_car
# -1.464822 I-Plot   SUF_i
# -1.478456 I-Plot   SUF_yan
# -1.533202 I-Plot   SUF_u
# -1.625560 I-Actor  SUF_ed

# %% [markdown]
# # 1. Split the training data into 80% training, 20% development set
# Here, we are splitting the training data (`training_data`) into two lists: one split of the first 80% of the instances of `training_data`, which we will use for training our CRF, and the remaining 20% for testing. Once we've done this, we will re-run the above code such that the tagger is trained on the 80% split and tested on the 20% split, and we obtain the classification report output and confusion heatmap output for the results of testing. We will record the results by saving the classification report output as a string somewhere in the notebook for future reference as we go through.

# %%
raw_training_data = get_raw_data_from_bio_file("trivia10k13train.bio.txt") 

import numpy as np
from sklearn.model_selection import train_test_split

x_train, x_test = train_test_split(raw_training_data,train_size = 0.8,  test_size=0.2 , shuffle = False)

def preProcess(example):
    """Function takes in list of (word, bio-tag) pairs, e.g.:
        [('steve', 'B-Actor'), ('mcqueen', 'I-Actor'), ('provided', 'O'),
        ('a', 'O'), ('thrilling', 'B-Plot'), ('motorcycle', 'I-Plot'),
        ('chase', 'I-Plot'), ('in', 'I-Plot'), ('this', 'I-Plot'),
        ('greatest', 'B-Opinion'), ('of', 'I-Opinion'), ('all', 'I-Opinion'),
        ('ww', 'B-Plot'), ('2', 'I-Plot'), ('prison', 'I-Plot'),
        ('escape', 'I-Plot'), ('movies', 'I-Plot')]
        
    returns new (token, bio-tag) pairs with preprocessing applied to the words"""

    preprocessed_example = example  # trivial- no preprocessing
    return preprocessed_example

training_data = [preProcess(example) for example in x_train]

# %%
_pattern = re.compile(r"\d")  # to recognize numbers/digits


# This is the 'out-of-the-box' get_features function from the nltk CRF tagger
def get_features(tokens, idx):
    """
    Extract basic features about this word including
         - Current Word
         - Is Capitalized ?
         - Has Punctuation ?
         - Has Number ?
         - Suffixes up to length 3
    Note that : we might include feature over previous word, next word ect.

    :return : a list which contains the features
    :rtype : list(str)

    """
    token = tokens[idx]
    feature_list = []

    if not token:
        return feature_list
    
    # Capitalization
    if token[0].isupper():
        feature_list.append("CAPITALIZATION")

    # Number
    if re.search(_pattern, token) is not None:
        feature_list.append("HAS_NUM")

    # Punctuation
    punc_cat = set(["Pc", "Pd", "Ps", "Pe", "Pi", "Pf", "Po"])
    if all(unicodedata.category(x) in punc_cat for x in token):
        feature_list.append("PUNCTUATION")

    # Suffix up to length 3
    if len(token) > 1:
        feature_list.append("SUF_" + token[-1:])
    if len(token) > 2:
        feature_list.append("SUF_" + token[-2:])
    if len(token) > 3:
        feature_list.append("SUF_" + token[-3:])
        
    feature_list.append("WORD_" + token)
    #print(feature_list)
    return feature_list

# %%
# Train the CRF BIO-tag tagger
TAGGER_PATH = "crf_nlu.tagger"  # path to the tagger- it will save/access the model from here
ct = CRFTagger(feature_func=get_features)  # initialize tagger with get_features function

print("training tagger...")
ct.train(training_data, TAGGER_PATH)
print("done")


# load tagger from saved file
ct = CRFTagger(feature_func=get_features)  # initialize tagger
ct.set_model_file(TAGGER_PATH)  # load model from file

# prepare the test data:

x_test = [preProcess(example) for example in x_test]
print(len(x_test), "instances")
print(sum([len(sent) for sent in x_test]), "words")


print("testing tagger...")
preds = []
y_test = []
length = 0
for sent in x_test:
    sent_preds = [x[1] for x in ct.tag([s[0] for s in sent])]
    sent_true = [s[1] for s in sent]
    preds.extend(sent_preds)
    y_test.extend(sent_true)
print("done")
# Out:
# training tagger...
# done
# 1564 instances
# 31304 words
# testing tagger...
# done

# %%
# Output the classification report (which you should save each time for comparing your models)
print(classification_report(y_test, preds))
print(precision_recall_fscore_support(y_test, preds, average='macro'))  # print out accurate macro score
# Out:
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                   precision    recall  f1-score   support
#
#          B-Actor       0.87      0.87      0.87      1231
#          B-Award       0.76      0.60      0.67        75
# B-Character_Name       0.63      0.12      0.21       212
#       B-Director       0.86      0.67      0.75       472
#          B-Genre       0.86      0.78      0.82       805
#        B-Opinion       0.48      0.24      0.32       160
#         B-Origin       0.57      0.43      0.49       159
#           B-Plot       0.49      0.46      0.47      1221
#          B-Quote       0.67      0.17      0.27        24
#   B-Relationship       0.81      0.40      0.53       125
#     B-Soundtrack       0.00      0.00      0.00        13
#           B-Year       0.97      0.99      0.98       703
#          I-Actor       0.89      0.84      0.87      1731
#          I-Award       0.79      0.81      0.80       202
# I-Character_Name       0.59      0.12      0.19       165
#       I-Director       0.86      0.66      0.74       456
#          I-Genre       0.79      0.74      0.76       576
#        I-Opinion       0.07      0.10      0.08        84
#         I-Origin       0.66      0.71      0.68       729
#           I-Plot       0.84      0.95      0.89     11448
#          I-Quote       0.56      0.19      0.28       176
#   I-Relationship       0.61      0.40      0.48       240
#     I-Soundtrack       0.00      0.00      0.00        41
#           I-Year       0.77      0.82      0.79        33
#                O       0.86      0.83      0.85     10223
#
#         accuracy                           0.83     31304
#        macro avg       0.65      0.51      0.55     31304
#     weighted avg       0.82      0.83      0.82     31304
#
# (0.6501291230396969, 0.5148784478638774, 0.5519308967692744, None)
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
def confusion_matrix_heatmap(y_test, preds):
    """Function to plot a confusion matrix"""
    labels = list(set(y_test))   # get the labels in the y_test
    # print(labels)
    cm = confusion_matrix(y_test, preds, labels)
    fig = plt.figure(figsize=(20,20))
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title('Confusion matrix of the classifier')
    fig.colorbar(cax)
    ax.set_xticks(np.arange(len(labels)))
    ax.set_yticks(np.arange(len(labels)))
    ax.set_xticklabels( labels, rotation=45)
    ax.set_yticklabels( labels)

    for i in range(len(cm)):
        for j in range(len(cm)):
            text = ax.text(j, i, cm[i, j],
                           ha="center", va="center", color="w")

    plt.xlabel('Predicted')
    plt.ylabel('True')
    #fig.tight_layout()
    # fix for mpl bug that cuts off top/bottom of seaborn viz:
    b, t = plt.ylim() # discover the values for bottom and top
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t) # update the ylim(bottom, top) values
    plt.show() # ta-da!
    
    
confusion_matrix_heatmap(y_test, preds)
# Out:
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=['I-Quote', 'B-Origin', 'I-Plot', 'I-Relationship', 'B-Soundtrack', 'B-Quote', 'B-Director', 'I-Actor', 'B-Year', 'B-Genre', 'B-Opinion', 'B-Actor', 'I-Genre', 'I-Year', 'I-Origin', 'I-Soundtrack', 'I-Director', 'B-Relationship', 'I-Character_Name', 'O', 'B-Award', 'B-Character_Name', 'B-Plot', 'I-Award', 'I-Opinion'] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %% [markdown]
# # 2. Error analysis 1: False positives
#
# Performing error analyses is a key part of improving our NLP applications. For the 5 classes which have the lowest precision, according to the results table from our 20% development data, print out all the sentences where there is a false positive for that class (i.e. the label is predicted in the predicted label for a given word by the tagger, but this is not present in the corresponding ground truth label for that word).

# %%
import itertools
output = (classification_report(y_test, preds, output_dict = True))
#print(output)
sorted_dict = {}
sorted_dict2 = {}
sliced_dict = {}

for key,value in output.items():   #Extracting the precision column from the dictionary
    if type(value) == dict:
        if (key != "macro avg") and (key!= "weighted avg"):
            sorted_dict.__setitem__(key,value['precision'])

sorted_dict2 = sorted(sorted_dict.items(), key=lambda x: x[1])
#print(sorted_dict2)
sliced_dict = dict(itertools.islice(sorted_dict2, 5))
print(sliced_dict)

list1=[]
for x in list(sliced_dict):
    list1.append(x)
#print(list1)

abc = []
fp_sentences = []

for sent in x_test:
    sent_preds = [x[1] for x in ct.tag([s[0] for s in sent])]
    sent_true = [s[1] for s in sent]
    for s in range(0,len(sent)):
        if (sent_preds[s]!=sent_true[s]):
            for i in range(0,len(list1)):
                if (sent_preds[s]==list1[i]):
                    if sent not in abc:
                        abc.append(sent)
    
print(len(abc))
print("The sentences with false positives for the given 5 classes with lowest precision are: \n")   
for i in abc:
    #print(i)
    for j in i:
        print(j[0], end = ' ')
        fp_sentences.append(j[0])
    print("\n")
# Out:
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'B-Soundtrack': 0.0, 'I-Soundtrack': 0.0, 'I-Opinion': 0.07272727272727272, 'B-Opinion': 0.4810126582278481, 'B-Plot': 0.4868881118881119}
# 620
# The sentences with false positives for the given 5 classes with lowest precision are:
#
# on a vacation in paris one of three travelers is mistaken for a british heiress
#
# one of the first disney animated films with beautiful images few lines and a lot of music
#
# orson welles directed and starred in this 1965 movie about the career of shakespeare s sir john falstaff as roistering companion to young prince hal
#
# orson wells psychological profile of an eccentric billionaire has been voted the greatest movie of all time by some
#
# paul giamatti and thomas haden church are two men reaching middle age with not much to show but disappointment in this 2004 comedy romance movie
#
# paul newman starred in this 1977 hockey movie about the struggles of a minor league team
#
# perseus mortal son of zeus battles the minions of the underworld to stop them from conquering the earth and the heavens in this 2010 action adventure fantasy
#
# peter hedges directed this charming fantasy based on the story by ahmet zappa about a boy who joins a family by rather unusual means
#
# peter jackson directed this smash hit starring jack black as a 1930 s film maker on a mission to make an unforgettable nature documentary who gets more than he bargained for
#
# peter sellers is a lowly gardener who s simple utterances are mistaken for profound wisdom in this 1979 comedy
#
# phoebe cates famously rose from the pool removing her red bikini top while sean penn was a stoned spicoli in this 1982 comedy
#
# play it again sam is one of the memorable quotes from this classic humphrey bogart romance
#
# rapunzel is having a bad hair day she s out of the tower and off to discover life in this 2010 animated feature
#
# ray liotta robert de niro and joe pesci star in this film about gangsters in organized crime
#
# red riding hood is training in the group of sister hoods when she and the wolf are called to examine the sudden mysterious disappearance of hansel and gretel in this animated feature
#
# remember that movie where the lion ruled the jungle and his brother turned on him
#
# renoir s look at bourgeois life in france at the onset of world war ii is the plot of this 1939 comedy drama
#
# richard gere took tap dance lessons for three months to prepare for his role as the criminal defense attorney billy flynn in this 2002 musical
#
# robert de niro is a former prohibition era jewish gangster who returns to brooklyn over 30 years later in this 1984 crime drama
#
# robert de niro walked away with the oscar for his role of a boxer who ca n t control his temper in this 1980 sports drama directed by martin scorsese
#
# robert downey jr and zach galifinakis star this comedy about a man traveling with an obnoxious road mate to see his wife before she delivers their child
#
# romance movie based off of nicholas sparks novel about a marine finding the woman who saved him
#
# rufus t firefly is named president dictator of bankrupt freedonia and declares war on neighboring sylvania over the love of wealthy mrs teasdale is the plot of this classic comedy starring all three of the marx brothers
#
# russell brandt starred as the title character in this most recent adaption of steve gordon s story about a rich drunken playboy who falls in love with a penniless girl
#
# russell crowe stars in this drama about a intelligent man that accepts secret work but his life turns for the worst
#
# ryan o neal ca n t seem to keep out of trouble whenever barbra streisand is around in this 1972 comedy
#
# samuel l jackson narrates this 2011 nature documentary about the king of the jungle raising cubs in the wild
#
# sequel to the popular film starring tiny singing critters
#
# sequel to the popular story of entering a strange world through a wardrobe
#
# set in 1825 a man is captured by indians but eventually becomes the leader of the tribe
#
# stacy keach and james keach play frank and jesse james in this 1980 western about the outlaws and their gang
#
# stanley kubrick directed this 1968 science fiction classic starring keir dullea gary lockwood and hal the computer
#
# steve carell starred in this animated movie about a lovable villain with thousands of tiny henchmen
#
# steven spielberg directed this 2011 drama about a man who enlists in the army when his beloved steed is taken into the cavalry
#
# steven spielberg personally screened this 1982 film at the white house for ronald reagan and nancy davis
#
# stopped they must be on this all depends only a fully trained jedi knight with the force as his ally will conquer vader in this 1980 george lucas sequel
#
# superhero movie where team of superheros get together to defeat threats too big for just one hero
#
# susan sarandon won an oscar for her role as a nun who develops a special relationship with a prisoner in this drama based on the novel by helen prejean
#
# tattooine is the home planet for a certain hero in this famous trilogy which is set in a distant galaxy
#
# the bellas take on their male rivals in a campus competition in this 2012 comedy musical
#
# the classic scene between burt lancaster and deborah kerr in the rushing water on the beach was a last minute inspiration from the director fred zinnemann in this romantic drama
#
# the debut movie of the famous director kevin smith featuring his breakout characters jay and silent bob
#
# the film i m thinking of is a romantic comedy starring jason segel and emily blunt as a couple whose relationship begins to deteriorate the more they put off their wedding
#
# the last part of a vampire love story between bella and edward
#
# the lesson of this disney story is do n t talk to strangers and do n t take short cuts
#
# the main character of this animated film is a fiery red haired princess who loves archery and has mom issues
#
# the movie about the famed english hero who steals from the rich and gives to the poor
#
# the movie about the high school girl who lies about a date and losing her virginity she rides off on a lawnmower with the guy she likes at the end
#
# the movie adaptation of a high school singing group that brought the fox show into 3 dimensions
#
# the movie starring emma stone who pretends to be a slut to become more popular at school
#
# the movie where marty mcfly and doc brown go back in time and have to get marty s mom to marry his dad
#
# the movie where two geeks played by simon pegg and nick frost on their way to comic con meet an alien
#
# the name of this classic movie is the same as the now famous monster a giant beast that wrecks tokyo
#
# the producer of this movie was shaken down for a contribution to the campaign of the now convicted felon and former illinois governor rod blagojevich
#
# the referee in the final match in this 1984 martial arts movie starring ralph macchio is pat e johnson a martial arts expert and former student of chuck norris
#
# the script was originally written as a sequel to l on the professional and would have focused on natalie portman s character mathilda but was later changed to star a main character with south american background
#
# the second to last movie about a boy wizard and his quest to destroy the most dangerous wizard alive
#
# the sequel to a popular children s movie about talking motor vehicle
#
# the story of t e lawrence a flamboyant and controversial british military figure and his conflicted loyalties during his world war i service in the middle east staring peter o toole
#
# the tagline for the final installment of this 2010 dreamworks animation film was it aint ogre til it s ogre
#
# the true story of a horse that defied expectations and now works for craig ferguson
#
# thinking of a 1939 blockbuster about love and war
#
# third series of animated movie that focuses on zoo animals who have escaped from the nyc zoo
#
# this 1954 classic stars marlon brando as a dockworker that witnesses a murder orchestrated by corrupt union bosses
#
# this 1960 thriller is a black and white hitchcock classic that features a famous shower murder scene
#
# this 1970 film stars george c scott as the titular u s general from world war 2
#
# this 1973 horror classic is well known for it s famous 360 degree head spin scene
#
# this 1974 film by mel brooks is about a doctor s grandson and his assistant igor who decides to repeat his grandfather s experiments with hilariously disastrous results
#
# this 1976 classic was written by and stars sylvester stallone as a boxer who tries to become a heavyweight champion
#
# this 1979 vision of post apocalypse australia stars mel gibson as the title character on his quest for vengeance
#
# this 1990 film starred kevin costner as a civil war soldier and won numerous academy awards
#
# this 1990 s animated feature taught us the song hakuna matata which championed a down to earth problem free philosophy
#
# this 1997 animated film directed by hayao miyazaki helped popularize anime in the united states
#
# this 1997 blockbuster revolves around a famous maritime tragedy in which an ocean liner strikes an ice berg
#
# this 2010 american supernatural horror film starred sprague grayden as kristi and molly ephraim as ali
#
# this 2010 drama romance starring julia roberts is about a woman who realizes her life needs a different direction
#
# this 2010 romantic comedy film featured cameos from multiple nba players including rajon rondon and dwight howard
#
# this 2011 adventure stars asa butterfield trying to find secrets his father left him
#
# this 2011 comedy film starred steve martin jack black and owen wilson as bird enthusiasts
#
# this 2011 film stars joseph gordon levitt as a young adult who learns that he has cancer
#
# this 2011 film was based on a comic book character whose job it is to police the galaxy
#
# this 2011 superhero movie stars seth rogen as an unlikely hero who starts a crime fighting career with the help of his father s assistant kato
#
# this 2012 action adventure film was a unique twist on an old fairy tale
#
# this 2012 comedy from seth macfarlane has a main character also voiced by macfarlane who is a stuffed animal
#
# this 2012 film features real united states navy seals and their attempts to recover a kidnapped cia agent
#
# this 2012 kung fu film was written and directed by and stars hip hop legend rza as a man who must fight evil men who threaten the safety of his town
#
# this 2012 movie of a classic dr seuss book is about a mustached creature that tries to protect the trees
#
# this 942 american biographical musical film about george m cohan known as the man who owns broadway
#
# this action film features aaaron johnson as a high school student turned vigilante nicholas cage and chloe moretz are also featured as big daddy and hit girl
#
# this action packed sequel stars arnold schwarzenegger as a robot sent back in time this time to protect young john connor
#
# this action packed shooter is the story of man whose life is changed by one little pill after taking this pill he is launched into a world of fighting where reality is not what it seems this film features star keanu reeves
#
# this alfred hitchcock film includes a motel manager norman bates in an infamous shower scene
#
# this ambitious 2012 film from the wachowski siblings is based on a book that interweaves six different narratives to tell a tale about how all life is connected
#
# this american film features single serving friends power animals project mayhem and jack s raging bile duct
#
# this animated sequel features ben stiller as alex the lion and his continuing adventures in africa
#
# this black and white comedy directed by mel brooks stars gene wilder and peter boyle and features the classic song puttin on the ritz
#
# this children s movie is about a young boy named greg heffley who enters the sixth grade and tries to make it through the school year unscathed
#
# this classic 1938 warner bros gangster picture stars james cagney pat o brien humphrey bogart and the dead end kids
#
# this classic gangster film directed by francis ford coppola shows the inner workings of the corleone crime family
#
# this classic sequel features a robot from the future who battles an even more powerful robot from the future
#
# this classic silent horror film from 1922 stars max schrek as the title villain and monster
#
# this comedy features anna kendrick and brittany snow as college students who participate in the competitive sport of a capella singing groups
#
# this comedy stars paul rudd as a man who recruits an idiot steve carell to come with him to his company s annual contest
#
# this computer animated film stars johnny depp as a timid chameleon who finds courage in the desert
#
# this computer animated comedy features the voice of steve carrell as the villainous but likeable gru
#
# this crime film from martin scorcese is about two men one a cop that goes undercover in a gang the other a member of the gang who goes undercover as a cop
#
# this disney film follows the adventures of a dog who befriends a family but then suffers tragically
#
# this disney princess pricks her finger on a spinning wheel needle and sends the entire kingdom into a deep slumber until her prince arrives with the kiss to wake her
#
# this famous musical takes place in new york city where two teenage gangs struggle for control of the neighborhood
#
# this film celebrated the famed 1980 u s hockey team and their victory over the soviet union
#
# this film directed by ben affleck tells the story of a band of men who go through boston with just their guns and their skills robbing banks and armored vehicles and not letting anything get in the way that is until they take a hostage
#
# this film looks at paranormal happenings in a former soviet republic
#
# this film showed a more feminine side of adam sandler who played himself and his twin sister
#
# this finale finally tells the true story of a potions professor who apparently despises the protagonist
#
# this holiday classic involves a man who changes his ways after he is visited by ghosts on christmas eve
#
# this horror is the exact middle movie of a series featuring a deplorable puppet
#
# this horror movie features one of the most famous villains in the genre who kills victims in their nightmares with his signature bladed hands
#
# this horror movie takes place at a summer camp and spawned a series of movies about a gruesome killed named jason
#
# this iconic science fiction space opera features one of the main characters being frozen in carbonite
#
# this is one of the most famous kung fu movies of all time about two warriors in pursuit of a stolen sword
#
# this is the fifth movie in a series of films that focus on illegal street racing
#
# this is the first part of the epic conclusion to an 8 part movie series about a boy wizard fighting the forces of evil
#
# this is the movie that made tim burton famous and put and combined two famous holidays
#
# this japanese anime set in shattered neo tokyo includes several old children who battle with telekinesis and telepathy
#
# this marvel superhero film assembles captain america iron man thor and the hulk to battle an evil being named loki
#
# this mel brook s classic takes place in the wild west and a small town is in chaos after a black sheriff comes town
#
# this modern batman film pits batman against bane and catwoman in a besieged new york city
#
# this modern crime film features robert downey jr as a bumbling crook caught up in a mystery alongside val kilmer as private investigator gay perry
#
# this modern version of an 80 s classic features an old jeff bridges and a well animated young jeff bridges
#
# this movie based on a famous j r r tolkein book is the first in a film trilogy featuring hobbits orcs and elves
#
# this movie features scientifically inaccurate but scary and intense recreations of a past extinct species
#
# this movie is a comic book adaptation of one of the first comic book heroes set mainly during world war 2
#
# this movie is a one word three letter title that is the first word of the river bordering texas and mexico
#
# this movie is about a civil war veteran that is transported off earth to another planet where he is found to have superhuman abilities based on the reduced gravity
#
# this movie is about a lone avatar who has the power to manipulate all four elements he teams up with katara who is a waterbender
#
# this movie is about a man who becomes tired with his mundane life and tries to find a way to break out only to discover his life is not real and once in the real world that he may be the savior the world has been expecting
#
# this movie is based on actual events where a young girl is involved in a shark attack
#
# this movie on my mind is a spoof of the vampire love story genre type movies
#
# this noir film was directed by roman polanski and featured jack nicholson as a private investigator
#
# this pixar film features and old man who attaches thousands of balloons to his house
#
# this reboot of a classic comicbook group features the younger versions of mutants including james mcavoy
#
# this recent thriller portrays a blonde young girl as a killer trained in the wilderness by her father
#
# this road trip comedy features robert downey jr and zach galifianakis as an unlikely pair traveling across the country
#
# this rockumentary from director rob reiner chronicles the misadventures of a fictional heavy metal band turn it up to 11
#
# this romance film stars julia roberts as a woman traveling around europe in an attempt to improve her life
#
# this russel crowe drama follows the story of a mathematician whose life is destroyed by paranoid schizophrenia
#
# this scary movie is named about a street and the horrible things that happen when you have a bad dream
#
# this sci fi hit stars keanu reeves as the one who will save humanity from their enslavement by the machines
#
# this stop motion animated feature directed by henry selick shows the adventures of jack skellington who tries to spread the magic of christmas
#
# this summer love story not only brought their characters together in the movie but also brought miley cirus and liam hemsworth together in real life
#
# this surreal romp from 1967 stars the beatles and features some of their famous hit songs
#
# this suspense film starred amanda seyfried as a young woman who escaped a murderer and has to find him to save her sister
#
# this tragedy written by william shakespeare centers on the prince of denmark who is driven mad by his own desire for revenge against his murderous uncle
#
# this was the first movie produced by pixar to be rated below 50 percent on the popular movie review site rotten tomatoes
#
# this was the movie that macaulay culkin was watching in the scene in home alone when the pizza boy arrived
#
# this zombie thriller directed by george a romero set the stage for the modern zombie movie scene and is considered to be one of the greatest horror movies of all time
#
# vin diesel and his gang are planning a massive heist to buy their freedom while in the sights of a powerful brazilian drug lord and a dangerous federal agent in the 2011 installment of this movie series
#
# vin diesel is the voice of an alien robot that a young boy is trying to save from being destroyed by the government in this 1999 animated feature
#
# wes anderson s adaptation of roald dahl s popular children s book about a fox who must help his friends and family survive the onslaught of local farmers
#
# what s that kevin smith movie with bruce willis where he s searching for a rare baseball card
#
# what s that movie where all of the zoo animals join the circus and perform in front of a giant crowd in stunning fashion
#
# what s that newer movie that quentin tarantino put out i think it has rza fighting kung fu style
#
# what s that stop animation movie with the creepy dolls with button eyes she travels to an alternate universe where her mother seems nice but is evil
#
# what s that stupid overrated movie about interplanetary fighting there are jedis and one of the main characters is harrison ford
#
# what s that sweet animated movie with the lizard voiced by johnny depp it has an awesome reference to fear and loathing at the beginning
#
# what s the 2011 movie with rob pattinson about a man who runs away with the circus and falls in love with the boss wife
#
# what s the classic film where brando tells his backstabbing brother that he could ve been a contender
#
# what s the film classic about a group of men who drive highly explosive material a long distance
#
# what s the italian film that is made up of cartoons set to classical music a la fantasia
#
# what s the movie based on a shakespeare play where the moor of venice doubts the virtue of his wife
#
# what s the movie based on a true story about the mod s involvement in the history of las vegas
#
# what s the movie i always confuse with goodfellas its by the same director and its about gangsters running gambling in las vegas
#
# what s the movie starring nathan lane and matthew broderick in which the intentionally try to create the worlds worst play
#
# what s the movie that has a main cast of nothing but girls in a mental institute who live in an alternate reality and stars emily browning and vanessa hudgens
#
# what s the movie where a film crew stumbles on a heck of a big monkey
#
# what s the movie where brad pitt and morgan freeman track a moralistic killer in chicago
#
# what s the movie with john wayne where you re not sure if he s going to rescue or kill a girl
#
# what s the movie with russell crowe playing a genius mathematician who gets a job in cryptography
#
# what s the name of that famous marlon brando film where he says i coulda been a contender
#
# what s the name of that martial film by ang lee where chow yun fat hunts for a sword in the hands of ziyi zhang
#
# what s the name of that movie that has guy in the wheelchair and that actress from aliens and they re on an alien planet that s full of animals and plants
#
# what s the name of the classic movie where no one believes the guy who claims to be santa claus
#
# what s the name of the comedy where jennifer anniston plays a sexually deviant character
#
# what s the name of the movie where a giant green lizard goes on a rampage in a city
#
# what s the one with that guy from the matrix and the girl from titanic where they try to save the world
#
# what s the recent movie in which amy adams is the estranged adult child of clint eastwood s character who is heavy into the baseball world and she meets a guy along the way
#
# what s the true life movie starring johnny depp about the ringleader of a massive drug cartel
#
# what s the ultra violent chinese film that ends in a prolonged shootout between cops and bad guys in a hospital
#
# what s the violent movie where ryan goslin does all sorts of nasty stuff to bad guys to protect a wife and kid
#
# what 1930 ernst lubitsch film starring jeanette macdonald took place in a famous european gambling city and featured the song beyond the blue horizon
#
# what 1931 film featured a man hunt in germany for a child killer aided by police and other criminals alike
#
# what 1931 movie depicts the creation of an monster made up of parts of dead people
#
# what 1937 french war film is directed by jean renoir and about french officers attempting to escape pow camp
#
# what 1938 howard hawks romantic comedy starred katharine hepburn cary grant charles ruggles and barry fitzgerald
#
# what 1939 frank capra drama stars james stewart jean arthur claude rains edward arnold and thomas mitchell
#
# what 1939 victor fleming movie centers around a girl named dorothy who gets swept away to a magical land
#
# what 1940 dramatic movie depicted a poor midwest family that is forced off their land
#
# what 1941 john huston crime drama starred humphrey bogart mary astor peter lorre and gladys george
#
# what 1941 orson welles movie garnered him an oscar for best writing along with writing partner herman j mankiewicz
#
# what 1942 best picture oscar winning film was set in unoccupied africa during the early days of world war ii
#
# what 1942 movie garnered a best music original song oscar win to irving berlin for his song white christmas
#
# what 1945 movie centered around a woman who is tempted to cheat on her husband with a stranger in a railway station
#
# what 1946 john huston documentary marked the final entry in a trilogy of films he produced for the u s government
#
# what 1948 film centers around a man driving his cattle when his adopted son turns against him
#
# what 1949 george cukor romantic comedy centered around a husband and wife working as opposing lawyers in a case involving a woman who shot her husband
#
# what 1950 joseph l mankiewicz movie garnered a total of six oscar wins including best writing and best directing for mankiewicz and best picture
#
# what 1951 george stevens movie centers around a poor boy working for his rich uncle and ends up falling in love with two women
#
# what 1954 elia kazan crime movie depicted an ex prize fighter turned longshoreman struggling to stand up to corrupt union bosses
#
# what 1957 king vidor movie starring audrey hepburn and henry fonda centered around napoleon s tumultuous relations with russia
#
# what 1960 french horror film directed by georges franju created massive controvery upon its release
#
# what 1960 stanley kubrick biopic centered around a slave that leads a violent revolt against the decadent roman republic
#
# what 1962 david lean biopic tells the story of a flamboyant and controversial british military figure
#
# what 1965 cartoon is a timeless classic starring the lovable charlie brown and his dog snoopy
#
# what 1965 musical based on a rogers and hammerstein musical of the same name features the von trapp family singers
#
# what 1966 sergio leone western adventure movie featured clint eastwood and eli wallach in a bounty hunting scam
#
# what 1967 musical comedy follows the adventures of the beatles on a special charter bus
#
# what 1970 movie takes place in 1825 and centers around an english aristocrat who is captured by indians
#
# what 1970 robert altman movie about the korean war spawned a long running television series
#
# what 1972 movie starred john wayne roscoe lee browns bruce dern colleen dewhurst and alfred barker jr
#
# what 1972 romantic comedy centered around the accidental mix up of four identical overnight bags
#
# what 1973 francois truffaut romantic comedy starred jacqueline bisset and jean pierre leaud and valentina cortese
#
# what 1974 american comedy film directed by mel brooks was a parody of the classical frankenstein horror fim
#
# what 1974 billy wilder movie starred jack lemmon walter matthau susan sarandon and vincent gardenia
#
# what 1974 stop motion animated tv special features kris kringle running into the heater miser
#
# what 1976 richard donner horror film featured gregory peck as an american ambassador and lee remick as his wife
#
# what 1976 western centered around a dying gunfighter spending his last days looking for a way to die with dignity
#
# what 1977 george lucas sci fi movie featured mark hamill harrison ford carrie fisher and alec guinness
#
# what 1977 steven spielberg sci fi adventured found richard dreyfuss making a mountain out of mashed potatoes
#
# what 1979 movie stars jon voight as an ex boxer who works as a horse trainer and raises his son
#
# what 1979 ridley scott sci fi horror movie featured sigourney weaver as part of a commercial deep space mining ship crew
#
# what 1980 american film featured a single woman moving to san fransisco during the holidays whil trying to get her life back togeather after a divorce
#
# what 1980 harold ramis sport comedy takes place at an exclusive golf course that has a dancing gopher
#
# what 1982 horror film centers around a man who seeks vengeance against the doctors who separated him against his will from his siamese twin brother
#
# what 1982 ridley scott sci fi flick stars harrison ford as a man who has to track down and terminate 4 replicants
#
# what 1983 harold ramis comedy finds the griswold family cross country driving to theme park walley world
#
# what 1984 barry levinson sport drama centered around an average baseball player out of nowhere to become a legendary player
#
# what 1984 historical biopic centered around a photographer trapped in cambodia during a violent time
#
# what 1984 james cameron film depicted a robotic assassin from a post apocalyptic future sent back in time to eliminate a waitress
#
# what 1984 james cameron film starring arnold schwarzenegger has spawned three sequels and a television program
#
# what 1985 harold becker coming of age movie finds a high school student wanting to be something more
#
# what 1986 sports movie featured gene hackman as a coach of a high school team
#
# what 1987 brian depalma film features kevin costner as federal agent eliot ness out to stop al capone
#
# what 1987 stanley kubrick film showed what it s like to be in the u s marine bootcamp
#
# what 1988 gary marshall chick flick centered around a rich debutante and a cynical entertainer who share an enduring childhood friendship through the years
#
# what 1988 ron howard movie shows a reluctant dwarf playing a critical role in protecting a special baby
#
# what 1990 american crime film featured the famous story of the rise and fall of the lucchese crime family
#
# what 1990 jeannot szwarc film centered around a chicago playwright who uses self hypnosis to find the actress whose vintage portrait hangs in a grand hotel
#
# what 1990 martin scorsese biopic centers around henry hill and his friends as they work their way up through the mob hierarchy
#
# what 1990 sci fi flick centers around a man in the future who goes in for virtual vacation memories but then faces unforeseen consequences
#
# what 1990 tim burton film featured johnny depp as a hairstylist and hedge trimmer and winona ryder as his love interest
#
# what 1991 animated disney movie tells the tale of a love story between two unlikely lovers
#
# what 1992 neil jordan dramatic movie centered around a british soldier kidnapped by ira terrorists
#
# what 1993 drama film directed by steven speilberg featured liam neeson as schindler in nazi germany
#
# what 1993 jane campion romantic drama centered on a mute woman lusted after by a local worker
#
# what 1993 wayne wang film shared the life histories of four asian women and their daughters
#
# what 1994 james cameron film was partially shot on location in the florida keys u s a
#
# what 1994 jan de bont thriller centered around a young cop who tries to keep a bomb on a bus from exploding
#
# what 1995 chick flick starred clint eastwood as photographer robert kincaid and meryl streep as his short lived love interest
#
# what 1995 family film centers around a pig raised by sheep dogs with a little help from farmer hoggett
#
# what 1995 martin scorsese biopic centered around greed deception money power and murder between two mobster best friends
#
# what 1995 movie centers on a man on the run after committing murder who takes a journey into the spiritual world
#
# what 1996 billy bob thornton movie centered around a lifelong hospitalized man who is released to start a new life in a small town
#
# what 1997 hit contained the famous quote i m the king of the world
#
# what 1997 james cameron film featured leonardo dicaprio exclaiming i m the king of the world
#
# what 1999 action flick starred brad pitt and edward norton and also had the famous musician meat loaf
#
# what 1999 film stars nicholas cage as an ambulance paramedic struggling to keep his sanity
#
# what 1999 movie found haley joel osment as cole sear a boy who communicated with spirits
#
# what 2001 pixar animated movie stars kevin spacey as the voice of a misfit ant
#
# what 2005 documentary tells the story of danny trejo from his troubled childhood through present day
#
# what 2005 james mangold biopic centered around the lives of johnny cash and june carter cash
#
# what 2005 ron howard biopic tells the story of james braddock a washed up boxer who came back to become a champion
#
# what 2006 movie takes place in turn of the century vienna where a magician uses his abilities to secure the love of a woman
#
# what 2007 biopic is about the story of jean dominique bauby and his trouble with locked in syndrome
#
# what 2007 parody comedy made fun of everyone from the jonas brothers tiger woods and the twilight series
#
# what 2008 disney pixar classic shows the adventure of a lonely waste collecting robot who goes on a journey in outer space
#
# what 2008 japanese animated fantasy film written and directed by hayao miyazaki is about brunhilde the fish girl
#
# what 2009 horror film takes place in the year 2019 when a plague has transformed almost every human into vampires
#
# what 2010 action adventure comedy stars tom cruise as a troubled spy
#
# what 2010 american supernatural film featured a group of strangers including arch angel micheal fighting for the fate of humanity
#
# what 2010 brian levant film starred jackie chan amber valletta billy ray cyrus and madeline carroll
#
# what 2010 drama centered on the efforts of joan and aileen crowley to find a researcher who might develop a cure for their children s rare genetic disorder
#
# what 2010 horror sequal shows the haunting of a home in carlsbad california
#
# what 2010 movie centers around a cia special forces team that was betrayed and left for dead by their superiors
#
# what 2010 movie features the story of a 1973 triple crown winner
#
# what 2010 movie finds superhero alter ego tony stark once again battling evil and saving the day
#
# what 2010 paul w s anderson movie features milla jovovich out to destroy the umbrella corporation
#
# what 2010 romantic comedy starred america ferrera forest whitaker carlos mencia lance gross and regina king
#
# what 2010 romantic crime drama features russell crowe and elizabeth banks as a married couple
#
# what 2010 sequel does michael douglas reprise his role as gordon gekko the infamous broker who coined greed is good
#
# what 2010 spy comedy film featuring jackie chan who plays a retired spy and falls in love with his next door neighbor
#
# what 2010 thriller set in 1954 finds u s marshal teddy daniels investigating the disappearance of a murderess who escaped a mental hospital
#
# what 2011 action film featured a futuristic holy man battling vampires on behalf of a totalitarion organization known as the church
#
# what 2011 cameron crowe family film set in southern california depicts a father moving his young family to the countryside
#
# what 2011 cameron crowe family film starred matt damon scarlett johansson and thomas haden church
#
# what 2011 crime drama centered around ryan gosling playing a mysterious hollywood stuntman and mechanic
#
# what 2011 crime movie features ryan phillippe as louis roulet a man with a foolproof plan to beat the system
#
# what 2011 farrelly brothers romantic comedy centers around two husbands having difficulties in their marriages
#
# what 2011 gary mckendry thriller features jason statham clive owen robert deniro and dominic purcell
#
# what 2011 horror movie featured an american seminary student who travels to italy to take an exorcism course
#
# what 2011 independent horror film stars elizabeth olsen and is about a girl haunted by her parent s abuse
#
# what 2011 j j abrams sci fi thriller finds a group of friends witnessing a train crash during the summer of 1979
#
# what 2011 movie finds an aspiring author detailing the african american maids point of view on white families during the 1960 s
#
# what 2011 movie stars bradley cooper as writer eddie morra who discovers a top secret drug
#
# what 2011 romantic comedy centers around a husband s life change after his wife asks him for a divorce
#
# what 2011 sci fi action movie features justin timberlake and amanda seyfried in a future where people stop aging at 25
#
# what 2011 sci fi flick starred ryan reynolds blake lively peter sarsgaard mark strong and tim robbins
#
# what 2011 sci fi thriller had the tag line there s a reason we ve never gone back to the moon
#
# what 2011 superhero film involves the god of thunder being striped of his power and exiled to earth
#
# what 2011 thriller based on a fairy tail features a young woman named valerie and her love peter
#
# what 2011 thriller centered around character dominic toretto and his crew of street racers planning a massive heist
#
# what 2012 action drama centered on a young cia agent tasked with looking after a fugitive
#
# what 2012 action movie depicted a homicide detective pushed to the brink of his moral and physical limits
#
# what 2012 ben affleck movie depicts a dramatization of the 1980 operation to free american hostages in iran
#
# what 2012 comedy centered around a high school biology teacher who looks to become a successful mixed martial arts fighter
#
# what 2012 film by peter jackson goes back to the original story of bilbo told by j r r tolkien
#
# what 2012 horror movie features elisabeth shue as a mother to jennifer lawrence who move to a new town
#
# what 2012 martial arts film starring russell crowe was directed by rapper and music producer the rza
#
# what 2012 mcg romantic comedy centers around two top cia operatives who wage an epic battle against each other when they discover they are dating the same woman
#
# what 2012 robert zemeckis drama centered around an airline pilot who saves a flight from crashing
#
# what 2012 sci fi movie featuring joseph gordon levitt and bruce willis had the tag line face your future fight your past
#
# what 2012 science fiction movie stars joseph gordon levitt and features assassins who kill their time traveling targets with the blunderbuss
#
# what 2012 thriller depicts a police force in a midwestern town searching for a killer santa claus
#
# what 2012 thriller finds a police psychologist trying to talk down an ex con from jumping off a manhattan hotel while a diamond heist is being committed
#
# what 2012 tyler perry comedy centered around a wall street investment banker who has been set up as the fall guy in his company s ponzi scheme
#
# what 2012 tyler perry movie features thandie newton as a homeless mother working as a cleaning lady
#
# what academy award winning film is based on the story of oakland a s general manager billy beane
#
# what action adventure movie has been remade multiple times and features clark kent and his alter ego the man of steel
#
# what action film depicts the life of a former getaway driver and the things he must to do to finally be free of his past
#
# what action movie featuring clint eastwood as a renegade cop harry callahand making his own rules delivering justice through this 44 magnum revolver
#
# what american super hero film features a alien superhuman with a famous and powerful hammer
#
# what animated classic christmas movie features snoopy and a really pathetic beat up looking christmas tree
#
# what animated film features two warring houses of lawn gnomes that takes a fresh spin on a shakespeare classic
#
# what animated pixar film is about a father clownfish tenaciously following the trail of his fish napped son through the ocean outside of sydney australia
#
# what are the names of the 3 hyenas
#
# what black and white horror movie features the classic monster vampire based on a book by bram stroker
#
# what black and white japanese classic epic features a story about 7 warriors facing unimaginable odds
#
# what blockbuster film stars liam nieson in his heart stopping thriller which takes place in a snowy wasteland
#
# what boxing centric movie inspired the character tag line of italian stallion and inspired legions of fans to workout to the song eye of the tiger
#
# what boxing movie drama tells the story of mickey ward and his narcotic addicted brother dickey
#
# what chick flick did julia louie dreyfus character in seinfeld hate with every fiber of her being
#
# what classic 1941 orson welles film is often considered the greatest movie of all time
#
# what classic 90 s trip shows the misadventures of two druggies trying to find adventure in the city of sin
#
# what classic disney fairy tale focus on a beautiful princess in search for her prince charming with the aide of seven friends
#
# what classic disney film takes place in africa and includes musical pieces such as hakkuna mattata
#
# what classic thriller about an enormous killer shark spawned one of the most popular movie themes of all time
#
# what cold war classic told the story of a small california town whose inhabitants are replaced by emotionless invaders from outer space
#
# what comedy brings together three friends who all work for terrible people in a triple murder plot
#
# what disney pixar hit film from 2006 got a sequel starring the movies slow sidekick mater
#
# what do these things have in common demonic possession eerie music projectile vomiting and divine rituals
#
# what documentary film directed by josh fox helped raise awareness on the subject of fracking
#
# what famous movie with clark gable featured the trials and tribulations of a southern bell during the civil war
#
# what fantasy epic starring val kilmer focuses on a young warrior and his small friend
#
# what film broke global records with its budget and showed people a new universe with a mysterious tree and blue folks
#
# what film directed by david fincher tells of mark zuckerberg s rise to power and the creation of facebook
#
# what film follows the adventures of a high school student and an eccentric scientist as they use a delorean time machine to time travel
#
# what film introduced the knives for fingers character of freddy krueger that haunts the dreams of teenagers eventually killing them
#
# what film involves time traveling killer robots sent into the past to assassinate the parents of future enemies
#
# what film released in 2000 stars vin diesel and ben affleck working in a less than legal broker firm
#
# what film starred keanu reeves and become a box office hit despite the fact that will smith was originally targeted to star
#
# what film stars jesse eisenberg and aziz ansari and is about a young man who is draped in explosives and forced to rob a bank
#
# what gary marshall film features a large variety of actors and actresses all interacting in separate vignettes around a holiday dedicated to love
#
# what inspirational film includes a story about a young woman who lost her arm doing her favorite sport
#
# what intense gritty 2012 cop drama focuses on the day to day of two los angelos police officers
#
# what is a movie about the holocaust that jerry seinfeld was caught making out with a date in an episode of seinfeld
#
# what is a science fiction comedy animated film by dreamworks involving a human coachroach talking slime a giant woman and others fighting space aliens
#
# what is steven spielberg s masterpiece made in 1982 depicts an alien and it s interactions with a young boy
#
# what is that 1934 film starring roddy mcdowall about the bond between a boy and his beloved dog
#
# what is that 1957 swedish film written and directed by ingmar bergman which is about an old man that tries to remember his past
#
# what is that 1971 dramatic film starring donald sutherland and jane fonda about a detective who solves a missing person case
#
# what is that 1977 american dance film that catapulted john travolta to fame where he plays a very good disco dancer
#
# what is that 1988 documentary film by errol morris about the story of randall dale adams
#
# what is that 1994 american historical drama film directed by robert redford based on richard n goodwin s memoir
#
# what is that 2012 american war movie which starred real life us navy seals and directed by mike mccoy and scott waugh
#
# what is that 2012 sports drama film starring clint eastwood justin timberlake and amy adams which is about an old baseball scout
#
# what is that comedy film starring jon heder in a breakout role as an awkward teen and details his adventures in high school
#
# what is that ensemble movie starring many actors including ashton kutcher zach efron jon bon jovi sofia vergara about what happened the day before the start of a new year
#
# what is that marvel superhero movie starring chris hemsworth as the main character playing a superhero from the far away galaxies
#
# what is that movie 2012 biographical film co directed by curtis hanson about the life of jay moriarty
#
# what is that movie directed and starring ben affleck about a cia agent who has to go to iran in the 70 s and rescue americans and also won an academy award for best director
#
# what is that movie starring adam sandler as a plastic surgeon who tries to win over brooklyn decker but ends up falling in love with jennifer aniston s character instead
#
# what is that movie starring keanu reeves as an lapd cop who has to stop bus from blowing up and also starring sandra bullock
#
# what is that movie starring leonardo di caprio as howard hughes and chronicles his life
#
# what is that movie starring mark wahlberg as a boxer who tries to make it big and also stars christian bale as his drug addicted brother
#
# what is that movie starring paul rudd who has to bring an idiot as a party guest this idiot who is played by steve carrel
#
# what is that quentin tarantino directed movie featuring an ensemble cast including bruce willis as a boxer and samuel l jackson and john travolta as gangsters working for a boss played by ving rhames
#
# what is that quentin tarantino directed movie which came out in 2012 and starring jamie foxx as an escaped slave
#
# what is that romantic comedy film starring jason segel and emily blunt who meet and fall in love with san francisco but then have to endure hurdles in their relationship including moving to michigan
#
# what is that ron howard directed movie where russell crowe plays john nash a very brilliant but troubled mathematician
#
# what is that satire movie the 1999 american comedy film which became a cult classic and starring ron livingston as a disgruntled employee
#
# what is that steven spielberg directed classic movie about an alien that comes to earth and becomes friends with a young boy
#
# what is that supernatural movie where the main character is a woman with impressive firearm skills
#
# what is that woody allen directed movie starring owen wilson as an american man who gets transported to 1920 s paris
#
# what is the 90 s movie featuring arnold schwarzenegger as a secret agent who has never told his wife jamie lee curtis what he does
#
# what is the 1935 american comedy film opera singer riccardo baroni wishes to be just as good as lassparri and hires his best friend to be his manager
#
# what is the 1950 american drama film which stars bette davis as margo channing an aging broadway actress
#
# what is the 1960 comedy drama film written and directed by federic fellini about journalists in rome
#
# what is the 1970 american biographical war film about the life of general patton and set during world war 2
#
# what is the 1982 american drama film starring richard gere as a navy officer candidate and also stars debra winger
#
# what is the 1994 action thriller film starring keanu reeves and sandra bullock that primarily takes place on a runaway bus
#
# what is the 1995 jungle themed comedy that stars robin williams as a small town s only hope against an evil board game
#
# what is the 1995 mel gibson movie about the the scottish revolt against the tyrannical english
#
# ...
#
# what is the name of the movie where ash must battle an army of the dead and retrieve the necronomicon
#
# what is the name of the popular children s movie about the boy who wants to save the killer whale
#
# what is the name of the remake movie starring johnny depp as the kooky man who owns a candy factory
#
# what is the name of the romantic drama starring robert pattinson and reese witherspoon about a veterinary student abandons his studies after his parents are killed and joins a traveling circus as their vet
#
# what is the name of the sequel in which there s a high tech war going on between cats and dogs that humans do n t know about
#
# what is the name of this classic movie set at a remote hotel featuring a typewriter with the words all work and no play make jack a dull boy
#
# what is the name of this classic science fiction film that includes lines like open the pod bay doors
#
# what is the name of this popular dc comic made into a movie where the main hero is able to use and perfect telekinesis through the use of a ring
#
# what is the paul giamatti and george clooney movie about a man who gets taught the lessons of dirty politics on the campaign trail
#
# what is the paul rudd and jennifer aniston comedy about a couple who ends up living on a free love commune
#
# what is the paul rudd movie where he plays a hippie named ned who is trying to raise rent money to return to the farm he lived on prior to going to prison
#
# what is the pg 13 movie that was well known for having a curse word in its name
#
# what is the quentin tarantino and tony scott movie about the southern prostitute and her husband who steal a bunch of cocaine from her pimp
#
# what is the reboot of a popular marvel movie franchise with james mcavoy as a young professor x and michael fassbender as a young magneto
#
# what is the romance movie from 1937 that stars barbara stanwyck john boles and anne shirley involves a woman marrying and he tries to change her
#
# what is the romance movie with rachel mcadams and channing tatum about a wife who loses all memory of her husband
#
# what is the second movie emma thompson starred in where she played a knock off of mary poppins
#
# what is the sequel to evil dead in which bruce campbell gets sent back in time and has to fight a bunch of zombies
#
# what is the sequel to the animated family film about a penguin born without the ability to sing but with a talent for dancing
#
# what is the sequel to the superhero movie starring robert downey jr as a billionaire who builds a coat of armor to fight enemies
#
# what is the third film in a series this time set during the holidays starring john cho and kal penn as two stoner buddies
#
# what is the tiny creature in one of dr seuss s stories that tries to save nature from evil
#
# what is the title of the 1982 film about a young boy who befriends an alien
#
# what is the woody allen movie that he stars in and has this relationship in new york
#
# what is this 1977 movie starring richard dreyfuss and teri garr about aliens that featured devil s tower
#
# what is this 2010 comic book based movie directed by matthew vaughn featuring a hero in a green wet suit
#
# what is this 2012 film starring denzel washington about an airline pilot with an alcohol problem
#
# what is this animated movie where a young woman must escape a tower and evil sorceress
#
# what is this classic from the 1930 s that was inspired by a dream
#
# what is this epic that takes place in acient greek times
#
# what is this george lucas masterpiece that is a six part movie epic
#
# what is this grim fairytale retelling that follows the story of a princess white as snow and her sidekick hatchet armed savior that leads her through the dark woods
#
# what is this name of this 1977 david lynch movie that takes place in a post apocalyptic industrial town of giant machines that are constantly working
#
# what is this stallone classic that places him as a underdog boxer
#
# what is this timeless classic that stars tom hanks as a prison guard
#
# what is this timeless horror flick that depicts a savage dog
#
# what james cameron epic featuring leonardo dicaprio and kate winslet is about two young people falling in love
#
# what judd apatow film features paul rudd and other actors from the movie knocked up taking on life after 39
#
# what kathryn bigelow movie is a pre apocalyptic thriller involving the consciousness of people being used to end the world
#
# what marvel movie s title is the same as the character who wields a mighty hammer
#
# what miramax film features the story of a photographer looking to expose a drug war just outside of rio de janero
#
# what mockumentary about a rock band features an amplifier that can be turned up to eleven
#
# what movie based on the book by charles dickens follows the story of ebenezer scrooge as he is cold and eventually sees the error of his ways and reforms himself
#
# what movie centers around a masked killer trying to murder his long lost sister after his escape from a mental institution
#
# what movie features a current australian super star and ed harris that s about an elaborate bank heist
#
# what movie features a martial arts wielding group of animals on a quest to stop an evil peacock
#
# what movie features a miserly old man who must learn lessons from a set of departed spirits
#
# what movie features a new test drug which helps the lead character to become a super genius
#
# what movie features the quote mrs robinson if you do n t mind my saying so this conversation is getting a little strange
#
# what movie featuring al pacino that was directed by brian depalma is about the cocaine drug trade in florida
#
# what movie finds a cast of sentient toys who were accidentally shipped to a thrift store trying to find the way back home before their owner goes away to college
#
# what movie from the mind of joss whedon takes the sloppy formulaic horror movie genre and flips it on its head
#
# what movie gives a new view of a former president as an ax wielding hero fighting supernatural creatures
#
# what movie has hayden panettiere and justin long doing the voice for 2 wolves who end up falling in love regardless of their pack order
#
# what movie involves two college students that move in to the same dorm resulting in a voilent ending
#
# what movie is about the now fallen angel gabriel coming to save mankind from god s wraith
#
# what movie is about world war i where a man s horse is sold to the cavalry
#
# what movie is based on a true story about a boy who helps save an aquatic animal
#
# what movie is the fourth in the series of unusual encounters shown in the manner of surveillance tapes
#
# what movie made in 1979 covers the story for four nineteen year olds committed to the idea of never growing up
#
# what movie produced by quinten tarentino and stars russel crowe had the tag line it put s the fu in kung fu
#
# what movie released in 2001 does johnny depp star in as a man who becomes the biggest drug kingpin in american cocaine market i m thinking of a movie in where johnny depp runs into a problem that many of us have never had no where to hide all his cash
#
# what movie released in 2012 covers the story of a hobbit by the name of bilbo baggins and his dwarf friends seeking to reclaim his home
#
# what movie remake has jeff bridges filling in for john wayne as the famous one eyed rooster cogburn
#
# what movie stars mark wahlberg and the voice of seth macfarlane as a foul mouthed teddy bear
#
# what movie takes place in nineteenth century vienna in which edward norton plays a magician who runs into his young love jessica biel
#
# what movie was written and directed by jim jarmusch and features forest whitaker as a hit man
#
# what movies featuring liam neeson focuses on survivor s of a plane crash who are then attacked by a pack of wild wolves
#
# what period drama directed by milos forman starred tom hulce as a very famous composer
#
# what pixar animated film features a talking dog named dug
#
# what popular animated addition to the story about america s favorite ogre included rumpelstiltskin an evil magical contract writer
#
# what popular sci fi film features the son of a virtual world designer who gets trapped in one of the dimensions his father designed
#
# what recent prequel to a famous apeocolypse classic featured the beginning of the end of society due to a new species of sentient apes taking over
#
# what robert dinero and joe pesci movie centers around two mobster friends that run a gaming establishment
#
# what romantic feature from the mid 90 s covers the story of two people who meet on the titanic and covers their story
#
# what sci fi film features a small group of older children obsessed with filming on their new super 8 camera witnessing an alien discovery
#
# what sequel to an animated box office smash hit involves a colorful cast of animals that are masters in martial arts
#
# what spielberg movie is considered the first summer blockbuster and involves a killer shark s rampage on a resort town
#
# what stanley kubric masterpiece is hailed as one of the greatest science fiction films ever made
#
# what stanley kubric masterpiece is hailed as one of the most controversial films of all time
#
# what stunning action film featured bane as a charismatic super villain trying to take over gothem
#
# what the 80 s movie about a group of former college friends that get together for the weekend
#
# what timeless classic starring clint eastwood does he carry a large firearm as a police officer
#
# what was that movie featuring a young anne hathaway as a girl who learns she s heir to the throne of genovia
#
# what was that movie starring jake gyllenhal and heath ledger as cowboys who fall in love with each other
#
# what was that movie that was the sequel to that jack black animated movie about the animals that know shaolin kung fu
#
# what was that sci fi adventure film starring keanu reeves in which most characters are revealed to be living in a simulated reality
#
# what was the first installment of christopher nolan s epic trilogy based on the dc comic following a masked vigilante
#
# what was the last of a series of movies starring johnny depp as a pirate
#
# what was the movie with the scientists in the extremely cold environment where the scientists encounter a shape shifting alien
#
# what was the name of that movie that was set in a western theme and being from outer space came in
#
# what was the name of that walt disney movie that was filled with all kind of colorful animation
#
# what was the name of the 1975 mega hit thriller in which a great white shark menaced and munched on citizens of the beach resort town of amity during july 4 weekend
#
# what was the name of the documentary that compiled clips from american propaganda films showing hilariously ineffective ways to survive a nuclear holocaust
#
# what was the name of the first sylvester stallone movie in a long line of them where he was a boxer
#
# what was the name of the movie with the little girl and her dad had a whole bunch of firearms all over the walls inside their apartment
#
# what was the second movie in that george lucas sci fi movie trilogy the one where they introduced the short green master guy
#
# when a christmas party turns into a hostage crisis one man takes matters into his own hands
#
# when a mad man calling himself the scorpio killer menaces the city tough as nails san francisco police inspector harry callahan is assigned to track down and ferret out the crazed psychopath
#
# when a man goes for virtual vacation memories of the planet mars an unexpected and harrowing series of events forces him to go to the planet is the plot of this sci fic action movie
#
# when a sports agent has a moral epiphany and is fired for expressing it he decides to put his new philosophy to the test as an independent with the only athlete who stays with him is the plot of this 1996 romantic drama starring tom cruise
#
# which 1985 film based on a 1982 novel by alice walker focuses on the problems faced by african american women during the 1900 s
#
# which 1988 movie stars a young val kilmer where he has to help a dwarf protect a baby from an evil queen
#
# which 2003 christmas comedy starred snl comedian will ferrell who travels from the north pole to new york city in search of his father
#
# which 90 s american slasher film directed by wes craven features an iconically masked murderer who preys on teenagers loosely based on the gainesville ripper
#
# which 90 s animated film has such songs as hakuna matata and the circle of life
#
# which comedy classic featuring billy crystal and andre the giant tells the story of prince wesley as he tries to capture the affections and save the life of princess buttercup
#
# which disney film introduces a curly red headed overly independent princess looking to follow her dreams
#
# which film starred vanessa hudgens in a modern day retelling of beauty and the beast
#
# which film stars steve carrell as a middle aged divorced man trying to find love after his wife has an affair
#
# which film was quirky director wes anderson s foray into the world of author roald dahl and hand crafted stop motion filmmaking
#
# which francis ford coppola directed movie featured robert deniro playing a young don corleone in sicily
#
# which hayao miyazaki animated film tells the story of a girl who enters an alternate reality and must find her way to freedom
#
# which iconic detective movie has a young clint eastwood uttering the words make my day
#
# which is the movie based on a book by c s lewis featuring the pevensie children as they try to rescue the seven lords of narnia
#
# which john travolta and nick cage movie features an undercover agent who must change his appearance to infiltrate a criminal organization
#
# which movie features the trials and tribulations of mark zuckerberg setting up his digital empire
#
# which movie is the one that s about the girl in the tower who has long magical hair that glows
#
# which movie starring brad pitt and edward norton contains the first rule is to not talk about it
#
# which musical set in 1950 s new york features two rival gangs the sharks and the jets playing out a modern day retelling of romeo and juliet
#
# which of these films showed us the murder of a king the defection of a prince and an angry uncle ascending the throne
#
# which of these movies has an actor who has since gotten into trouble with the law several times
#
# which of these movies is a cross over of two separate films that exist within a similar genre
#
# which one of the following films listed took place in a french train station in the 1930 s
#
# which period drama centered around music features rival composers competing against each other in vienna during the 18 th century
#
# which quentin tarantino film told the story of two attempts to assassinate political leaders in nazi germany
#
# which steven spielberg film tells the story of a german businessman who saved the lives of nearly a thousand jews during world war 2
#
# which war film depicted the life of ordinary sailors on a german u boat during world war 2
#
# whos brain did dr frankenstein put in the jar
#
# why were the pacifists so easily turned to murder perhaps vegetarians have the same lust for life as the rest of us
#
# will forte plays an ex special operative trying to stop his arch enemy dieter von cunth from destroying washington d c
#
# william brent bell wrote and directed this 2012 horror movie about a series of unauthorized exorcisms in italy
#
# winona ryder is a girl who half heartedly tries to be part of the in crowd of her school when she meets a rebel who teaches her a more devious way to play social politics in this 1988 comedy drama
#
# you are living in the pacific northwest and forming a group of neighbors to hold back the invading north koreans what movie are you in
#
# you are told that who need to rob a bank or else by two people dressed in planet of the apes masks what movie are you in
#
# you know the prefects bathroom on the fifth floor it s not a bad place for a bath just take your egg and mull things over in the hot water is a quote from which j k rowling novel turned movie

# %% [markdown]
# # 3. Error analysis 2: False negatives
#
# For the 5 classes which have the lowest recall, according to the results table from our 20% development data, print out all the sentences where there is a false negative for that label (i.e. the label is present in the ground truth label for a given word, but that label is not predicted for that word by the tagger).

# %%
import itertools
output = (classification_report(y_test, preds, output_dict = True))
#print(output)
sorted_dict = {}
sorted_dict2 = {}
sliced_dict = {}

for key,value in output.items():   #Extracting the precision column from the dictionary
    if type(value) == dict:
        if (key != "macro avg") and (key!= "weighted avg"):
            sorted_dict.__setitem__(key,value['recall'])

sorted_dict2 = sorted(sorted_dict.items(), key=lambda x: x[1])
#print(sorted_dict2)
sliced_dict = dict(itertools.islice(sorted_dict2, 5))
print(sliced_dict)

list1_fn=[]
for x in list(sliced_dict):
    list1_fn.append(x)
#print(list1_fn)


abc_fn = []
fn_sentences = []
for sent in x_test:
    sent_preds = [x[1] for x in ct.tag([s[0] for s in sent])]
    sent_true = [s[1] for s in sent]
    for s in range(0,len(sent)):
        if (sent_preds[s]!=sent_true[s]):
            for i in range(0,len(list1_fn)):
                if (sent_true[s]==list1_fn[i]):
                    if sent not in abc_fn:
                        abc_fn.append(sent)
                        
print(len(abc_fn))
    

print("The sentences with false positives for the given 5 classes with lowest precision are: \n")   
for i in abc_fn:
    for j in i:
        print(j[0], end = ' ')
        fn_sentences.append(j[0])
    print("\n")
# Out:
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'B-Soundtrack': 0.0, 'I-Soundtrack': 0.0, 'I-Opinion': 0.09523809523809523, 'I-Character_Name': 0.11515151515151516, 'B-Character_Name': 0.12264150943396226}
# 202
# The sentences with false positives for the given 5 classes with lowest precision are:
#
# one of the most memorable scenes from this film involve a boy riding his bike through the sky
#
# orson wells psychological profile of an eccentric billionaire has been voted the greatest movie of all time by some
#
# paul newman stars as rocky graziano in this biographical drama about a criminal turned boxer
#
# penny chenery tweedy and colleagues guide her long shot but precocious stallion to set in 1973 the unbeaten record for winning the triple crown is the plot of this 2010 family drama
#
# perseus mortal son of zeus battles the minions of the underworld to stop them from conquering the earth and the heavens in this 2010 action adventure fantasy
#
# peter jackson directed this smash hit starring jack black as a 1930 s film maker on a mission to make an unforgettable nature documentary who gets more than he bargained for
#
# rapunzel is having a bad hair day she s out of the tower and off to discover life in this 2010 animated feature
#
# red riding hood is training in the group of sister hoods when she and the wolf are called to examine the sudden mysterious disappearance of hansel and gretel in this animated feature
#
# reese witherspoon won an oscar for best actress for playing the wife of johnny cash in this film
#
# richard gere took tap dance lessons for three months to prepare for his role as the criminal defense attorney billy flynn in this 2002 musical
#
# robert duvall is bank robber outlaw jesse james in this movie about a bank robbery gone wrong
#
# robert redford directed ralph fiennes as charles van doren in this 1994 film set in the 1950 s
#
# rufus t firefly is named president dictator of bankrupt freedonia and declares war on neighboring sylvania over the love of wealthy mrs teasdale is the plot of this classic comedy starring all three of the marx brothers
#
# sarah jessica parker is kate reddy a finance executive who is the breadwinner for her husband and two kids in this 2011 movie based on the novel by allison pearson
#
# sean anderson partners with his mom s husband on a mission to find his grandfather who is thought to be missing in a mythical location in this 2012 adventure starring dwayne johnson
#
# stacy keach and james keach play frank and jesse james in this 1980 western about the outlaws and their gang
#
# stopped they must be on this all depends only a fully trained jedi knight with the force as his ally will conquer vader in this 1980 george lucas sequel
#
# the debut movie of the famous director kevin smith featuring his breakout characters jay and silent bob
#
# the last part of a vampire love story between bella and edward
#
# the movie i m thinking of has a rabbit named thumper and a faun that grows to a female deer who the movie is named after
#
# the movie where marty mcfly and doc brown go back in time and have to get marty s mom to marry his dad
#
# the movie where two of the characters have dogs with country singers names one was willie nelson and the other dolly parton
#
# the second movie in a popular fantasy trilogy this film introduces a character named treebeard
#
# the story of avant garde comedian andy kaufman and his notorious antics on the stage
#
# the story of t e lawrence a flamboyant and controversial british military figure and his conflicted loyalties during his world war i service in the middle east staring peter o toole
#
# this 1948 american film written by john huston starred humphrey bogart as the character dobbs
#
# this 1962 classic drama features a little girl named scout who lived in the depression era south
#
# this 1990 s animated feature taught us the song hakuna matata which championed a down to earth problem free philosophy
#
# this 1997 smash hit is loosely based on a famous cruise ship that sank in 1912
#
# this 2010 american supernatural horror film starred sprague grayden as kristi and molly ephraim as ali
#
# this 2011 superhero movie stars seth rogen as an unlikely hero who starts a crime fighting career with the help of his father s assistant kato
#
# this 2012 movie is eye candy for the ladies this movie is set in the world of the male stripper
#
# this 942 american biographical musical film about george m cohan known as the man who owns broadway
#
# this action film features aaaron johnson as a high school student turned vigilante nicholas cage and chloe moretz are also featured as big daddy and hit girl
#
# this action movie follows the actions of a team of super heroes including magneto
#
# this action packed futuristic thriller about time travel stars bruce willis and joseph gordon levitt as a 20 something willis
#
# this alfred hitchcock film includes a motel manager norman bates in an infamous shower scene
#
# this american film features single serving friends power animals project mayhem and jack s raging bile duct
#
# this animated sequel features ben stiller as alex the lion and his continuing adventures in africa
#
# this black and white comedy directed by mel brooks stars gene wilder and peter boyle and features the classic song puttin on the ritz
#
# this children s movie is about a young boy named greg heffley who enters the sixth grade and tries to make it through the school year unscathed
#
# this classic 1938 warner bros gangster picture stars james cagney pat o brien humphrey bogart and the dead end kids
#
# this computer animated comedy features the voice of steve carrell as the villainous but likeable gru
#
# this disney film was a long awaited sequel to the science fiction thriller starring jeff bridges in the world of living computer programs
#
# this horror movie features one of the most famous villains in the genre who kills victims in their nightmares with his signature bladed hands
#
# this horror movie takes place at a summer camp and spawned a series of movies about a gruesome killed named jason
#
# this is one of the most famous kung fu movies of all time about two warriors in pursuit of a stolen sword
#
# this james bond film starring daniel craig features a theme song by adele
#
# this marvel superhero film assembles captain america iron man thor and the hulk to battle an evil being named loki
#
# this modern batman film pits batman against bane and catwoman in a besieged new york city
#
# this modern crime film features robert downey jr as a bumbling crook caught up in a mystery alongside val kilmer as private investigator gay perry
#
# this modern twist on the superhero genre is a found footage movie about a group of teenagers who accidentally gain superpowers
#
# this movie about gold prospectors in mexico is often considered one of humphry bogart s best works
#
# this movie features scientifically inaccurate but scary and intense recreations of a past extinct species
#
# this movie is about a lone avatar who has the power to manipulate all four elements he teams up with katara who is a waterbender
#
# this movie stars cary elwes as westley or could it be the dread pirate roberts
#
# this stop motion animated feature directed by henry selick shows the adventures of jack skellington who tries to spread the magic of christmas
#
# this surreal romp from 1967 stars the beatles and features some of their famous hit songs
#
# tim burton used stop motion animation to tell the story of jack skellington in what 1993 disney movie
#
# two good friends mike and sully team up to scare as many children as possible but encounter something that no one has ever encountered before in this film
#
# werner herzog wrote and directed this biographical documentary about timothy treadwell and amie huguenard bear activists who were killed while living among them in alaska
#
# what s that awesome funny movie with jennifer anniston the guys start a pyramid scheme and almost get fired one man is named michael bolton
#
# what s that stupid overrated movie about interplanetary fighting there are jedis and one of the main characters is harrison ford
#
# what s that super slow paced movie with ryan gostling where nobody says anything the whole time
#
# what s the camp comedy musical classic that features susan sarandon s first role and the song time warp
#
# what s the name of the first pixar movie where tim allen and tom hanks voice woody and buzz lightyear
#
# what s the name of the remake of moe larry and curly where larry david plays a nun
#
# what s the one with that guy from the matrix and the girl from titanic where they try to save the world
#
# what s the title of wes craven s horror film where serial killer freddy krueger kills people in their dreams
#
# what 1930 ernst lubitsch film starring jeanette macdonald took place in a famous european gambling city and featured the song beyond the blue horizon
#
# what 1934 jean vigo film called one of the best of all time starred michel simon as p re jules
#
# what 1942 movie garnered a best music original song oscar win to irving berlin for his song white christmas
#
# what 1946 frank capra movie centers around the life of george bailey in bedford falls
#
# what 1957 king vidor movie starring audrey hepburn and henry fonda centered around napoleon s tumultuous relations with russia
#
# what 1958 alfred hitchcock film based on a novel by boileau narcejac starred james stewart as detective john scottie ferguson
#
# what 1965 cartoon is a timeless classic starring the lovable charlie brown and his dog snoopy
#
# what 1965 musical based on a rogers and hammerstein musical of the same name features the von trapp family singers
#
# what 1974 stop motion animated tv special features kris kringle running into the heater miser
#
# what 1981 biopic starred faye dunaway and depicted the abusive adoptive upbringing of christina crawford
#
# what 1983 harold ramis comedy finds the griswold family cross country driving to theme park walley world
#
# what 1987 brian depalma film features kevin costner as federal agent eliot ness out to stop al capone
#
# what 1987 movie featured an evil prince his six fingered henchman and a swordsman hero named inigo montoya
#
# what 1989 comedy features chevy chase as clark griswold and beverly d angelo as his wife ellen
#
# what 1990 crime drama had robert de niro playing a mob type gangster named james conway
#
# what 1990 martin scorsese biopic centers around henry hill and his friends as they work their way up through the mob hierarchy
#
# what 1991 movie featured jessica tandy in her best supporting actress oscar winning role of ninny threadgoode
#
# what 1991 musical comedy centers around characters janet and brad as they become game show contestants
#
# what 1993 drama film directed by steven speilberg featured liam neeson as schindler in nazi germany
#
# what 1995 chick flick starred clint eastwood as photographer robert kincaid and meryl streep as his short lived love interest
#
# what 1996 family movie depicts paul hogan as sandy ricks and elijah wood as his troubled nephew
#
# what 1999 movie found haley joel osment as cole sear a boy who communicated with spirits
#
# what 2005 ron howard biopic tells the story of james braddock a washed up boxer who came back to become a champion
#
# what 2007 biopic is about the story of jean dominique bauby and his trouble with locked in syndrome
#
# what 2008 japanese animated fantasy film written and directed by hayao miyazaki is about brunhilde the fish girl
#
# what 2009 rob zombie horror movie centers around character laurie strode and her brother michael
#
# what 2010 american supernatural film featured a group of strangers including arch angel micheal fighting for the fate of humanity
#
# what 2010 drama centered on the efforts of joan and aileen crowley to find a researcher who might develop a cure for their children s rare genetic disorder
#
# what 2010 movie finds superhero alter ego tony stark once again battling evil and saving the day
#
# what 2010 romantic comedy features anne hathaway as maggie murdock and jake gyllenhaal as jamie randall
#
# what 2010 sequel does michael douglas reprise his role as gordon gekko the infamous broker who coined greed is good
#
# what 2010 thriller set in 1954 finds u s marshal teddy daniels investigating the disappearance of a murderess who escaped a mental hospital
#
# what 2011 crime movie features ryan phillippe as louis roulet a man with a foolproof plan to beat the system
#
# what 2011 movie stars bradley cooper as writer eddie morra who discovers a top secret drug
#
# what 2011 thriller based on a fairy tail features a young woman named valerie and her love peter
#
# what 2011 thriller centered around character dominic toretto and his crew of street racers planning a massive heist
#
# what 2012 film by peter jackson goes back to the original story of bilbo told by j r r tolkien
#
# what 2012 superhero film starred anne hathaway as cat woman and tom hardy as bane
#
# what 2012 thriller finds retired cia operative bryan mills played by liam neeson and his wife played by famke janssen taken hostage
#
# what action adventure movie has been remade multiple times and features clark kent and his alter ego the man of steel
#
# what action film directed by tarsem singh starred henry cavill as theseus and freida pinto as phaedra
#
# what action movie featuring clint eastwood as a renegade cop harry callahand making his own rules delivering justice through this 44 magnum revolver
#
# what animated classic christmas movie features snoopy and a really pathetic beat up looking christmas tree
#
# what animated movie tells the story of simba who returns to his homeland to reclaim the crown from his uncle scar
#
# what black and white japanese classic epic features a story about 7 warriors facing unimaginable odds
#
# what blockbuster film stars liam nieson in his heart stopping thriller which takes place in a snowy wasteland
#
# what boxing centric movie inspired the character tag line of italian stallion and inspired legions of fans to workout to the song eye of the tiger
#
# what classic disney film takes place in africa and includes musical pieces such as hakkuna mattata
#
# what classic thriller about an enormous killer shark spawned one of the most popular movie themes of all time
#
# what film directed by david fincher tells of mark zuckerberg s rise to power and the creation of facebook
#
# what film introduced the knives for fingers character of freddy krueger that haunts the dreams of teenagers eventually killing them
#
# what intense gritty 2012 cop drama focuses on the day to day of two los angelos police officers
#
# what is that 2012 movie that stars liam neeson as zeus and ralph fiennes as hades
#
# what is that comedy film starring jon heder in a breakout role as an awkward teen and details his adventures in high school
#
# what is that movie 2012 biographical film co directed by curtis hanson about the life of jay moriarty
#
# what is that movie about the american cocaine smuggler george jung who is played by johnny depp
#
# what is that movie starring leonardo di caprio as howard hughes and chronicles his life
#
# what is that movie that details how mark zuckerberg created facebook and details facebook s early inception at harvard
#
# what is that ron howard directed movie where russell crowe plays john nash a very brilliant but troubled mathematician
#
# what is that satire movie the 1999 american comedy film which became a cult classic and starring ron livingston as a disgruntled employee
#
# what is the 1935 american comedy film opera singer riccardo baroni wishes to be just as good as lassparri and hires his best friend to be his manager
#
# what is the 1942 musical film staring bing crosby and fred astaire with music by irving berlin
#
# what is the 1950 american drama film which stars bette davis as margo channing an aging broadway actress
#
# what is the 1991 disney animated movie that featured angela lansbury as the voice of a teapot
#
# what is the 1995 american medieval movie starring richard gere as lancelot and sean connery as king arthur
#
# what is the 2004 horror film about victims chained in a bathroom and given rules to survive by a serial killer named jigsaw
#
# what is the 2010 american fantasy adventure movie based on the greek story of perseus starring sam worthington
#
# what is the 2010 american sci fi film released by walt disney pictures starring jeff bridges and had a soundtrack by french band daft punk
#
# what is the 2010 american western remake by the coen brothers that starred jeff bridges as us marshall reuben rooster cogburn
#
# what is the 2011 master piece with adam sandler and directed by dennis dugan and involves hawaii
#
# what is the 2012 blockbuster hit that featured a team of superheros that banded together to fight a supervillain
#
# what is the animated movie from disney that took a fresh adventurous take on the fairy tale classic rapunzel
#
# what is the classic cartoon christmas movie based on a comic strip about a boy his friends his dog and a bird named woodstock
#
# what is the cult classic movie with keanu reeves in which he is called the one
#
# what is the disney film featuring a princess aurora who is put under a sleeping spell until awakened by a kiss
#
# what is the family comedy that is really good to watch at christmas time that had the newest version released in 2006 and stars john goodman
#
# what is the famous cult classic movie about the girl whose first love returns in the form of a pirate to kidnap her from the man she is about to marry
#
# what is the famous cult classic movie with samuel jackson and john travolta dances with uma thurman in a well known scene
#
# what is the first movie in a series starring arnold schwarzenegger as a cyborg sent back in time to kill john connor the leader of a future resistance against the machines
#
# what is the fred astaire and judy garland movie with the song about a bonnet
#
# what is the marvel comic movie about the god of thunder who comes to earth and fights his brother loki
#
# what is the most recent bond film called with the new bond played by daniel craig
#
# what is the movie based on another jrr tolkien book but not the lord of the rings trilogy
#
# what is the movie starring russell crowe as the brilliant mathematician john nash and directed by ron howard
#
# what is the movie with liam neeson as zeus and sam worthington as perseus battling the forces of the underworld
#
# what is the movie with the rock and that guy who plays peeta mellark on hunger games
#
# what is the name of that superhero movie where clark kent is played by christopher reeve and lex luthor is played by gene hackman
#
# what is the name of the 80 s movie about mozart that had a hit song with the same name
#
# what is the name of the disney movie where princess jazmine goes on a magic carpet ride with the lease character
#
# what is the name of the first film in the series that features the infamous jason voorhees
#
# what is the name of the master piece moved directed by francis lawrence and has robert pattinson in it
#
# what is the name of the movie in which christina aguilera pink mya and lil kim collaborated for the lead music track of the film
#
# what is the name of the movie in which gandalf and aragorn lead an army against sauron s army so frodo and same can get to mount doom
#
# what is the name of the movie where ash must battle an army of the dead and retrieve the necronomicon
#
# what is the pg 13 movie that was well known for having a curse word in its name
#
# what is the reboot of a popular marvel movie franchise with james mcavoy as a young professor x and michael fassbender as a young magneto
#
# what is the sequel to the science fiction movie with sigourney weaver returning as ellen ripley
#
# what is the super popular war movie with tom hanks and matt damon in which three of four brothers die in the war
#
# what is the third harry potter movie where dementors are on the move searching for the escapee from prison who ends up in the end being harry s godfather
#
# what is the updated version of romeo and juliet where a man and woman from two feuding gangs in new york fall in love and have to deal with the problems it causes
#
# what is the very famous clint eastwood movie about two bounty hunters who try to beat a third before they find buried treasure
#
# what is this 2009 film based on a true story that stars jim carrey as steven jay russell
#
# what is this classic horror flick that stars the toy chuckie
#
# what is this mind bending film directed by christopher nolan and starring leonardo dicaprio that takes place inside the mind
#
# what is this star studded action sequel that teams up slyvester stallone with bruce willis and arnold schwarzenegger
#
# what is this timeless classic that stars tom hanks as a prison guard
#
# what jerry zuker film starred richard gere as lancelot and sean connery as king arthur
#
# what movie based on the book by charles dickens follows the story of ebenezer scrooge as he is cold and eventually sees the error of his ways and reforms himself
#
# what movie is about the now fallen angel gabriel coming to save mankind from god s wraith
#
# what movie released in 2012 covers the story of a hobbit by the name of bilbo baggins and his dwarf friends seeking to reclaim his home
#
# what movie remake has jeff bridges filling in for john wayne as the famous one eyed rooster cogburn
#
# what movie starring sasha baron cohen features another character from his infamous and highly controversial show da ali g show
#
# what pixar animated film features a talking dog named dug
#
# what popular animated addition to the story about america s favorite ogre included rumpelstiltskin an evil magical contract writer
#
# what sequel to an animated box office smash hit involves a colorful cast of animals that are masters in martial arts
#
# what stanley kubric masterpiece is hailed as one of the greatest science fiction films ever made
#
# what stunning action film featured bane as a charismatic super villain trying to take over gothem
#
# what timeless classic starring clint eastwood does he carry a large firearm as a police officer
#
# what was that film about a speech therapist helping george vi learn to speak without a stutter
#
# what was that film that had queequeg and ishmael in it where they chased a whale
#
# what was the name of the 1975 mega hit thriller in which a great white shark menaced and munched on citizens of the beach resort town of amity during july 4 weekend
#
# what was the title of the cult favorite monster musical spoof starring tim curry as a transvestite alien from the planet transylvania menacing a straight laced young couple
#
# when a mad man calling himself the scorpio killer menaces the city tough as nails san francisco police inspector harry callahan is assigned to track down and ferret out the crazed psychopath
#
# which comedy classic featuring billy crystal and andre the giant tells the story of prince wesley as he tries to capture the affections and save the life of princess buttercup
#
# which ensemble film follows two hitmen to return a briefcase to their boss marsellus wallace
#
# which film starred vanessa hudgens in a modern day retelling of beauty and the beast
#
# which film stars macaulay culkin as kevin mccallister defending his home from a pair of robbers
#
# which francis ford coppola directed movie featured robert deniro playing a young don corleone in sicily
#
# which movie features the trials and tribulations of mark zuckerberg setting up his digital empire
#
# which musical set in 1950 s new york features two rival gangs the sharks and the jets playing out a modern day retelling of romeo and juliet
#
# whos brain did dr frankenstein put in the jar
#
# will forte plays an ex special operative trying to stop his arch enemy dieter von cunth from destroying washington d c
#
# young traveler allan gray discovers evidence of the supernatural in this black and white 1932 horror film
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # 4. Incorporating POS tags as features
# Using the CRF part-of-speech (POS) tagger to add POS tags to the words in the training data. Note the CRF tagger only takes strings as input so we will have to concatenate the word and POS tag together (with a special symbol, e.g. @), and you will also have to then split on this special symbol in the feature extraction function `get_features` to get the word and POS tag - modify that function so it uses the POS tag in addition to the word (currently using the word only is achieved by `feature_list.append("WORD_" + token)`.

# %%
# a postagger for use in exercises
posttagger = CRFTagger()
posttagger.set_model_file("crf_pos.tagger")
# example use:
words = ["john", "likes", "mary", "and", "bill"]
print(posttagger.tag(words))
# Out:
# [('john', 'NNP'), ('likes', 'VBZ'), ('mary', 'JJ'), ('and', 'CC'), ('bill', 'NN')]

# %%
raw_training_data = get_raw_data_from_bio_file("trivia10k13train.bio.txt") 

import numpy as np
from sklearn.model_selection import train_test_split

x_train, x_test = train_test_split(raw_training_data,train_size = 0.8,  test_size=0.2 , shuffle = False)

# %%
def preProcess1(example):
    
    """returns new (token, bio-tag) pairs with preprocessing applied to the words

    example = [('steve', 'B-Actor'), ('mcqueen', 'I-Actor'), ('provided', 'O'), ('a', 'O'), ('thrilling', 'B-Plot'), 
        ('motorcycle', 'I-Plot'), ('chase', 'I-Plot'), ('in', 'I-Plot'), ('this', 'I-Plot'), 
        ('greatest', 'B-Opinion'), ('of', 'I-Opinion'), ('all', 'I-Opinion'), ('ww', 'B-Plot'), 
        ('2', 'I-Plot'), ('prison', 'I-Plot'), ('escape', 'I-Plot'), ('movies', 'I-Plot')]"""


    # a postagger for use in exercises
    posttagger = CRFTagger()
    posttagger.set_model_file("crf_pos.tagger")

    final_list = []


        
    for i in example:
        word = i[0]       # Extracting the words from training data
        classes = i[1]     #Extracting the classes ('I-Plot, A-Actor' etc) from training data
        POS_tags = posttagger.tag([word])     # Tagging the words from training data using POS tagger
        POS_tagged_words = word+"@"+POS_tags[0][1]  # concatenating the words and the POS tags with a special symbol '@'.
        final_list.append((POS_tagged_words,classes))  # Appending the words@POStag with the classes 
        

    
    return final_list

# %%
training_data = [preProcess1(example) for example in x_train]

# %%
_pattern = re.compile(r"\d")  # to recognize numbers/digits


# This is the 'out-of-the-box' get_features function from the nltk CRF tagger
def get_features1(tokens,idx):
    """
    Extract basic features about this word including
         - Current Word
         - Is Capitalized ?
         - Has Punctuation ?
         - Has Number ?
         - Suffixes up to length 3
    Note that : we might include feature over previous word, next word ect.

    :return : a list which contains the features
    :rtype : list(str)

    """
    token = (tokens[idx].split('@'))
    word_token = token[0]
    POS_token = token[1]
    feature_list = []
    
    

    if not word_token:
        return feature_list
    
    # Capitalization
    if word_token[0].isupper():
        feature_list.append("CAPITALIZATION")

    # Number
    if re.search(_pattern, word_token) is not None:
        feature_list.append("HAS_NUM")

    # Punctuation
    punc_cat = set(["Pc", "Pd", "Ps", "Pe", "Pi", "Pf", "Po"])
    if all(unicodedata.category(x) in punc_cat for x in word_token):
        feature_list.append("PUNCTUATION")

    # Suffix up to length 3
    if len(word_token) > 1:
        feature_list.append("SUF_" + word_token[-1:])
    if len(word_token) > 2:
        feature_list.append("SUF_" + word_token[-2:])
    if len(word_token) > 3:
        feature_list.append("SUF_" + word_token[-3:])
        
    feature_list.append("WORD_" + word_token + ", POStag_" + POS_token)
    #print(feature_list)
    
    
    return feature_list

# %%
# Train the CRF BIO-tag tagger
TAGGER_PATH = "crf_nlu.tagger"  # path to the tagger- it will save/access the model from here
ct = CRFTagger(feature_func=get_features1)  # initialize tagger with get_features function

print("training tagger...")
ct.train(training_data, TAGGER_PATH)
print("done")


# load tagger from saved file
ct = CRFTagger(feature_func=get_features1)  # initialize tagger
ct.set_model_file(TAGGER_PATH)  # load model from file

# prepare the test data:

x_test = [preProcess1(example) for example in x_test]
print(len(x_test), "instances")
print(sum([len(sent) for sent in x_test]), "words")


print("testing tagger...")
preds = []
y_test = []
length = 0
for sent in x_test:
    sent_preds = [x[1] for x in ct.tag([s[0] for s in sent])]
    sent_true = [s[1] for s in sent]
    preds.extend(sent_preds)
    y_test.extend(sent_true)
print("done")
# Out:
# training tagger...
# done
# 1564 instances
# 31304 words
# testing tagger...
# done

# %%
# Output the classification report (which you should save each time for comparing your models)
print(classification_report(y_test, preds))
print(precision_recall_fscore_support(y_test, preds, average='macro'))  # print out accurate macro score
# Out:
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                   precision    recall  f1-score   support
#
#          B-Actor       0.87      0.87      0.87      1231
#          B-Award       0.76      0.60      0.67        75
# B-Character_Name       0.63      0.12      0.21       212
#       B-Director       0.86      0.67      0.75       472
#          B-Genre       0.86      0.78      0.82       805
#        B-Opinion       0.48      0.24      0.32       160
#         B-Origin       0.57      0.43      0.49       159
#           B-Plot       0.49      0.46      0.47      1221
#          B-Quote       0.67      0.17      0.27        24
#   B-Relationship       0.81      0.40      0.53       125
#     B-Soundtrack       0.00      0.00      0.00        13
#           B-Year       0.97      0.99      0.98       703
#          I-Actor       0.89      0.84      0.87      1731
#          I-Award       0.79      0.81      0.80       202
# I-Character_Name       0.59      0.12      0.19       165
#       I-Director       0.86      0.66      0.74       456
#          I-Genre       0.79      0.74      0.76       576
#        I-Opinion       0.07      0.10      0.08        84
#         I-Origin       0.66      0.71      0.68       729
#           I-Plot       0.84      0.95      0.89     11448
#          I-Quote       0.56      0.19      0.28       176
#   I-Relationship       0.61      0.40      0.48       240
#     I-Soundtrack       0.00      0.00      0.00        41
#           I-Year       0.77      0.82      0.79        33
#                O       0.86      0.83      0.85     10223
#
#         accuracy                           0.83     31304
#        macro avg       0.65      0.51      0.55     31304
#     weighted avg       0.82      0.83      0.82     31304
#
# (0.6501291230396969, 0.5148784478638774, 0.5519308967692744, None)
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
def confusion_matrix_heatmap(y_test, preds):
    """Function to plot a confusion matrix"""
    labels = list(set(y_test))   # get the labels in the y_test
    # print(labels)
    cm = confusion_matrix(y_test, preds, labels)
    fig = plt.figure(figsize=(20,20))
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title('Confusion matrix of the classifier')
    fig.colorbar(cax)
    ax.set_xticks(np.arange(len(labels)))
    ax.set_yticks(np.arange(len(labels)))
    ax.set_xticklabels( labels, rotation=45)
    ax.set_yticklabels( labels)

    for i in range(len(cm)):
        for j in range(len(cm)):
            text = ax.text(j, i, cm[i, j],
                           ha="center", va="center", color="w")

    plt.xlabel('Predicted')
    plt.ylabel('True')
    #fig.tight_layout()
    # fix for mpl bug that cuts off top/bottom of seaborn viz:
    b, t = plt.ylim() # discover the values for bottom and top
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t) # update the ylim(bottom, top) values
    plt.show() # ta-da!
    
confusion_matrix_heatmap(y_test, preds)
# Out:
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=['I-Quote', 'B-Origin', 'I-Plot', 'I-Relationship', 'B-Soundtrack', 'B-Quote', 'B-Director', 'I-Actor', 'B-Year', 'B-Genre', 'B-Opinion', 'B-Actor', 'I-Genre', 'I-Year', 'I-Origin', 'I-Soundtrack', 'I-Director', 'B-Relationship', 'I-Character_Name', 'O', 'B-Award', 'B-Character_Name', 'B-Plot', 'I-Award', 'I-Opinion'] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %% [markdown]
# # 5. Feature experimentation and other optimization for optimal macro average.
# Now, we will experiment with different features by further adjusting the `get_features` function, and modifying it to get the best results in terms of `macro average f-score` (i.e. average f-score across all classes) on our 20% development data. Iteratively we will try different functions, briefly describe the method and record the results in the classification report format.
#
# We could try more suffixes/prefixes of the current word than those currently extracted, use windows of the next and previous tokens (of different sizes, e.g. the previous/next N words/tags).
#
# After our feature engineering, for even better performance we have tried optimizing the hyperparameters by adjusting the `training_opt` dictionary values, experimenting with changing the minimum document frequency, c1 and c2 regularization parameters for https://www.nltk.org/api/nltk.tag.crf.html#nltk.tag.crf.CRFTagger.__init__ e.g. changing the initialization to make the minimum feature frequency 2 (rather than the default 1) would be:
#
# `ct = CRFTagger(feature_func=get_features, training_opt={"feature.minfreq":2})`

# %%
raw_training_data = get_raw_data_from_bio_file("trivia10k13train.bio.txt") 

import numpy as np
from sklearn.model_selection import train_test_split

x_train, x_test = train_test_split(raw_training_data,train_size = 0.8,  test_size=0.2 , shuffle = False)

# %%
def preProcess1(example):
    
    """returns new (token, bio-tag) pairs with preprocessing applied to the words

    example = [('steve', 'B-Actor'), ('mcqueen', 'I-Actor'), ('provided', 'O'), ('a', 'O'), ('thrilling', 'B-Plot'), 
        ('motorcycle', 'I-Plot'), ('chase', 'I-Plot'), ('in', 'I-Plot'), ('this', 'I-Plot'), 
        ('greatest', 'B-Opinion'), ('of', 'I-Opinion'), ('all', 'I-Opinion'), ('ww', 'B-Plot'), 
        ('2', 'I-Plot'), ('prison', 'I-Plot'), ('escape', 'I-Plot'), ('movies', 'I-Plot')]"""


    # a postagger for use in exercises
    posttagger = CRFTagger()
    posttagger.set_model_file("crf_pos.tagger")

    final_list = []


        
    for i in example:
        word = i[0]       # Extracting the words from training data
        classes = i[1]     #Extracting the classes ('I-Plot, A-Actor' etc) from training data
        POS_tags = posttagger.tag([word])     # Tagging the words from training data using POS tagger
        POS_tagged_words = word+"@"+POS_tags[0][1]  # concatenating the words and the POS tags with a special symbol '@'.
        final_list.append((POS_tagged_words,classes))  # Appending the words@POStag with the classes 
        

    
    return final_list

# %%
training_data = [preProcess1(example) for example in x_train]

# %%
_pattern = re.compile(r"\d")  # to recognize numbers/digits


# This is the 'out-of-the-box' get_features function from the nltk CRF tagger
def get_features1(tokens,idx):
    """
    Extract basic features about this word including
         - Current Word
         - Is Capitalized ?
         - Has Punctuation ?
         - Has Number ?
         - Suffixes up to length 3
    Note that : we might include feature over previous word, next word ect.

    :return : a list which contains the features
    :rtype : list(str)

    """
    
    
    token = ((tokens[idx]).split('@'))  #Splitting the words and the POS Tags
    word_token = token[0]   #Storing the word 
    POS_token = token[1]    #Storing the POS tags
    feature_list = []
    
    

    if not word_token:
        return feature_list
    
    feature_list.append("Length = " + str(len(word_token)))
    
    if (idx==0):
        feature_list.append("is_first_word")
    
    
    if (idx==len(tokens)-1):
        feature_list.append("is_last_word")
    
    # Capitalization
    if word_token[0].isupper():
        feature_list.append("CAPITALIZATION")

    # Number
    if re.search(_pattern, word_token) is not None:
        feature_list.append("HAS_NUM")

    # Punctuation
    punc_cat = set(["Pc", "Pd", "Ps", "Pe", "Pi", "Pf", "Po"])
    if all(unicodedata.category(x) in punc_cat for x in word_token):
        feature_list.append("PUNCTUATION")

    # Suffix up to length 4
    if len(word_token) > 1:
        feature_list.append("SUF_" + word_token[-1:])
    if len(word_token) > 2:
        feature_list.append("SUF_" + word_token[-2:])
    if len(word_token) > 3:
        feature_list.append("SUF_" + word_token[-3:])
    if len(word_token) > 4:
        feature_list.append("SUF_" + word_token[-4:])
        
        
    # Prefix up to length 4
    if len(word_token) > 1:
        feature_list.append("PRE_" + word_token[:1])
    if len(word_token) > 2:
        feature_list.append("PRE_" + word_token[:2])
    if len(word_token) > 3:
        feature_list.append("PRE_" + word_token[:3])
    if len(word_token) > 4:
        feature_list.append("PRE_" + word_token[:4])
        
    if idx!=0:    #added a feature for the previous word.
        token3 = tokens[idx-1]
        token3 = token3.split('@')
        token3 = token3[0]
        feature_list.append("Previous Word_"+ token3)
        
    feature_list.append("WORD_" + word_token + ", POStag_" + POS_token)
    
    
    if idx!=(len(tokens)-2):      #added a feature for the next two words.
        if idx!=(len(tokens)-1):
            token1 = tokens[idx+1]
            token1 = token1.split('@')
            token1 = token1[0]
            #print(token1)
            token2 = (tokens[idx+2])
            token2 = token2.split('@')
            token2 = token2[0]
            #print(token2)
            feature_list.append("Next Two Words_" + token1 + "," + token2 )
        
    
    
    #print(feature_list)
    return feature_list

# %%
# Train the CRF BIO-tag tagger
TAGGER_PATH = "crf_nlu.tagger"  # path to the tagger- it will save/access the model from here
ct = CRFTagger(feature_func=get_features1)  # initialize tagger with get_features function

print("training tagger...")
ct.train(training_data, TAGGER_PATH)
print("done")


# load tagger from saved file
ct = CRFTagger(feature_func=get_features1)  # initialize tagger
ct.set_model_file(TAGGER_PATH)  # load model from file

# prepare the test data:

x_test = [preProcess1(example) for example in x_test]
print(len(x_test), "instances")
print(sum([len(sent) for sent in x_test]), "words")


print("testing tagger...")
preds = []
y_test = []
length = 0
for sent in x_test:
    sent_preds = [x[1] for x in ct.tag([s[0] for s in sent])]
    sent_true = [s[1] for s in sent]
    preds.extend(sent_preds)
    y_test.extend(sent_true)
print("done")
# Out:
# training tagger...
# done
# 1564 instances
# 31304 words
# testing tagger...
# done

# %%
# Output the classification report (which you should save each time for comparing your models)
print(classification_report(y_test, preds))
print(precision_recall_fscore_support(y_test, preds, average='macro'))  # print out accurate macro score
# Out:
#                   precision    recall  f1-score   support
#
#          B-Actor       0.92      0.93      0.93      1231
#          B-Award       0.75      0.65      0.70        75
# B-Character_Name       0.80      0.33      0.46       212
#       B-Director       0.90      0.76      0.83       472
#          B-Genre       0.90      0.84      0.87       805
#        B-Opinion       0.61      0.37      0.46       160
#         B-Origin       0.59      0.47      0.52       159
#           B-Plot       0.49      0.46      0.47      1221
#          B-Quote       0.78      0.29      0.42        24
#   B-Relationship       0.81      0.53      0.64       125
#     B-Soundtrack       1.00      0.15      0.27        13
#           B-Year       0.98      0.99      0.98       703
#          I-Actor       0.93      0.93      0.93      1731
#          I-Award       0.82      0.78      0.80       202
# I-Character_Name       0.83      0.30      0.44       165
#       I-Director       0.92      0.76      0.83       456
#          I-Genre       0.82      0.78      0.80       576
#        I-Opinion       0.37      0.27      0.31        84
#         I-Origin       0.75      0.70      0.72       729
#           I-Plot       0.87      0.94      0.90     11448
#          I-Quote       0.84      0.35      0.50       176
#   I-Relationship       0.64      0.45      0.53       240
#     I-Soundtrack       1.00      0.05      0.09        41
#           I-Year       0.79      0.67      0.72        33
#                O       0.85      0.86      0.86     10223
#
#         accuracy                           0.85     31304
#        macro avg       0.80      0.58      0.64     31304
#     weighted avg       0.85      0.85      0.85     31304
#
# (0.797840865304654, 0.5848888414585137, 0.6396102556570454, None)

# %% [markdown]
# #Classification report after adding the features to get_features function
#
#                     precision    recall  f1-score   support
#
#          B-Actor       0.92      0.93      0.93      1231
#          B-Award       0.75      0.65      0.70        75
# B-Character_Name       0.74      0.33      0.46       212
#       B-Director       0.91      0.77      0.83       472
#          B-Genre       0.89      0.84      0.87       805
#        B-Opinion       0.61      0.36      0.45       160
#         B-Origin       0.57      0.45      0.50       159
#           B-Plot       0.49      0.45      0.47      1221
#          B-Quote       0.86      0.25      0.39        24
#   B-Relationship       0.82      0.53      0.64       125
#     B-Soundtrack       1.00      0.15      0.27        13
#           B-Year       0.98      0.99      0.98       703
#          I-Actor       0.93      0.92      0.93      1731
#          I-Award       0.81      0.78      0.80       202
# I-Character_Name       0.76      0.30      0.43       165
#       I-Director       0.92      0.76      0.83       456
#          I-Genre       0.82      0.78      0.80       576
#        I-Opinion       0.42      0.26      0.32        84
#         I-Origin       0.73      0.68      0.70       729
#           I-Plot       0.87      0.94      0.90     11448
#          I-Quote       0.92      0.31      0.47       176
#   I-Relationship       0.66      0.45      0.54       240
#     I-Soundtrack       1.00      0.05      0.09        41
#           I-Year       0.79      0.67      0.72        33
#                O       0.85      0.87      0.86     10223
#
#         accuracy                           0.85     31304
#        macro avg       0.80      0.58      0.64     31304
#     weighted avg       0.85      0.85      0.85     31304
#
# (0.8004030378492045, 0.5795477583011504, 0.6353858164613881, None)

# %%
def confusion_matrix_heatmap(y_test, preds):
    """Function to plot a confusion matrix"""
    labels = list(set(y_test))   # get the labels in the y_test
    # print(labels)
    cm = confusion_matrix(y_test, preds, labels)
    fig = plt.figure(figsize=(20,20))
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title('Confusion matrix of the classifier')
    fig.colorbar(cax)
    ax.set_xticks(np.arange(len(labels)))
    ax.set_yticks(np.arange(len(labels)))
    ax.set_xticklabels( labels, rotation=45)
    ax.set_yticklabels( labels)

    for i in range(len(cm)):
        for j in range(len(cm)):
            text = ax.text(j, i, cm[i, j],
                           ha="center", va="center", color="w")

    plt.xlabel('Predicted')
    plt.ylabel('True')
    #fig.tight_layout()
    # fix for mpl bug that cuts off top/bottom of seaborn viz:
    b, t = plt.ylim() # discover the values for bottom and top
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t) # update the ylim(bottom, top) values
    plt.show() # ta-da!
    
confusion_matrix_heatmap(y_test, preds)
# Out:
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=['I-Quote', 'B-Origin', 'I-Plot', 'I-Relationship', 'B-Soundtrack', 'B-Quote', 'B-Director', 'I-Actor', 'B-Year', 'B-Genre', 'B-Opinion', 'B-Actor', 'I-Genre', 'I-Year', 'I-Origin', 'I-Soundtrack', 'I-Director', 'B-Relationship', 'I-Character_Name', 'O', 'B-Award', 'B-Character_Name', 'B-Plot', 'I-Award', 'I-Opinion'] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %%
raw_training_data = get_raw_data_from_bio_file("trivia10k13train.bio.txt") 

import numpy as np
from sklearn.model_selection import train_test_split

x_train, x_test = train_test_split(raw_training_data,train_size = 0.8,  test_size=0.2 , shuffle = False)

# %%
training_data = [preProcess1(example) for example in x_train]

# %%
#Modifing the minfreq


# Train the CRF BIO-tag tagger
TAGGER_PATH = "crf_nlu.tagger"  # path to the tagger- it will save/access the model from here
#ct = CRFTagger(feature_func=get_features1)  # initialize tagger with get_features function
ct = CRFTagger(feature_func=get_features1, training_opt={"c1":0.2,"c2":0.2})

print("training tagger...")
ct.train(training_data, TAGGER_PATH)
print("done")

# load tagger from saved file
#ct = CRFTagger(feature_func=get_features1)  # initialize tagger
ct = CRFTagger(feature_func=get_features1, training_opt={"c1":0.2,"c2":0.2})
ct.set_model_file(TAGGER_PATH)  # load model from file

# prepare the test data:

x_test = [preProcess1(example) for example in x_test]
#print(x_test)
#print(len(x_test), "instances")
#print(sum([len(sent) for sent in x_test]), "words")

print("testing tagger...")
preds = []
y_test = []
for sent in x_test:
    sent_preds = [x[1] for x in ct.tag([s[0] for s in sent])]
    sent_true = [s[1] for s in sent]
    preds.extend(sent_preds)
    y_test.extend(sent_true)
print("done")
#print(predicted)
# Out:
# training tagger...
# done
# testing tagger...
# done

# %%
# Output the classification report (which you should save each time for comparing your models)
print(classification_report(y_test, preds))
print(precision_recall_fscore_support(y_test, preds, average='macro'))  # print out accurate macro score
# Out:
#                   precision    recall  f1-score   support
#
#          B-Actor       0.92      0.94      0.93      1231
#          B-Award       0.73      0.64      0.68        75
# B-Character_Name       0.72      0.38      0.50       212
#       B-Director       0.90      0.76      0.83       472
#          B-Genre       0.89      0.85      0.87       805
#        B-Opinion       0.59      0.38      0.46       160
#         B-Origin       0.59      0.50      0.54       159
#           B-Plot       0.49      0.45      0.47      1221
#          B-Quote       0.67      0.33      0.44        24
#   B-Relationship       0.80      0.54      0.64       125
#     B-Soundtrack       0.75      0.23      0.35        13
#           B-Year       0.97      0.99      0.98       703
#          I-Actor       0.93      0.94      0.93      1731
#          I-Award       0.80      0.79      0.79       202
# I-Character_Name       0.76      0.38      0.50       165
#       I-Director       0.92      0.77      0.84       456
#          I-Genre       0.84      0.77      0.80       576
#        I-Opinion       0.40      0.30      0.34        84
#         I-Origin       0.73      0.70      0.71       729
#           I-Plot       0.88      0.93      0.90     11448
#          I-Quote       0.74      0.38      0.50       176
#   I-Relationship       0.73      0.45      0.56       240
#     I-Soundtrack       1.00      0.17      0.29        41
#           I-Year       0.77      0.73      0.75        33
#                O       0.85      0.87      0.86     10223
#
#         accuracy                           0.85     31304
#        macro avg       0.77      0.61      0.66     31304
#     weighted avg       0.85      0.85      0.85     31304
#
# (0.7745745514898725, 0.6063326127327022, 0.6594991073456816, None)

# %% [markdown]
# #Classification report when the minfreq = 2
#
#                     precision    recall  f1-score   support
#
#          B-Actor       0.92      0.94      0.93      1231
#          B-Award       0.75      0.65      0.70        75
# B-Character_Name       0.75      0.33      0.45       212
#       B-Director       0.90      0.76      0.82       472
#          B-Genre       0.89      0.83      0.86       805
#        B-Opinion       0.62      0.38      0.47       160
#         B-Origin       0.55      0.44      0.49       159
#           B-Plot       0.50      0.46      0.48      1221
#          B-Quote       0.75      0.25      0.38        24
#   B-Relationship       0.81      0.53      0.64       125
#     B-Soundtrack       0.50      0.08      0.13        13
#           B-Year       0.98      0.99      0.98       703
#          I-Actor       0.93      0.93      0.93      1731
#          I-Award       0.82      0.79      0.80       202
# I-Character_Name       0.74      0.32      0.44       165
#       I-Director       0.90      0.75      0.82       456
#          I-Genre       0.81      0.77      0.79       576
#        I-Opinion       0.28      0.24      0.26        84
#         I-Origin       0.73      0.68      0.70       729
#           I-Plot       0.87      0.94      0.90     11448
#          I-Quote       0.75      0.28      0.41       176
#   I-Relationship       0.66      0.45      0.54       240
#     I-Soundtrack       0.25      0.02      0.04        41
#           I-Year       0.79      0.67      0.72        33
#                O       0.85      0.87      0.86     10223
#
#         accuracy                           0.85     31304
#        macro avg       0.73      0.57      0.62     31304
#     weighted avg       0.85      0.85      0.85     31304
#
# (0.7317164664040393, 0.5731421881793213, 0.6221089149797558, None)
#
#
#
# #Classification report when the minfreq = 3
#
#
#                   precision    recall  f1-score   support
#
#          B-Actor       0.92      0.93      0.93      1231
#          B-Award       0.77      0.65      0.71        75
# B-Character_Name       0.75      0.34      0.47       212
#       B-Director       0.90      0.76      0.82       472
#          B-Genre       0.88      0.82      0.85       805
#        B-Opinion       0.61      0.37      0.46       160
#         B-Origin       0.58      0.45      0.51       159
#           B-Plot       0.50      0.46      0.48      1221
#          B-Quote       0.60      0.25      0.35        24
#   B-Relationship       0.81      0.54      0.64       125
#     B-Soundtrack       0.25      0.08      0.12        13
#           B-Year       0.98      0.99      0.98       703
#          I-Actor       0.93      0.93      0.93      1731
#          I-Award       0.81      0.80      0.80       202
# I-Character_Name       0.71      0.33      0.45       165
#       I-Director       0.90      0.74      0.81       456
#          I-Genre       0.80      0.77      0.78       576
#        I-Opinion       0.27      0.24      0.25        84
#         I-Origin       0.74      0.69      0.71       729
#           I-Plot       0.88      0.93      0.91     11448
#          I-Quote       0.68      0.31      0.43       176
#   I-Relationship       0.62      0.46      0.53       240
#     I-Soundtrack       0.45      0.12      0.19        41
#           I-Year       0.82      0.70      0.75        33
#                O       0.85      0.87      0.86     10223
#
#         accuracy                           0.85     31304
#        macro avg       0.72      0.58      0.63     31304
#     weighted avg       0.85      0.85      0.85     31304
#
# (0.7207916945228096, 0.5816815560757368, 0.6298643114221203, None)
#
#
# #Classification report when the minfreq = 4
#
#
#                   precision    recall  f1-score   support
#
#          B-Actor       0.92      0.93      0.92      1231
#          B-Award       0.75      0.63      0.68        75
# B-Character_Name       0.75      0.32      0.45       212
#       B-Director       0.90      0.76      0.82       472
#          B-Genre       0.88      0.82      0.85       805
#        B-Opinion       0.59      0.32      0.41       160
#         B-Origin       0.59      0.47      0.52       159
#           B-Plot       0.50      0.46      0.48      1221
#          B-Quote       0.70      0.29      0.41        24
#   B-Relationship       0.82      0.54      0.65       125
#     B-Soundtrack       1.00      0.15      0.27        13
#           B-Year       0.98      0.98      0.98       703
#          I-Actor       0.92      0.93      0.93      1731
#          I-Award       0.81      0.80      0.80       202
# I-Character_Name       0.68      0.32      0.43       165
#       I-Director       0.90      0.75      0.82       456
#          I-Genre       0.81      0.78      0.79       576
#        I-Opinion       0.18      0.14      0.16        84
#         I-Origin       0.74      0.70      0.72       729
#           I-Plot       0.87      0.94      0.90     11448
#          I-Quote       0.70      0.32      0.44       176
#   I-Relationship       0.61      0.50      0.55       240
#     I-Soundtrack       1.00      0.15      0.26        41
#           I-Year       0.79      0.67      0.72        33
#                O       0.86      0.86      0.86     10223
#
#         accuracy                           0.85     31304
#        macro avg       0.77      0.58      0.63     31304
#     weighted avg       0.85      0.85      0.85     31304
#
# (0.7689284038065325, 0.5812836143578672, 0.6334994680557336, None)
#
#
# Classification report when c1 = 0.25 and c2= 0.3
#
#                  precision    recall  f1-score   support
#
#          B-Actor       0.92      0.93      0.93      1231
#          B-Award       0.73      0.63      0.68        75
# B-Character_Name       0.76      0.34      0.47       212
#       B-Director       0.90      0.77      0.83       472
#          B-Genre       0.89      0.84      0.86       805
#        B-Opinion       0.60      0.38      0.47       160
#         B-Origin       0.59      0.47      0.52       159
#           B-Plot       0.51      0.47      0.49      1221
#          B-Quote       0.67      0.33      0.44        24
#   B-Relationship       0.81      0.54      0.65       125
#     B-Soundtrack       0.60      0.23      0.33        13
#           B-Year       0.98      0.99      0.98       703
#          I-Actor       0.92      0.93      0.93      1731
#          I-Award       0.79      0.80      0.80       202
# I-Character_Name       0.74      0.35      0.47       165
#       I-Director       0.91      0.77      0.83       456
#          I-Genre       0.81      0.77      0.79       576
#        I-Opinion       0.23      0.24      0.24        84
#         I-Origin       0.74      0.68      0.71       729
#           I-Plot       0.88      0.94      0.90     11448
#          I-Quote       0.74      0.38      0.50       176
#   I-Relationship       0.68      0.47      0.56       240
#     I-Soundtrack       0.70      0.17      0.27        41
#           I-Year       0.79      0.70      0.74        33
#                O       0.86      0.87      0.86     10223
#
#         accuracy                           0.85     31304
#        macro avg       0.75      0.60      0.65     31304
#     weighted avg       0.85      0.85      0.85     31304
#
# (0.749520636521778, 0.5991952374415128, 0.650150837325279, None)
#
# Classification report when c1 = 0.2 and c2= 0.2
#                   precision    recall  f1-score   support
#
#          B-Actor       0.92      0.94      0.93      1231
#          B-Award       0.72      0.63      0.67        75
# B-Character_Name       0.73      0.36      0.48       212
#       B-Director       0.90      0.77      0.83       472
#          B-Genre       0.89      0.85      0.87       805
#        B-Opinion       0.61      0.39      0.48       160
#         B-Origin       0.56      0.47      0.51       159
#           B-Plot       0.49      0.45      0.47      1221
#          B-Quote       0.67      0.33      0.44        24
#   B-Relationship       0.79      0.54      0.64       125
#     B-Soundtrack       0.75      0.23      0.35        13
#           B-Year       0.98      0.99      0.98       703
#          I-Actor       0.93      0.94      0.93      1731
#          I-Award       0.78      0.81      0.80       202
# I-Character_Name       0.74      0.36      0.49       165
#       I-Director       0.92      0.77      0.84       456
#          I-Genre       0.83      0.78      0.80       576
#        I-Opinion       0.42      0.30      0.35        84
#         I-Origin       0.73      0.68      0.71       729
#           I-Plot       0.88      0.93      0.90     11448
#          I-Quote       0.74      0.38      0.50       176
#   I-Relationship       0.71      0.45      0.55       240
#     I-Soundtrack       1.00      0.17      0.29        41
#           I-Year       0.80      0.73      0.76        33
#                O       0.86      0.87      0.86     10223
#
#         accuracy                           0.85     31304
#        macro avg       0.77      0.60      0.66     31304
#     weighted avg       0.85      0.85      0.85     31304
#
# (0.7731889972127022, 0.604376683160191, 0.6575428865611712, None)

# %% [markdown]
# # TRAINING AND TESTING ON RAW DATA

# %%
raw_training_data = get_raw_data_from_bio_file("trivia10k13train.bio.txt")

# %%
training_data = [preProcess1(example) for example in raw_training_data]

# %%
# Final results on original test data, using all training data, with best settings from dev set:

# prepare the test data:
raw_test_data = get_raw_data_from_bio_file("trivia10k13test.bio.txt") 
test_data = [preProcess1(example) for example in raw_test_data]
print(len(test_data), "instances")
print(sum([len(sent) for sent in test_data]), "words")


# Train the CRF BIO-tag tagger on all training data
TAGGER_PATH = "crf_nlu.tagger"  # path to the tagger- it will save/access the model from here
ct = CRFTagger(feature_func=get_features1, training_opt={"c1":0.2,"c2":0.2}) # initialize tagger with get_features function

print("training tagger...")
ct.train(training_data, TAGGER_PATH)
print("done")

# load tagger from saved file
ct = CRFTagger(feature_func=get_features1, training_opt={"c1":0.2,"c2":0.2})  # initialize tagger
ct.set_model_file(TAGGER_PATH)  # load model from file

print(len(test_data), "instances")
print(sum([len(sent) for sent in test_data]), "words")

print("testing tagger on test data...")
preds = []
y_test = []
for sent in test_data:
    sent_preds = [x[1] for x in ct.tag([s[0] for s in sent])]
    sent_true = [s[1] for s in sent]
    preds.extend(sent_preds)
    y_test.extend(sent_true)
print("done")
# Out:
# 1953 instances
# 39035 words
# training tagger...
# done
# 1953 instances
# 39035 words
# testing tagger on test data...
# done

# %%
print(classification_report(y_test, preds))
print(precision_recall_fscore_support(y_test, preds, average='macro'))
# Out:
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                   precision    recall  f1-score   support
#
#          B-Actor       0.92      0.93      0.92      1274
#          B-Award       0.72      0.74      0.73        66
# B-Character_Name       0.71      0.45      0.55       283
#       B-Director       0.86      0.84      0.85       425
#          B-Genre       0.82      0.79      0.81       789
#        B-Opinion       0.50      0.40      0.44       195
#         B-Origin       0.47      0.37      0.41       190
#           B-Plot       0.51      0.49      0.50      1577
#          B-Quote       0.77      0.36      0.49        47
#   B-Relationship       0.80      0.57      0.67       171
#     B-Soundtrack       0.00      0.00      0.00         8
#           B-Year       0.97      0.97      0.97       661
#          I-Actor       0.92      0.93      0.92      1553
#          I-Award       0.79      0.82      0.81       147
# I-Character_Name       0.74      0.52      0.61       227
#       I-Director       0.90      0.85      0.87       411
#          I-Genre       0.80      0.75      0.77       544
#        I-Opinion       0.36      0.17      0.24       143
#         I-Origin       0.66      0.65      0.66       808
#           I-Plot       0.86      0.93      0.89     14661
#          I-Quote       0.84      0.63      0.72       349
#   I-Relationship       0.53      0.47      0.50       289
#     I-Soundtrack       0.00      0.00      0.00        30
#           I-Year       0.68      0.57      0.62        44
#                O       0.88      0.84      0.86     14143
#
#         accuracy                           0.84     39035
#        macro avg       0.68      0.60      0.63     39035
#     weighted avg       0.84      0.84      0.84     39035
#
# (0.6794255365190429, 0.602286967462336, 0.6324127052875607, None)
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
def confusion_matrix_heatmap(y_test, preds):
    """Function to plot a confusion matrix"""
    labels = list(set(y_test))   # get the labels in the y_test
    # print(labels)
    cm = confusion_matrix(y_test, preds, labels)
    fig = plt.figure(figsize=(20,20))
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title('Confusion matrix of the classifier')
    fig.colorbar(cax)
    ax.set_xticks(np.arange(len(labels)))
    ax.set_yticks(np.arange(len(labels)))
    ax.set_xticklabels( labels, rotation=45)
    ax.set_yticklabels( labels)

    for i in range(len(cm)):
        for j in range(len(cm)):
            text = ax.text(j, i, cm[i, j],
                           ha="center", va="center", color="w")

    plt.xlabel('Predicted')
    plt.ylabel('True')
    #fig.tight_layout()
    # fix for mpl bug that cuts off top/bottom of seaborn viz:
    b, t = plt.ylim() # discover the values for bottom and top
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t) # update the ylim(bottom, top) values
    plt.show() # ta-da!
    
confusion_matrix_heatmap(y_test, preds)
# Out:
# /Users/urmithakkar/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=['I-Quote', 'B-Origin', 'I-Plot', 'I-Relationship', 'B-Soundtrack', 'B-Quote', 'B-Director', 'I-Actor', 'B-Year', 'B-Genre', 'B-Opinion', 'B-Actor', 'I-Genre', 'I-Year', 'I-Origin', 'I-Soundtrack', 'I-Director', 'B-Relationship', 'I-Character_Name', 'O', 'B-Award', 'B-Character_Name', 'B-Plot', 'I-Award', 'I-Opinion'] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
